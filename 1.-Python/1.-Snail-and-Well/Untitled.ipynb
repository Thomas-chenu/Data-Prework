# %%
# !pip3 install bs4
# Out:
# Requirement already satisfied: bs4 in /usr/local/lib/python3.9/site-packages (0.0.1)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.9/site-packages (from bs4) (4.9.3)
# Requirement already satisfied: soupsieve>1.2; python_version >= "3.0" in /usr/local/lib/python3.9/site-packages (from beautifulsoup4->bs4) (2.0.1)

# %%
# !pip3 install requests
# Out:
# Requirement already satisfied: requests in /usr/local/lib/python3.9/site-packages (2.24.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/site-packages (from requests) (2020.6.20)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.9/site-packages (from requests) (1.25.11)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.9/site-packages (from requests) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.9/site-packages (from requests) (2.10)

# %%
# !pip3 install selenium
# Out:
# Requirement already satisfied: selenium in /usr/local/lib/python3.9/site-packages (3.141.0)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.9/site-packages (from selenium) (1.25.11)

# %%
# !pip3 install catboost
# Out:
# Requirement already satisfied: catboost in /usr/local/lib/python3.9/site-packages (0.1.1.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.9/site-packages (from catboost) (1.19.4)
# Requirement already satisfied: six in /usr/local/lib/python3.9/site-packages (from catboost) (1.15.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.9/site-packages (from catboost) (1.1.4)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.9/site-packages (from pandas->catboost) (2.8.1)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.9/site-packages (from pandas->catboost) (2020.4)

# %%
# !pip3 install xgboost
# Out:
# Collecting xgboost
#   Using cached xgboost-1.2.1-py3-none-macosx_10_13_x86_64.macosx_10_14_x86_64.macosx_10_15_x86_64.whl (1.2 MB)
# Collecting scipy
#   Using cached scipy-1.5.3.tar.gz (25.2 MB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# Requirement already satisfied: numpy in /usr/local/lib/python3.9/site-packages (from xgboost) (1.19.4)
# Building wheels for collected packages: scipy
#   Building wheel for scipy (PEP 517) ... error
#   ERROR: Command errored out with exit status 1:
#    command: /usr/local/opt/python@3.9/bin/python3.9 /usr/local/lib/python3.9/site-packages/pip/_vendor/pep517/_in_process.py build_wheel /var/folders/5m/z78sg2m56qj87c1075qmwq780000gn/T/tmpyfufvjbf
#        cwd: /private/var/folders/5m/z78sg2m56qj87c1075qmwq780000gn/T/pip-install-j5ylw76p/scipy
#   Complete output (810 lines):
#   Running from SciPy source directory.
#   lapack_opt_info:
#   lapack_mkl_info:
#   customize UnixCCompiler
#     libraries mkl_rt not found in ['/usr/local/Cellar/python@3.9/3.9.0_1/Frameworks/Python.framework/Versions/3.9/lib', '/usr/local/lib', '/usr/lib']
#     NOT AVAILABLE
#
#   openblas_lapack_info:
#   customize UnixCCompiler
#   customize UnixCCompiler
#     libraries openblas not found in ['/usr/local/Cellar/python@3.9/3.9.0_1/Frameworks/Python.framework/Versions/3.9/lib', '/usr/local/lib', '/usr/lib']
#     NOT AVAILABLE
#
#   openblas_clapack_info:
#   customize UnixCCompiler
#   customize UnixCCompiler
#     libraries openblas,lapack not found in ['/usr/local/Cellar/python@3.9/3.9.0_1/Frameworks/Python.framework/Versions/3.9/lib', '/usr/local/lib', '/usr/lib']
#     NOT AVAILABLE
#
#   flame_info:
#   customize UnixCCompiler
#     libraries flame not found in ['/usr/local/Cellar/python@3.9/3.9.0_1/Frameworks/Python.framework/Versions/3.9/lib', '/usr/local/lib', '/usr/lib']
#     NOT AVAILABLE
#
#   atlas_3_10_threads_info:
#   Setting PTATLAS=ATLAS
#   customize UnixCCompiler
#     libraries lapack_atlas not found in /usr/local/Cellar/python@3.9/3.9.0_1/Frameworks/Python.framework/Versions/3.9/lib
#   customize UnixCCompiler
#     libraries tatlas,tatlas not found in /usr/local/Cellar/python@3.9/3.9.0_1/Frameworks/Python.framework/Versions/3.9/lib
#   customize UnixCCompiler
#     libraries lapack_atlas not found in /usr/local/lib
#   customize UnixCCompiler
#     libraries tatlas,tatlas not found in /usr/local/lib
#   customize UnixCCompiler
#     libraries lapack_atlas not found in /usr/lib
#   customize UnixCCompiler
#     libraries tatlas,tatlas not found in /usr/lib
#   <class 'numpy.distutils.system_info.atlas_3_10_threads_info'>
#     NOT AVAILABLE
#
#   atlas_3_10_info:
#   customize UnixCCompiler
#     libraries lapack_atlas not found in /usr/local/Cellar/python@3.9/3.9.0_1/Frameworks/Python.framework/Versions/3.9/lib
#   customize UnixCCompiler
#     libraries satlas,satlas not found in /usr/local/Cellar/python@3.9/3.9.0_1/Frameworks/Python.framework/Versions/3.9/lib
#   customize UnixCCompiler
#     libraries lapack_atlas not found in /usr/local/lib
#   customize UnixCCompiler
#     libraries satlas,satlas not found in /usr/local/lib
#   customize UnixCCompiler
#     libraries lapack_atlas not found in /usr/lib
#   customize UnixCCompiler
#     libraries satlas,satlas not found in /usr/lib
#   <class 'numpy.distutils.system_info.atlas_3_10_info'>
#     NOT AVAILABLE
#
#   atlas_threads_info:
#   Setting PTATLAS=ATLAS
#   customize UnixCCompiler
#     libraries lapack_atlas not found in /usr/local/Cellar/python@3.9/3.9.0_1/Frameworks/Python.framework/Versions/3.9/lib
#   customize UnixCCompiler
#     libraries ptf77blas,ptcblas,atlas not found in /usr/local/Cellar/python@3.9/3.9.0_1/Frameworks/Python.framework/Versions/3.9/lib
#   customize UnixCCompiler
#     libraries lapack_atlas not found in /usr/local/lib
#   customize UnixCCompiler
#     libraries ptf77blas,ptcblas,atlas not found in /usr/local/lib
#   customize UnixCCompiler
#     libraries lapack_atlas not found in /usr/lib
#   customize UnixCCompiler
#     libraries ptf77blas,ptcblas,atlas not found in /usr/lib
#   <class 'numpy.distutils.system_info.atlas_threads_info'>
#     NOT AVAILABLE
#
#   atlas_info:
#   customize UnixCCompiler
#     libraries lapack_atlas not found in /usr/local/Cellar/python@3.9/3.9.0_1/Frameworks/Python.framework/Versions/3.9/lib
#   customize UnixCCompiler
#     libraries f77blas,cblas,atlas not found in /usr/local/Cellar/python@3.9/3.9.0_1/Frameworks/Python.framework/Versions/3.9/lib
#   customize UnixCCompiler
#     libraries lapack_atlas not found in /usr/local/lib
#   customize UnixCCompiler
#     libraries f77blas,cblas,atlas not found in /usr/local/lib
#   customize UnixCCompiler
#     libraries lapack_atlas not found in /usr/lib
#   customize UnixCCompiler
#     libraries f77blas,cblas,atlas not found in /usr/lib
#   <class 'numpy.distutils.system_info.atlas_info'>
#     NOT AVAILABLE
#
#   accelerate_info:
#     NOT AVAILABLE
#
#   lapack_info:
#   customize UnixCCompiler
#   customize UnixCCompiler
#     FOUND:
#       libraries = ['lapack', 'lapack']
#       library_dirs = ['/usr/lib']
#       language = f77
#
#   blas_opt_info:
#   blas_mkl_info:
#   customize UnixCCompiler
#     libraries mkl_rt not found in ['/usr/local/Cellar/python@3.9/3.9.0_1/Frameworks/Python.framework/Versions/3.9/lib', '/usr/local/lib', '/usr/lib']
#     NOT AVAILABLE
#
#   blis_info:
#   customize UnixCCompiler
#     libraries blis not found in ['/usr/local/Cellar/python@3.9/3.9.0_1/Frameworks/Python.framework/Versions/3.9/lib', '/usr/local/lib', '/usr/lib']
#     NOT AVAILABLE
#
#   openblas_info:
#   customize UnixCCompiler
#   customize UnixCCompiler
#     libraries openblas not found in ['/usr/local/Cellar/python@3.9/3.9.0_1/Frameworks/Python.framework/Versions/3.9/lib', '/usr/local/lib', '/usr/lib']
#     NOT AVAILABLE
#
#   atlas_3_10_blas_threads_info:
#   Setting PTATLAS=ATLAS
#   customize UnixCCompiler
#     libraries tatlas not found in ['/usr/local/Cellar/python@3.9/3.9.0_1/Frameworks/Python.framework/Versions/3.9/lib', '/usr/local/lib', '/usr/lib']
#     NOT AVAILABLE
#
#   atlas_3_10_blas_info:
#   customize UnixCCompiler
#     libraries satlas not found in ['/usr/local/Cellar/python@3.9/3.9.0_1/Frameworks/Python.framework/Versions/3.9/lib', '/usr/local/lib', '/usr/lib']
#     NOT AVAILABLE
#
#   atlas_blas_threads_info:
#   Setting PTATLAS=ATLAS
#   customize UnixCCompiler
#     libraries ptf77blas,ptcblas,atlas not found in ['/usr/local/Cellar/python@3.9/3.9.0_1/Frameworks/Python.framework/Versions/3.9/lib', '/usr/local/lib', '/usr/lib']
#     NOT AVAILABLE
#
#   atlas_blas_info:
#   customize UnixCCompiler
#     libraries f77blas,cblas,atlas not found in ['/usr/local/Cellar/python@3.9/3.9.0_1/Frameworks/Python.framework/Versions/3.9/lib', '/usr/local/lib', '/usr/lib']
#     NOT AVAILABLE
#
#   /private/var/folders/5m/z78sg2m56qj87c1075qmwq780000gn/T/pip-build-env-ghbvshz8/overlay/lib/python3.9/site-packages/numpy/distutils/system_info.py:690: UserWarning:
#       Optimized (vendor) Blas libraries are not found.
#       Falls back to netlib Blas library which has worse performance.
#       A better performance should be easily gained by switching
#       Blas library.
#     self.calc_info()
#   blas_info:
#   customize UnixCCompiler
#   customize UnixCCompiler
#   C compiler: clang -Wno-unused-result -Wsign-compare -Wunreachable-code -fno-common -dynamic -DNDEBUG -g -fwrapv -O3 -Wall -isysroot /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk -I/Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include -I/Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/System/Library/Frameworks/Tk.framework/Versions/8.5/Headers
#
#   creating /var/folders/5m/z78sg2m56qj87c1075qmwq780000gn/T/tmpbwxug7c8/var
#   creating /var/folders/5m/z78sg2m56qj87c1075qmwq780000gn/T/tmpbwxug7c8/var/folders
#   creating /var/folders/5m/z78sg2m56qj87c1075qmwq780000gn/T/tmpbwxug7c8/var/folders/5m
#   creating /var/folders/5m/z78sg2m56qj87c1075qmwq780000gn/T/tmpbwxug7c8/var/folders/5m/z78sg2m56qj87c1075qmwq780000gn
#   creating /var/folders/5m/z78sg2m56qj87c1075qmwq780000gn/T/tmpbwxug7c8/var/folders/5m/z78sg2m56qj87c1075qmwq780000gn/T
#   creating /var/folders/5m/z78sg2m56qj87c1075qmwq780000gn/T/tmpbwxug7c8/var/folders/5m/z78sg2m56qj87c1075qmwq780000gn/T/tmpbwxug7c8
#   compile options: '-I/usr/local/include -I/usr/local/Cellar/python@3.9/3.9.0_1/Frameworks/Python.framework/Versions/3.9/include -c'
#   clang: /var/folders/5m/z78sg2m56qj87c1075qmwq780000gn/T/tmpbwxug7c8/source.c
#   /var/folders/5m/z78sg2m56qj87c1075qmwq780000gn/T/tmpbwxug7c8/source.c:1:10: fatal error: 'cblas.h' file not found
#   #include <cblas.h>
#            ^~~~~~~~~
#   1 error generated.
#   customize UnixCCompiler
#     FOUND:
#       libraries = ['blas', 'blas']
#       library_dirs = ['/usr/lib']
#       include_dirs = ['/usr/local/include', '/usr/local/Cellar/python@3.9/3.9.0_1/Frameworks/Python.framework/Versions/3.9/include']
#
#     FOUND:
#       define_macros = [('NO_ATLAS_INFO', 1)]
#       libraries = ['blas', 'blas']
#       library_dirs = ['/usr/lib']
#       include_dirs = ['/usr/local/include', '/usr/local/Cellar/python@3.9/3.9.0_1/Frameworks/Python.framework/Versions/3.9/include']
#
#     FOUND:
#       libraries = ['lapack', 'lapack', 'blas', 'blas']
#       library_dirs = ['/usr/lib']
#       language = f77
#       define_macros = [('NO_ATLAS_INFO', 1)]
#       include_dirs = ['/usr/local/include', '/usr/local/Cellar/python@3.9/3.9.0_1/Frameworks/Python.framework/Versions/3.9/include']
#
#   /private/var/folders/5m/z78sg2m56qj87c1075qmwq780000gn/T/pip-build-env-ghbvshz8/overlay/lib/python3.9/site-packages/numpy/distutils/system_info.py:782: UserWarning: Specified path /private/var/folders/5m/z78sg2m56qj87c1075qmwq780000gn/T/pip-build-env-ghbvshz8/overlay/include/python3.9 is invalid.
#     return self.get_paths(self.section, key)
#   /private/var/folders/5m/z78sg2m56qj87c1075qmwq780000gn/T/pip-build-env-ghbvshz8/overlay/lib/python3.9/site-packages/numpy/distutils/system_info.py:782: UserWarning: Specified path /usr/local/include/python3.9 is invalid.
#     return self.get_paths(self.section, key)
#   [makenpz] scipy/special/tests/data/boost.npz not rebuilt
#   [makenpz] scipy/special/tests/data/gsl.npz not rebuilt
#   [makenpz] scipy/special/tests/data/local.npz not rebuilt
#   non-existing path in 'scipy/signal/windows': 'tests'
#   running bdist_wheel
#   running build
#   running config_cc
#   unifing config_cc, config, build_clib, build_ext, build commands --compiler options
#   running config_fc
#   unifing config_fc, config, build_clib, build_ext, build commands --fcompiler options
#   running build_src
#   build_src
#   building py_modules sources
#   building library "mach" sources
#   building library "quadpack" sources
#   building library "lsoda" sources
#   building library "vode" sources
#   building library "dop" sources
#   building library "fitpack" sources
#   building library "fwrappers" sources
#   building library "odrpack" sources
#   building library "minpack" sources
#   building library "rectangular_lsap" sources
#   building library "rootfind" sources
#   building library "superlu_src" sources
#   building library "arpack_scipy" sources
#   building library "sc_cephes" sources
#   building library "sc_mach" sources
#   building library "sc_amos" sources
#   building library "sc_cdf" sources
#   building library "sc_specfun" sources
#   building library "statlib" sources
#   building extension "scipy.cluster._vq" sources
#   building extension "scipy.cluster._hierarchy" sources
#   building extension "scipy.cluster._optimal_leaf_ordering" sources
#   building extension "scipy.fft._pocketfft.pypocketfft" sources
#   building extension "scipy.fftpack.convolve" sources
#   building extension "scipy.integrate._quadpack" sources
#   building extension "scipy.integrate._odepack" sources
#   building extension "scipy.integrate.vode" sources
#   f2py options: []
#     adding 'build/src.macosx-10.15-x86_64-3.9/build/src.macosx-10.15-x86_64-3.9/scipy/integrate/fortranobject.c' to sources.
#     adding 'build/src.macosx-10.15-x86_64-3.9/build/src.macosx-10.15-x86_64-3.9/scipy/integrate' to include_dirs.
#     adding 'build/src.macosx-10.15-x86_64-3.9/scipy/integrate/vode-f2pywrappers.f' to sources.
#   building extension "scipy.integrate.lsoda" sources
#   f2py options: []
#     adding 'build/src.macosx-10.15-x86_64-3.9/build/src.macosx-10.15-x86_64-3.9/scipy/integrate/fortranobject.c' to sources.
#     adding 'build/src.macosx-10.15-x86_64-3.9/build/src.macosx-10.15-x86_64-3.9/scipy/integrate' to include_dirs.
#     adding 'build/src.macosx-10.15-x86_64-3.9/scipy/integrate/lsoda-f2pywrappers.f' to sources.
#   building extension "scipy.integrate._dop" sources
#   f2py options: []
#     adding 'build/src.macosx-10.15-x86_64-3.9/build/src.macosx-10.15-x86_64-3.9/scipy/integrate/fortranobject.c' to sources.
#     adding 'build/src.macosx-10.15-x86_64-3.9/build/src.macosx-10.15-x86_64-3.9/scipy/integrate' to include_dirs.
#     adding 'build/src.macosx-10.15-x86_64-3.9/scipy/integrate/_dop-f2pywrappers.f' to sources.
#   building extension "scipy.integrate._test_multivariate" sources
#   building extension "scipy.integrate._test_odeint_banded" sources
#   f2py options: []
#     adding 'build/src.macosx-10.15-x86_64-3.9/build/src.macosx-10.15-x86_64-3.9/scipy/integrate/fortranobject.c' to sources.
#     adding 'build/src.macosx-10.15-x86_64-3.9/build/src.macosx-10.15-x86_64-3.9/scipy/integrate' to include_dirs.
#     adding 'build/src.macosx-10.15-x86_64-3.9/scipy/integrate/_test_odeint_banded-f2pywrappers.f' to sources.
#   building extension "scipy.interpolate.interpnd" sources
#   building extension "scipy.interpolate._ppoly" sources
#   building extension "scipy.interpolate._bspl" sources
#   building extension "scipy.interpolate._fitpack" sources
#   building extension "scipy.interpolate.dfitpack" sources
#   f2py options: []
#     adding 'build/src.macosx-10.15-x86_64-3.9/build/src.macosx-10.15-x86_64-3.9/scipy/interpolate/src/fortranobject.c' to sources.
#     adding 'build/src.macosx-10.15-x86_64-3.9/build/src.macosx-10.15-x86_64-3.9/scipy/interpolate/src' to include_dirs.
#     adding 'build/src.macosx-10.15-x86_64-3.9/scipy/interpolate/src/dfitpack-f2pywrappers.f' to sources.
#   building extension "scipy.io._test_fortran" sources
#   f2py options: []
#     adding 'build/src.macosx-10.15-x86_64-3.9/build/src.macosx-10.15-x86_64-3.9/scipy/io/fortranobject.c' to sources.
#     adding 'build/src.macosx-10.15-x86_64-3.9/build/src.macosx-10.15-x86_64-3.9/scipy/io' to include_dirs.
#   building extension "scipy.io.matlab.streams" sources
#   building extension "scipy.io.matlab.mio_utils" sources
#   building extension "scipy.io.matlab.mio5_utils" sources
#   building extension "scipy.linalg._fblas" sources
#   f2py options: []
#     adding 'build/src.macosx-10.15-x86_64-3.9/build/src.macosx-10.15-x86_64-3.9/build/src.macosx-10.15-x86_64-3.9/scipy/linalg/fortranobject.c' to sources.
#     adding 'build/src.macosx-10.15-x86_64-3.9/build/src.macosx-10.15-x86_64-3.9/build/src.macosx-10.15-x86_64-3.9/scipy/linalg' to include_dirs.
#     adding 'build/src.macosx-10.15-x86_64-3.9/build/src.macosx-10.15-x86_64-3.9/scipy/linalg/_fblas-f2pywrappers.f' to sources.
#   building extension "scipy.linalg._flapack" sources
#   f2py options: []
#     adding 'build/src.macosx-10.15-x86_64-3.9/build/src.macosx-10.15-x86_64-3.9/build/src.macosx-10.15-x86_64-3.9/scipy/linalg/fortranobject.c' to sources.
#     adding 'build/src.macosx-10.15-x86_64-3.9/build/src.macosx-10.15-x86_64-3.9/build/src.macosx-10.15-x86_64-3.9/scipy/linalg' to include_dirs.
#     adding 'build/src.macosx-10.15-x86_64-3.9/build/src.macosx-10.15-x86_64-3.9/scipy/linalg/_flapack-f2pywrappers.f' to sources.
#   building extension "scipy.linalg._flinalg" sources
#   f2py options: []
#     adding 'build/src.macosx-10.15-x86_64-3.9/build/src.macosx-10.15-x86_64-3.9/scipy/linalg/fortranobject.c' to sources.
#     adding 'build/src.macosx-10.15-x86_64-3.9/build/src.macosx-10.15-x86_64-3.9/scipy/linalg' to include_dirs.
#   building extension "scipy.linalg._interpolative" sources
#   f2py options: []
#     adding 'build/src.macosx-10.15-x86_64-3.9/build/src.macosx-10.15-x86_64-3.9/scipy/linalg/fortranobject.c' to sources.
#     adding 'build/src.macosx-10.15-x86_64-3.9/build/src.macosx-10.15-x86_64-3.9/scipy/linalg' to include_dirs.
#   building extension "scipy.linalg._solve_toeplitz" sources
#   building extension "scipy.linalg.cython_blas" sources
#   building extension "scipy.linalg.cython_lapack" sources
#   building extension "scipy.linalg._decomp_update" sources
#   building extension "scipy.odr.__odrpack" sources
#   building extension "scipy.optimize._minpack" sources
#   building extension "scipy.optimize._lsap_module" sources
#   building extension "scipy.optimize._zeros" sources
#   building extension "scipy.optimize._lbfgsb" sources
#   f2py options: []
#     adding 'build/src.macosx-10.15-x86_64-3.9/build/src.macosx-10.15-x86_64-3.9/scipy/optimize/lbfgsb_src/fortranobject.c' to sources.
#     adding 'build/src.macosx-10.15-x86_64-3.9/build/src.macosx-10.15-x86_64-3.9/scipy/optimize/lbfgsb_src' to include_dirs.
#     adding 'build/src.macosx-10.15-x86_64-3.9/scipy/optimize/lbfgsb_src/_lbfgsb-f2pywrappers.f' to sources.
#   building extension "scipy.optimize.moduleTNC" sources
#   building extension "scipy.optimize._cobyla" sources
#   f2py options: []
#     adding 'build/src.macosx-10.15-x86_64-3.9/build/src.macosx-10.15-x86_64-3.9/scipy/optimize/cobyla/fortranobject.c' to sources.
#     adding 'build/src.macosx-10.15-x86_64-3.9/build/src.macosx-10.15-x86_64-3.9/scipy/optimize/cobyla' to include_dirs.
#   building extension "scipy.optimize.minpack2" sources
#   f2py options: []
#     adding 'build/src.macosx-10.15-x86_64-3.9/build/src.macosx-10.15-x86_64-3.9/scipy/optimize/minpack2/fortranobject.c' to sources.
#     adding 'build/src.macosx-10.15-x86_64-3.9/build/src.macosx-10.15-x86_64-3.9/scipy/optimize/minpack2' to include_dirs.
#   building extension "scipy.optimize._slsqp" sources
#   f2py options: []
#     adding 'build/src.macosx-10.15-x86_64-3.9/build/src.macosx-10.15-x86_64-3.9/scipy/optimize/slsqp/fortranobject.c' to sources.
#     adding 'build/src.macosx-10.15-x86_64-3.9/build/src.macosx-10.15-x86_64-3.9/scipy/optimize/slsqp' to include_dirs.
#   building extension "scipy.optimize.__nnls" sources
#   f2py options: []
#     adding 'build/src.macosx-10.15-x86_64-3.9/build/src.macosx-10.15-x86_64-3.9/scipy/optimize/__nnls/fortranobject.c' to sources.
#     adding 'build/src.macosx-10.15-x86_64-3.9/build/src.macosx-10.15-x86_64-3.9/scipy/optimize/__nnls' to include_dirs.
#   building extension "scipy.optimize._group_columns" sources
#   building extension "scipy.optimize._bglu_dense" sources
#   building extension "scipy.optimize._lsq.givens_elimination" sources
#   building extension "scipy.optimize._trlib._trlib" sources
#   building extension "scipy.optimize.cython_optimize._zeros" sources
#   building extension "scipy.signal.sigtools" sources
#   building extension "scipy.signal._spectral" sources
#   building extension "scipy.signal._max_len_seq_inner" sources
#   building extension "scipy.signal._peak_finding_utils" sources
#   building extension "scipy.signal._sosfilt" sources
#   building extension "scipy.signal._upfirdn_apply" sources
#   building extension "scipy.signal.spline" sources
#   building extension "scipy.sparse.linalg.isolve._iterative" sources
#   f2py options: []
#     adding 'build/src.macosx-10.15-x86_64-3.9/build/src.macosx-10.15-x86_64-3.9/build/src.macosx-10.15-x86_64-3.9/scipy/sparse/linalg/isolve/iterative/fortranobject.c' to sources.
#     adding 'build/src.macosx-10.15-x86_64-3.9/build/src.macosx-10.15-x86_64-3.9/build/src.macosx-10.15-x86_64-3.9/scipy/sparse/linalg/isolve/iterative' to include_dirs.
#   building extension "scipy.sparse.linalg.dsolve._superlu" sources
#   building extension "scipy.sparse.linalg.eigen.arpack._arpack" sources
#   f2py options: []
#     adding 'build/src.macosx-10.15-x86_64-3.9/build/src.macosx-10.15-x86_64-3.9/build/src.macosx-10.15-x86_64-3.9/scipy/sparse/linalg/eigen/arpack/fortranobject.c' to sources.
#     adding 'build/src.macosx-10.15-x86_64-3.9/build/src.macosx-10.15-x86_64-3.9/build/src.macosx-10.15-x86_64-3.9/scipy/sparse/linalg/eigen/arpack' to include_dirs.
#     adding 'build/src.macosx-10.15-x86_64-3.9/build/src.macosx-10.15-x86_64-3.9/scipy/sparse/linalg/eigen/arpack/_arpack-f2pywrappers.f' to sources.
#   building extension "scipy.sparse.csgraph._shortest_path" sources
#   building extension "scipy.sparse.csgraph._traversal" sources
#   building extension "scipy.sparse.csgraph._min_spanning_tree" sources
#   building extension "scipy.sparse.csgraph._matching" sources
#   building extension "scipy.sparse.csgraph._flow" sources
#   building extension "scipy.sparse.csgraph._reordering" sources
#   building extension "scipy.sparse.csgraph._tools" sources
#   building extension "scipy.sparse._csparsetools" sources
#   building extension "scipy.sparse._sparsetools" sources
#   [generate_sparsetools] '/private/var/folders/5m/z78sg2m56qj87c1075qmwq780000gn/T/pip-install-j5ylw76p/scipy/scipy/sparse/sparsetools/bsr_impl.h' already up-to-date
#   [generate_sparsetools] '/private/var/folders/5m/z78sg2m56qj87c1075qmwq780000gn/T/pip-install-j5ylw76p/scipy/scipy/sparse/sparsetools/csr_impl.h' already up-to-date
#   [generate_sparsetools] '/private/var/folders/5m/z78sg2m56qj87c1075qmwq780000gn/T/pip-install-j5ylw76p/scipy/scipy/sparse/sparsetools/csc_impl.h' already up-to-date
#   [generate_sparsetools] '/private/var/folders/5m/z78sg2m56qj87c1075qmwq780000gn/T/pip-install-j5ylw76p/scipy/scipy/sparse/sparsetools/other_impl.h' already up-to-date
#   [generate_sparsetools] '/private/var/folders/5m/z78sg2m56qj87c1075qmwq780000gn/T/pip-install-j5ylw76p/scipy/scipy/sparse/sparsetools/sparsetools_impl.h' already up-to-date
#   building extension "scipy.spatial.qhull" sources
#   building extension "scipy.spatial.ckdtree" sources
#   building extension "scipy.spatial._distance_wrap" sources
#   building extension "scipy.spatial._voronoi" sources
#   building extension "scipy.spatial._hausdorff" sources
#   building extension "scipy.special.specfun" sources
#   f2py options: ['--no-wrap-functions']
#     adding 'build/src.macosx-10.15-x86_64-3.9/build/src.macosx-10.15-x86_64-3.9/scipy/special/fortranobject.c' to sources.
#     adding 'build/src.macosx-10.15-x86_64-3.9/build/src.macosx-10.15-x86_64-3.9/scipy/special' to include_dirs.
#   building extension "scipy.special._ufuncs" sources
#   building extension "scipy.special._ufuncs_cxx" sources
#   building extension "scipy.special._ellip_harm_2" sources
#   building extension "scipy.special.cython_special" sources
#   building extension "scipy.special._comb" sources
#   building extension "scipy.special._test_round" sources
#   building extension "scipy.stats.statlib" sources
#   f2py options: ['--no-wrap-functions']
#     adding 'build/src.macosx-10.15-x86_64-3.9/build/src.macosx-10.15-x86_64-3.9/scipy/stats/fortranobject.c' to sources.
#     adding 'build/src.macosx-10.15-x86_64-3.9/build/src.macosx-10.15-x86_64-3.9/scipy/stats' to include_dirs.
#   building extension "scipy.stats._stats" sources
#   building extension "scipy.stats.mvn" sources
#   f2py options: []
#     adding 'build/src.macosx-10.15-x86_64-3.9/build/src.macosx-10.15-x86_64-3.9/scipy/stats/fortranobject.c' to sources.
#     adding 'build/src.macosx-10.15-x86_64-3.9/build/src.macosx-10.15-x86_64-3.9/scipy/stats' to include_dirs.
#     adding 'build/src.macosx-10.15-x86_64-3.9/scipy/stats/mvn-f2pywrappers.f' to sources.
#   building extension "scipy.ndimage._nd_image" sources
#   building extension "scipy.ndimage._ni_label" sources
#   building extension "scipy.ndimage._ctest" sources
#   building extension "scipy.ndimage._ctest_oldapi" sources
#   building extension "scipy.ndimage._cytest" sources
#   building extension "scipy._lib._ccallback_c" sources
#   building extension "scipy._lib._test_ccallback" sources
#   building extension "scipy._lib._fpumode" sources
#   building extension "scipy._lib.messagestream" sources
#   get_default_fcompiler: matching types: '['gnu95', 'nag', 'absoft', 'ibm', 'intel', 'gnu', 'g95', 'pg']'
#   customize Gnu95FCompiler
#   Could not locate executable gfortran
#   Could not locate executable f95
#   customize NAGFCompiler
#   customize AbsoftFCompiler
#   Could not locate executable f90
#   Could not locate executable f77
#   customize IBMFCompiler
#   Could not locate executable xlf90
#   Could not locate executable xlf
#   customize IntelFCompiler
#   Could not locate executable ifort
#   Could not locate executable ifc
#   customize GnuFCompiler
#   Could not locate executable g77
#   customize G95FCompiler
#   Could not locate executable g95
#   customize PGroupFCompiler
#   Could not locate executable pgfortran
#   don't know how to compile Fortran code on platform 'posix'
#   C compiler: clang -Wno-unused-result -Wsign-compare -Wunreachable-code -fno-common -dynamic -DNDEBUG -g -fwrapv -O3 -Wall -isysroot /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk -I/Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include -I/Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/System/Library/Frameworks/Tk.framework/Versions/8.5/Headers
#
#   compile options: '-I/usr/local/include -I/usr/local/opt/openssl@1.1/include -I/usr/local/opt/sqlite/include -I/usr/local/Cellar/python@3.9/3.9.0_1/Frameworks/Python.framework/Versions/3.9/include/python3.9 -c'
#   clang: _configtest.c
#   clang _configtest.o -o _configtest
#   success!
#   removing: _configtest.c _configtest.o _configtest.o.d _configtest
#   building extension "scipy._lib._test_deprecation_call" sources
#   building extension "scipy._lib._test_deprecation_def" sources
#   building extension "scipy._lib._uarray._uarray" sources
#   building data_files sources
#   build_src: building npy-pkg config files
#   running build_py
#   creating build/lib.macosx-10.15-x86_64-3.9
#   creating build/lib.macosx-10.15-x86_64-3.9/scipy
#   copying scipy/conftest.py -> build/lib.macosx-10.15-x86_64-3.9/scipy
#   copying scipy/version.py -> build/lib.macosx-10.15-x86_64-3.9/scipy
#   copying scipy/__init__.py -> build/lib.macosx-10.15-x86_64-3.9/scipy
#   copying scipy/_distributor_init.py -> build/lib.macosx-10.15-x86_64-3.9/scipy
#   copying scipy/setup.py -> build/lib.macosx-10.15-x86_64-3.9/scipy
#   copying build/src.macosx-10.15-x86_64-3.9/scipy/__config__.py -> build/lib.macosx-10.15-x86_64-3.9/scipy
#   creating build/lib.macosx-10.15-x86_64-3.9/scipy/cluster
#   copying scipy/cluster/vq.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/cluster
#   copying scipy/cluster/__init__.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/cluster
#   copying scipy/cluster/hierarchy.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/cluster
#   copying scipy/cluster/setup.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/cluster
#   creating build/lib.macosx-10.15-x86_64-3.9/scipy/constants
#   copying scipy/constants/constants.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/constants
#   copying scipy/constants/__init__.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/constants
#   copying scipy/constants/codata.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/constants
#   copying scipy/constants/setup.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/constants
#   creating build/lib.macosx-10.15-x86_64-3.9/scipy/fft
#   copying scipy/fft/_backend.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/fft
#   copying scipy/fft/_helper.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/fft
#   copying scipy/fft/__init__.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/fft
#   copying scipy/fft/setup.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/fft
#   copying scipy/fft/_debug_backends.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/fft
#   copying scipy/fft/_realtransforms.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/fft
#   copying scipy/fft/_basic.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/fft
#   creating build/lib.macosx-10.15-x86_64-3.9/scipy/fft/_pocketfft
#   copying scipy/fft/_pocketfft/__init__.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/fft/_pocketfft
#   copying scipy/fft/_pocketfft/setup.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/fft/_pocketfft
#   copying scipy/fft/_pocketfft/realtransforms.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/fft/_pocketfft
#   copying scipy/fft/_pocketfft/basic.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/fft/_pocketfft
#   copying scipy/fft/_pocketfft/helper.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/fft/_pocketfft
#   creating build/lib.macosx-10.15-x86_64-3.9/scipy/fftpack
#   copying scipy/fftpack/__init__.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/fftpack
#   copying scipy/fftpack/pseudo_diffs.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/fftpack
#   copying scipy/fftpack/setup.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/fftpack
#   copying scipy/fftpack/realtransforms.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/fftpack
#   copying scipy/fftpack/basic.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/fftpack
#   copying scipy/fftpack/helper.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/fftpack
#   creating build/lib.macosx-10.15-x86_64-3.9/scipy/integrate
#   copying scipy/integrate/_ode.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/integrate
#   copying scipy/integrate/_quadrature.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/integrate
#   copying scipy/integrate/__init__.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/integrate
#   copying scipy/integrate/quadpack.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/integrate
#   copying scipy/integrate/_quad_vec.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/integrate
#   copying scipy/integrate/setup.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/integrate
#   copying scipy/integrate/_bvp.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/integrate
#   copying scipy/integrate/odepack.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/integrate
#   creating build/lib.macosx-10.15-x86_64-3.9/scipy/integrate/_ivp
#   copying scipy/integrate/_ivp/bdf.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/integrate/_ivp
#   copying scipy/integrate/_ivp/ivp.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/integrate/_ivp
#   copying scipy/integrate/_ivp/dop853_coefficients.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/integrate/_ivp
#   copying scipy/integrate/_ivp/__init__.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/integrate/_ivp
#   copying scipy/integrate/_ivp/setup.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/integrate/_ivp
#   copying scipy/integrate/_ivp/common.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/integrate/_ivp
#   copying scipy/integrate/_ivp/radau.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/integrate/_ivp
#   copying scipy/integrate/_ivp/lsoda.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/integrate/_ivp
#   copying scipy/integrate/_ivp/rk.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/integrate/_ivp
#   copying scipy/integrate/_ivp/base.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/integrate/_ivp
#   creating build/lib.macosx-10.15-x86_64-3.9/scipy/interpolate
#   copying scipy/interpolate/_cubic.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/interpolate
#   copying scipy/interpolate/polyint.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/interpolate
#   copying scipy/interpolate/ndgriddata.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/interpolate
#   copying scipy/interpolate/_bsplines.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/interpolate
#   copying scipy/interpolate/__init__.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/interpolate
#   copying scipy/interpolate/fitpack.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/interpolate
#   copying scipy/interpolate/rbf.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/interpolate
#   copying scipy/interpolate/interpnd_info.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/interpolate
#   copying scipy/interpolate/setup.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/interpolate
#   copying scipy/interpolate/_pade.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/interpolate
#   copying scipy/interpolate/interpolate.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/interpolate
#   copying scipy/interpolate/_fitpack_impl.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/interpolate
#   copying scipy/interpolate/fitpack2.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/interpolate
#   creating build/lib.macosx-10.15-x86_64-3.9/scipy/io
#   copying scipy/io/wavfile.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/io
#   copying scipy/io/idl.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/io
#   copying scipy/io/__init__.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/io
#   copying scipy/io/netcdf.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/io
#   copying scipy/io/setup.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/io
#   copying scipy/io/_fortran.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/io
#   copying scipy/io/mmio.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/io
#   creating build/lib.macosx-10.15-x86_64-3.9/scipy/io/matlab
#   copying scipy/io/matlab/miobase.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/io/matlab
#   copying scipy/io/matlab/mio5_params.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/io/matlab
#   copying scipy/io/matlab/__init__.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/io/matlab
#   copying scipy/io/matlab/setup.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/io/matlab
#   copying scipy/io/matlab/byteordercodes.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/io/matlab
#   copying scipy/io/matlab/mio.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/io/matlab
#   copying scipy/io/matlab/mio4.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/io/matlab
#   copying scipy/io/matlab/mio5.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/io/matlab
#   creating build/lib.macosx-10.15-x86_64-3.9/scipy/io/arff
#   copying scipy/io/arff/__init__.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/io/arff
#   copying scipy/io/arff/setup.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/io/arff
#   copying scipy/io/arff/arffread.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/io/arff
#   creating build/lib.macosx-10.15-x86_64-3.9/scipy/io/harwell_boeing
#   copying scipy/io/harwell_boeing/__init__.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/io/harwell_boeing
#   copying scipy/io/harwell_boeing/setup.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/io/harwell_boeing
#   copying scipy/io/harwell_boeing/_fortran_format_parser.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/io/harwell_boeing
#   copying scipy/io/harwell_boeing/hb.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/io/harwell_boeing
#   creating build/lib.macosx-10.15-x86_64-3.9/scipy/linalg
#   copying scipy/linalg/decomp_qr.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/linalg
#   copying scipy/linalg/_matfuncs_inv_ssq.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/linalg
#   copying scipy/linalg/misc.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/linalg
#   copying scipy/linalg/_sketches.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/linalg
#   copying scipy/linalg/decomp_cholesky.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/linalg
#   copying scipy/linalg/_testutils.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/linalg
#   copying scipy/linalg/decomp_lu.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/linalg
#   copying scipy/linalg/decomp_svd.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/linalg
#   copying scipy/linalg/_procrustes.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/linalg
#   copying scipy/linalg/_matfuncs_sqrtm.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/linalg
#   copying scipy/linalg/matfuncs.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/linalg
#   copying scipy/linalg/__init__.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/linalg
#   copying scipy/linalg/_generate_pyx.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/linalg
#   copying scipy/linalg/_solvers.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/linalg
#   copying scipy/linalg/_interpolative_backend.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/linalg
#   copying scipy/linalg/flinalg.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/linalg
#   copying scipy/linalg/setup.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/linalg
#   copying scipy/linalg/basic.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/linalg
#   copying scipy/linalg/_decomp_polar.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/linalg
#   copying scipy/linalg/decomp.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/linalg
#   copying scipy/linalg/interpolative.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/linalg
#   copying scipy/linalg/blas.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/linalg
#   copying scipy/linalg/_cython_signature_generator.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/linalg
#   copying scipy/linalg/special_matrices.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/linalg
#   copying scipy/linalg/_decomp_ldl.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/linalg
#   copying scipy/linalg/_decomp_cossin.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/linalg
#   copying scipy/linalg/decomp_schur.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/linalg
#   copying scipy/linalg/_decomp_qz.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/linalg
#   copying scipy/linalg/_expm_frechet.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/linalg
#   copying scipy/linalg/lapack.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/linalg
#   creating build/lib.macosx-10.15-x86_64-3.9/scipy/misc
#   copying scipy/misc/__init__.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/misc
#   copying scipy/misc/setup.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/misc
#   copying scipy/misc/common.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/misc
#   copying scipy/misc/doccer.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/misc
#   creating build/lib.macosx-10.15-x86_64-3.9/scipy/odr
#   copying scipy/odr/_add_newdocs.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/odr
#   copying scipy/odr/models.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/odr
#   copying scipy/odr/odrpack.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/odr
#   copying scipy/odr/__init__.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/odr
#   copying scipy/odr/setup.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/odr
#   creating build/lib.macosx-10.15-x86_64-3.9/scipy/optimize
#   copying scipy/optimize/tnc.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/optimize
#   copying scipy/optimize/_lsap.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/optimize
#   copying scipy/optimize/optimize.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/optimize
#   copying scipy/optimize/_linprog_ip.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/optimize
#   copying scipy/optimize/linesearch.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/optimize
#   copying scipy/optimize/nonlin.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/optimize
#   copying scipy/optimize/_linprog_rs.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/optimize
#   copying scipy/optimize/_root.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/optimize
#   copying scipy/optimize/lbfgsb.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/optimize
#   copying scipy/optimize/zeros.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/optimize
#   copying scipy/optimize/_shgo.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/optimize
#   copying scipy/optimize/_linprog_simplex.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/optimize
#   copying scipy/optimize/slsqp.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/optimize
#   copying scipy/optimize/_trustregion_ncg.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/optimize
#   copying scipy/optimize/_minimize.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/optimize
#   copying scipy/optimize/minpack.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/optimize
#   copying scipy/optimize/_basinhopping.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/optimize
#   copying scipy/optimize/_linprog.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/optimize
#   copying scipy/optimize/_hessian_update_strategy.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/optimize
#   copying scipy/optimize/__init__.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/optimize
#   copying scipy/optimize/cobyla.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/optimize
#   copying scipy/optimize/_tstutils.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/optimize
#   copying scipy/optimize/_nnls.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/optimize
#   copying scipy/optimize/_spectral.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/optimize
#   copying scipy/optimize/_differentiable_functions.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/optimize
#   copying scipy/optimize/_trustregion_krylov.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/optimize
#   copying scipy/optimize/_trustregion.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/optimize
#   copying scipy/optimize/setup.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/optimize
#   copying scipy/optimize/_linprog_util.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/optimize
#   copying scipy/optimize/_dual_annealing.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/optimize
#   copying scipy/optimize/_root_scalar.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/optimize
#   copying scipy/optimize/_trustregion_dogleg.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/optimize
#   copying scipy/optimize/_trustregion_exact.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/optimize
#   copying scipy/optimize/_constraints.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/optimize
#   copying scipy/optimize/_differentialevolution.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/optimize
#   copying scipy/optimize/_remove_redundancy.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/optimize
#   copying scipy/optimize/_numdiff.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/optimize
#   creating build/lib.macosx-10.15-x86_64-3.9/scipy/optimize/_lsq
#   copying scipy/optimize/_lsq/least_squares.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/optimize/_lsq
#   copying scipy/optimize/_lsq/dogbox.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/optimize/_lsq
#   copying scipy/optimize/_lsq/__init__.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/optimize/_lsq
#   copying scipy/optimize/_lsq/trf_linear.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/optimize/_lsq
#   copying scipy/optimize/_lsq/setup.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/optimize/_lsq
#   copying scipy/optimize/_lsq/common.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/optimize/_lsq
#   copying scipy/optimize/_lsq/lsq_linear.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/optimize/_lsq
#   copying scipy/optimize/_lsq/bvls.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/optimize/_lsq
#   copying scipy/optimize/_lsq/trf.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/optimize/_lsq
#   creating build/lib.macosx-10.15-x86_64-3.9/scipy/optimize/_trlib
#   copying scipy/optimize/_trlib/__init__.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/optimize/_trlib
#   copying scipy/optimize/_trlib/setup.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/optimize/_trlib
#   creating build/lib.macosx-10.15-x86_64-3.9/scipy/optimize/_trustregion_constr
#   copying scipy/optimize/_trustregion_constr/equality_constrained_sqp.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/optimize/_trustregion_constr
#   copying scipy/optimize/_trustregion_constr/__init__.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/optimize/_trustregion_constr
#   copying scipy/optimize/_trustregion_constr/setup.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/optimize/_trustregion_constr
#   copying scipy/optimize/_trustregion_constr/tr_interior_point.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/optimize/_trustregion_constr
#   copying scipy/optimize/_trustregion_constr/qp_subproblem.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/optimize/_trustregion_constr
#   copying scipy/optimize/_trustregion_constr/minimize_trustregion_constr.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/optimize/_trustregion_constr
#   copying scipy/optimize/_trustregion_constr/projections.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/optimize/_trustregion_constr
#   copying scipy/optimize/_trustregion_constr/report.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/optimize/_trustregion_constr
#   copying scipy/optimize/_trustregion_constr/canonical_constraint.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/optimize/_trustregion_constr
#   creating build/lib.macosx-10.15-x86_64-3.9/scipy/optimize/cython_optimize
#   copying scipy/optimize/cython_optimize/__init__.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/optimize/cython_optimize
#   creating build/lib.macosx-10.15-x86_64-3.9/scipy/optimize/_shgo_lib
#   copying scipy/optimize/_shgo_lib/__init__.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/optimize/_shgo_lib
#   copying scipy/optimize/_shgo_lib/sobol_seq.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/optimize/_shgo_lib
#   copying scipy/optimize/_shgo_lib/triangulation.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/optimize/_shgo_lib
#   creating build/lib.macosx-10.15-x86_64-3.9/scipy/signal
#   copying scipy/signal/waveforms.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/signal
#   copying scipy/signal/_savitzky_golay.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/signal
#   copying scipy/signal/signaltools.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/signal
#   copying scipy/signal/bsplines.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/signal
#   copying scipy/signal/__init__.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/signal
#   copying scipy/signal/_arraytools.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/signal
#   copying scipy/signal/_max_len_seq.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/signal
#   copying scipy/signal/wavelets.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/signal
#   copying scipy/signal/lti_conversion.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/signal
#   copying scipy/signal/setup.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/signal
#   copying scipy/signal/_peak_finding.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/signal
#   copying scipy/signal/filter_design.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/signal
#   copying scipy/signal/spectral.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/signal
#   copying scipy/signal/_upfirdn.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/signal
#   copying scipy/signal/ltisys.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/signal
#   copying scipy/signal/fir_filter_design.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/signal
#   creating build/lib.macosx-10.15-x86_64-3.9/scipy/signal/windows
#   copying scipy/signal/windows/__init__.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/signal/windows
#   copying scipy/signal/windows/setup.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/signal/windows
#   copying scipy/signal/windows/windows.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/signal/windows
#   creating build/lib.macosx-10.15-x86_64-3.9/scipy/sparse
#   copying scipy/sparse/csc.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/sparse
#   copying scipy/sparse/generate_sparsetools.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/sparse
#   copying scipy/sparse/sparsetools.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/sparse
#   copying scipy/sparse/dok.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/sparse
#   copying scipy/sparse/coo.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/sparse
#   copying scipy/sparse/compressed.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/sparse
#   copying scipy/sparse/dia.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/sparse
#   copying scipy/sparse/_index.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/sparse
#   copying scipy/sparse/spfuncs.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/sparse
#   copying scipy/sparse/__init__.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/sparse
#   copying scipy/sparse/lil.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/sparse
#   copying scipy/sparse/sputils.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/sparse
#   copying scipy/sparse/bsr.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/sparse
#   copying scipy/sparse/setup.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/sparse
#   copying scipy/sparse/_matrix_io.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/sparse
#   copying scipy/sparse/csr.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/sparse
#   copying scipy/sparse/construct.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/sparse
#   copying scipy/sparse/extract.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/sparse
#   copying scipy/sparse/base.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/sparse
#   copying scipy/sparse/data.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/sparse
#   creating build/lib.macosx-10.15-x86_64-3.9/scipy/sparse/linalg
#   copying scipy/sparse/linalg/matfuncs.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/sparse/linalg
#   copying scipy/sparse/linalg/interface.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/sparse/linalg
#   copying scipy/sparse/linalg/_expm_multiply.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/sparse/linalg
#   copying scipy/sparse/linalg/__init__.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/sparse/linalg
#   copying scipy/sparse/linalg/setup.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/sparse/linalg
#   copying scipy/sparse/linalg/_norm.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/sparse/linalg
#   copying scipy/sparse/linalg/_onenormest.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/sparse/linalg
#   creating build/lib.macosx-10.15-x86_64-3.9/scipy/sparse/linalg/isolve
#   copying scipy/sparse/linalg/isolve/lsqr.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/sparse/linalg/isolve
#   copying scipy/sparse/linalg/isolve/__init__.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/sparse/linalg/isolve
#   copying scipy/sparse/linalg/isolve/setup.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/sparse/linalg/isolve
#   copying scipy/sparse/linalg/isolve/iterative.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/sparse/linalg/isolve
#   copying scipy/sparse/linalg/isolve/utils.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/sparse/linalg/isolve
#   copying scipy/sparse/linalg/isolve/_gcrotmk.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/sparse/linalg/isolve
#   copying scipy/sparse/linalg/isolve/minres.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/sparse/linalg/isolve
#   copying scipy/sparse/linalg/isolve/lsmr.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/sparse/linalg/isolve
#   copying scipy/sparse/linalg/isolve/lgmres.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/sparse/linalg/isolve
#   creating build/lib.macosx-10.15-x86_64-3.9/scipy/sparse/linalg/dsolve
#   copying scipy/sparse/linalg/dsolve/_add_newdocs.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/sparse/linalg/dsolve
#   copying scipy/sparse/linalg/dsolve/linsolve.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/sparse/linalg/dsolve
#   copying scipy/sparse/linalg/dsolve/__init__.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/sparse/linalg/dsolve
#   copying scipy/sparse/linalg/dsolve/setup.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/sparse/linalg/dsolve
#   creating build/lib.macosx-10.15-x86_64-3.9/scipy/sparse/linalg/eigen
#   copying scipy/sparse/linalg/eigen/__init__.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/sparse/linalg/eigen
#   copying scipy/sparse/linalg/eigen/setup.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/sparse/linalg/eigen
#   creating build/lib.macosx-10.15-x86_64-3.9/scipy/sparse/linalg/eigen/arpack
#   copying scipy/sparse/linalg/eigen/arpack/__init__.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/sparse/linalg/eigen/arpack
#   copying scipy/sparse/linalg/eigen/arpack/setup.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/sparse/linalg/eigen/arpack
#   copying scipy/sparse/linalg/eigen/arpack/arpack.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/sparse/linalg/eigen/arpack
#   creating build/lib.macosx-10.15-x86_64-3.9/scipy/sparse/linalg/eigen/lobpcg
#   copying scipy/sparse/linalg/eigen/lobpcg/lobpcg.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/sparse/linalg/eigen/lobpcg
#   copying scipy/sparse/linalg/eigen/lobpcg/__init__.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/sparse/linalg/eigen/lobpcg
#   copying scipy/sparse/linalg/eigen/lobpcg/setup.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/sparse/linalg/eigen/lobpcg
#   creating build/lib.macosx-10.15-x86_64-3.9/scipy/sparse/csgraph
#   copying scipy/sparse/csgraph/_laplacian.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/sparse/csgraph
#   copying scipy/sparse/csgraph/__init__.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/sparse/csgraph
#   copying scipy/sparse/csgraph/setup.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/sparse/csgraph
#   copying scipy/sparse/csgraph/_validation.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/sparse/csgraph
#   creating build/lib.macosx-10.15-x86_64-3.9/scipy/spatial
#   copying scipy/spatial/_spherical_voronoi.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/spatial
#   copying scipy/spatial/_procrustes.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/spatial
#   copying scipy/spatial/__init__.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/spatial
#   copying scipy/spatial/distance.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/spatial
#   copying scipy/spatial/kdtree.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/spatial
#   copying scipy/spatial/setup.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/spatial
#   copying scipy/spatial/_geometric_slerp.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/spatial
#   copying scipy/spatial/_plotutils.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/spatial
#   creating build/lib.macosx-10.15-x86_64-3.9/scipy/spatial/transform
#   copying scipy/spatial/transform/__init__.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/spatial/transform
#   copying scipy/spatial/transform/setup.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/spatial/transform
#   copying scipy/spatial/transform/_rotation_spline.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/spatial/transform
#   copying scipy/spatial/transform/rotation.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/spatial/transform
#   copying scipy/spatial/transform/_rotation_groups.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/spatial/transform
#   creating build/lib.macosx-10.15-x86_64-3.9/scipy/special
#   copying scipy/special/spfun_stats.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/special
#   copying scipy/special/_testutils.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/special
#   copying scipy/special/sf_error.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/special
#   copying scipy/special/add_newdocs.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/special
#   copying scipy/special/_spherical_bessel.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/special
#   copying scipy/special/_mptestutils.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/special
#   copying scipy/special/__init__.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/special
#   copying scipy/special/_ellip_harm.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/special
#   copying scipy/special/_generate_pyx.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/special
#   copying scipy/special/setup.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/special
#   copying scipy/special/_lambertw.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/special
#   copying scipy/special/basic.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/special
#   copying scipy/special/orthogonal.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/special
#   copying scipy/special/_basic.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/special
#   copying scipy/special/_logsumexp.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/special
#   creating build/lib.macosx-10.15-x86_64-3.9/scipy/special/_precompute
#   copying scipy/special/_precompute/expn_asy.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/special/_precompute
#   copying scipy/special/_precompute/zetac.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/special/_precompute
#   copying scipy/special/_precompute/struve_convergence.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/special/_precompute
#   copying scipy/special/_precompute/loggamma.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/special/_precompute
#   copying scipy/special/_precompute/gammainc_asy.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/special/_precompute
#   copying scipy/special/_precompute/wrightomega.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/special/_precompute
#   copying scipy/special/_precompute/gammainc_data.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/special/_precompute
#   copying scipy/special/_precompute/__init__.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/special/_precompute
#   copying scipy/special/_precompute/setup.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/special/_precompute
#   copying scipy/special/_precompute/utils.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/special/_precompute
#   copying scipy/special/_precompute/lambertw.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/special/_precompute
#   creating build/lib.macosx-10.15-x86_64-3.9/scipy/stats
#   copying scipy/stats/_multivariate.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/stats
#   copying scipy/stats/_constants.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/stats
#   copying scipy/stats/_binned_statistic.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/stats
#   copying scipy/stats/_distr_params.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/stats
#   copying scipy/stats/_tukeylambda_stats.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/stats
#   copying scipy/stats/_rvs_sampling.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/stats
#   copying scipy/stats/_stats_mstats_common.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/stats
#   copying scipy/stats/_ksstats.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/stats
#   copying scipy/stats/kde.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/stats
#   copying scipy/stats/__init__.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/stats
#   copying scipy/stats/mstats_extras.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/stats
#   copying scipy/stats/_discrete_distns.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/stats
#   copying scipy/stats/distributions.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/stats
#   copying scipy/stats/_hypotests.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/stats
#   copying scipy/stats/setup.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/stats
#   copying scipy/stats/mstats.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/stats
#   copying scipy/stats/_distn_infrastructure.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/stats
#   copying scipy/stats/stats.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/stats
#   copying scipy/stats/_continuous_distns.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/stats
#   copying scipy/stats/morestats.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/stats
#   copying scipy/stats/mstats_basic.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/stats
#   copying scipy/stats/contingency.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/stats
#   copying scipy/stats/_wilcoxon_data.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/stats
#   creating build/lib.macosx-10.15-x86_64-3.9/scipy/ndimage
#   copying scipy/ndimage/_ni_support.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/ndimage
#   copying scipy/ndimage/interpolation.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/ndimage
#   copying scipy/ndimage/_ni_docstrings.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/ndimage
#   copying scipy/ndimage/__init__.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/ndimage
#   copying scipy/ndimage/morphology.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/ndimage
#   copying scipy/ndimage/setup.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/ndimage
#   copying scipy/ndimage/fourier.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/ndimage
#   copying scipy/ndimage/filters.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/ndimage
#   copying scipy/ndimage/measurements.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/ndimage
#   creating build/lib.macosx-10.15-x86_64-3.9/scipy/_build_utils
#   copying scipy/_build_utils/system_info.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/_build_utils
#   copying scipy/_build_utils/__init__.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/_build_utils
#   copying scipy/_build_utils/setup.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/_build_utils
#   copying scipy/_build_utils/_fortran.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/_build_utils
#   copying scipy/_build_utils/compiler_helper.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/_build_utils
#   creating build/lib.macosx-10.15-x86_64-3.9/scipy/_lib
#   copying scipy/_lib/uarray.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/_lib
#   copying scipy/_lib/_testutils.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/_lib
#   copying scipy/_lib/_pep440.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/_lib
#   copying scipy/_lib/deprecation.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/_lib
#   copying scipy/_lib/decorator.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/_lib
#   copying scipy/_lib/__init__.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/_lib
#   copying scipy/_lib/_ccallback.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/_lib
#   copying scipy/_lib/_threadsafety.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/_lib
#   copying scipy/_lib/setup.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/_lib
#   copying scipy/_lib/_tmpdirs.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/_lib
#   copying scipy/_lib/_util.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/_lib
#   copying scipy/_lib/_gcutils.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/_lib
#   copying scipy/_lib/doccer.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/_lib
#   creating build/lib.macosx-10.15-x86_64-3.9/scipy/_lib/_uarray
#   copying scipy/_lib/_uarray/_backend.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/_lib/_uarray
#   copying scipy/_lib/_uarray/__init__.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/_lib/_uarray
#   copying scipy/_lib/_uarray/setup.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/_lib/_uarray
#   running build_clib
#   customize UnixCCompiler
#   #### ['clang', '-Wno-unused-result', '-Wsign-compare', '-Wunreachable-code', '-fno-common', '-dynamic', '-DNDEBUG', '-g', '-fwrapv', '-O3', '-Wall', '-isysroot', '/Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk', '-I/Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include', '-I/Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/System/Library/Frameworks/Tk.framework/Versions/8.5/Headers'] #######
#   customize UnixCCompiler using build_clib
#   building 'mach' library
#   error: library mach has Fortran sources but no Fortran compiler found
#   ----------------------------------------
#   ERROR: Failed building wheel for scipy
# Failed to build scipy
# ERROR: Could not build wheels for scipy which use PEP 517 and cannot be installed directly

# %%
# !pip3 install imbalanced-learn
# Out:
# Collecting imbalanced-learn
#   Using cached imbalanced_learn-0.7.0-py3-none-any.whl (167 kB)
# Collecting scipy>=0.19.1
#   Using cached scipy-1.5.3.tar.gz (25.2 MB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# Collecting scikit-learn>=0.23
#   Using cached scikit-learn-0.23.2.tar.gz (7.2 MB)
#   Installing build dependencies ... error
#   ERROR: Command errored out with exit status 1:
#    command: /usr/local/opt/python@3.9/bin/python3.9 /usr/local/lib/python3.9/site-packages/pip install --ignore-installed --no-user --prefix /private/var/folders/5m/z78sg2m56qj87c1075qmwq780000gn/T/pip-build-env-aobb9s1a/overlay --no-warn-script-location --no-binary :none: --only-binary :none: -i https://pypi.org/simple -- setuptools wheel 'Cython>=0.28.5' 'numpy==1.13.3; python_version=='"'"'3.6'"'"' and platform_system!='"'"'AIX'"'"' and platform_python_implementation == '"'"'CPython'"'"'' 'numpy==1.14.0; python_version=='"'"'3.6'"'"' and platform_system!='"'"'AIX'"'"' and platform_python_implementation != '"'"'CPython'"'"'' 'numpy==1.14.5; python_version=='"'"'3.7'"'"' and platform_system!='"'"'AIX'"'"'' 'numpy==1.17.3; python_version>='"'"'3.8'"'"' and platform_system!='"'"'AIX'"'"'' 'numpy==1.16.0; python_version=='"'"'3.6'"'"' and platform_system=='"'"'AIX'"'"'' 'numpy==1.16.0; python_version=='"'"'3.7'"'"' and platform_system=='"'"'AIX'"'"'' 'numpy==1.17.3; python_version>='"'"'3.8'"'"' and platform_system=='"'"'AIX'"'"'' 'scipy>=0.19.1'
#        cwd: None
#   Complete output (842 lines):
#   Ignoring numpy: markers 'python_version == "3.6" and platform_system != "AIX" and platform_python_implementation == "CPython"' don't match your environment
#   Ignoring numpy: markers 'python_version == "3.6" and platform_system != "AIX" and platform_python_implementation != "CPython"' don't match your environment
#   Ignoring numpy: markers 'python_version == "3.7" and platform_system != "AIX"' don't match your environment
#   Ignoring numpy: markers 'python_version == "3.6" and platform_system == "AIX"' don't match your environment
#   Ignoring numpy: markers 'python_version == "3.7" and platform_system == "AIX"' don't match your environment
#   Ignoring numpy: markers 'python_version >= "3.8" and platform_system == "AIX"' don't match your environment
#   Collecting setuptools
#     Using cached setuptools-50.3.2-py3-none-any.whl (785 kB)
#   Collecting wheel
#     Using cached wheel-0.35.1-py2.py3-none-any.whl (33 kB)
#   Collecting Cython>=0.28.5
#     Using cached Cython-0.29.21-py2.py3-none-any.whl (974 kB)
#   Processing /Users/thomaschenu/Library/Caches/pip/wheels/88/21/07/12b17bd52e2030a53d9757e9d65610e73d4075ee2d7c456d70/numpy-1.17.3-cp39-cp39-macosx_10_15_x86_64.whl
#   Collecting scipy>=0.19.1
#     Using cached scipy-1.5.3.tar.gz (25.2 MB)
#     Installing build dependencies: started
#     Installing build dependencies: finished with status 'done'
#     Getting requirements to build wheel: started
#     Getting requirements to build wheel: finished with status 'done'
#       Preparing wheel metadata: started
#       Preparing wheel metadata: finished with status 'done'
#   Building wheels for collected packages: scipy
#     Building wheel for scipy (PEP 517): started
#     Building wheel for scipy (PEP 517): finished with status 'error'
#     ERROR: Command errored out with exit status 1:
#      command: /usr/local/opt/python@3.9/bin/python3.9 /usr/local/lib/python3.9/site-packages/pip/_vendor/pep517/_in_process.py build_wheel /var/folders/5m/z78sg2m56qj87c1075qmwq780000gn/T/tmp7q5gm4bh
#          cwd: /private/var/folders/5m/z78sg2m56qj87c1075qmwq780000gn/T/pip-install-awo43y9a/scipy
#     Complete output (810 lines):
#     Running from SciPy source directory.
#     lapack_opt_info:
#     lapack_mkl_info:
#     customize UnixCCompiler
#       libraries mkl_rt not found in ['/usr/local/Cellar/python@3.9/3.9.0_1/Frameworks/Python.framework/Versions/3.9/lib', '/usr/local/lib', '/usr/lib']
#       NOT AVAILABLE
#
#     openblas_lapack_info:
#     customize UnixCCompiler
#     customize UnixCCompiler
#       libraries openblas not found in ['/usr/local/Cellar/python@3.9/3.9.0_1/Frameworks/Python.framework/Versions/3.9/lib', '/usr/local/lib', '/usr/lib']
#       NOT AVAILABLE
#
#     openblas_clapack_info:
#     customize UnixCCompiler
#     customize UnixCCompiler
#       libraries openblas,lapack not found in ['/usr/local/Cellar/python@3.9/3.9.0_1/Frameworks/Python.framework/Versions/3.9/lib', '/usr/local/lib', '/usr/lib']
#       NOT AVAILABLE
#
#     flame_info:
#     customize UnixCCompiler
#       libraries flame not found in ['/usr/local/Cellar/python@3.9/3.9.0_1/Frameworks/Python.framework/Versions/3.9/lib', '/usr/local/lib', '/usr/lib']
#       NOT AVAILABLE
#
#     atlas_3_10_threads_info:
#     Setting PTATLAS=ATLAS
#     customize UnixCCompiler
#       libraries lapack_atlas not found in /usr/local/Cellar/python@3.9/3.9.0_1/Frameworks/Python.framework/Versions/3.9/lib
#     customize UnixCCompiler
#       libraries tatlas,tatlas not found in /usr/local/Cellar/python@3.9/3.9.0_1/Frameworks/Python.framework/Versions/3.9/lib
#     customize UnixCCompiler
#       libraries lapack_atlas not found in /usr/local/lib
#     customize UnixCCompiler
#       libraries tatlas,tatlas not found in /usr/local/lib
#     customize UnixCCompiler
#       libraries lapack_atlas not found in /usr/lib
#     customize UnixCCompiler
#       libraries tatlas,tatlas not found in /usr/lib
#     <class 'numpy.distutils.system_info.atlas_3_10_threads_info'>
#       NOT AVAILABLE
#
#     atlas_3_10_info:
#     customize UnixCCompiler
#       libraries lapack_atlas not found in /usr/local/Cellar/python@3.9/3.9.0_1/Frameworks/Python.framework/Versions/3.9/lib
#     customize UnixCCompiler
#       libraries satlas,satlas not found in /usr/local/Cellar/python@3.9/3.9.0_1/Frameworks/Python.framework/Versions/3.9/lib
#     customize UnixCCompiler
#       libraries lapack_atlas not found in /usr/local/lib
#     customize UnixCCompiler
#       libraries satlas,satlas not found in /usr/local/lib
#     customize UnixCCompiler
#       libraries lapack_atlas not found in /usr/lib
#     customize UnixCCompiler
#       libraries satlas,satlas not found in /usr/lib
#     <class 'numpy.distutils.system_info.atlas_3_10_info'>
#       NOT AVAILABLE
#
#     atlas_threads_info:
#     Setting PTATLAS=ATLAS
#     customize UnixCCompiler
#       libraries lapack_atlas not found in /usr/local/Cellar/python@3.9/3.9.0_1/Frameworks/Python.framework/Versions/3.9/lib
#     customize UnixCCompiler
#       libraries ptf77blas,ptcblas,atlas not found in /usr/local/Cellar/python@3.9/3.9.0_1/Frameworks/Python.framework/Versions/3.9/lib
#     customize UnixCCompiler
#       libraries lapack_atlas not found in /usr/local/lib
#     customize UnixCCompiler
#       libraries ptf77blas,ptcblas,atlas not found in /usr/local/lib
#     customize UnixCCompiler
#       libraries lapack_atlas not found in /usr/lib
#     customize UnixCCompiler
#       libraries ptf77blas,ptcblas,atlas not found in /usr/lib
#     <class 'numpy.distutils.system_info.atlas_threads_info'>
#       NOT AVAILABLE
#
#     atlas_info:
#     customize UnixCCompiler
#       libraries lapack_atlas not found in /usr/local/Cellar/python@3.9/3.9.0_1/Frameworks/Python.framework/Versions/3.9/lib
#     customize UnixCCompiler
#       libraries f77blas,cblas,atlas not found in /usr/local/Cellar/python@3.9/3.9.0_1/Frameworks/Python.framework/Versions/3.9/lib
#     customize UnixCCompiler
#       libraries lapack_atlas not found in /usr/local/lib
#     customize UnixCCompiler
#       libraries f77blas,cblas,atlas not found in /usr/local/lib
#     customize UnixCCompiler
#       libraries lapack_atlas not found in /usr/lib
#     customize UnixCCompiler
#       libraries f77blas,cblas,atlas not found in /usr/lib
#     <class 'numpy.distutils.system_info.atlas_info'>
#       NOT AVAILABLE
#
#     accelerate_info:
#       NOT AVAILABLE
#
#     lapack_info:
#     customize UnixCCompiler
#     customize UnixCCompiler
#       FOUND:
#         libraries = ['lapack', 'lapack']
#         library_dirs = ['/usr/lib']
#         language = f77
#
#     blas_opt_info:
#     blas_mkl_info:
#     customize UnixCCompiler
#       libraries mkl_rt not found in ['/usr/local/Cellar/python@3.9/3.9.0_1/Frameworks/Python.framework/Versions/3.9/lib', '/usr/local/lib', '/usr/lib']
#       NOT AVAILABLE
#
#     blis_info:
#     customize UnixCCompiler
#       libraries blis not found in ['/usr/local/Cellar/python@3.9/3.9.0_1/Frameworks/Python.framework/Versions/3.9/lib', '/usr/local/lib', '/usr/lib']
#       NOT AVAILABLE
#
#     openblas_info:
#     customize UnixCCompiler
#     customize UnixCCompiler
#       libraries openblas not found in ['/usr/local/Cellar/python@3.9/3.9.0_1/Frameworks/Python.framework/Versions/3.9/lib', '/usr/local/lib', '/usr/lib']
#       NOT AVAILABLE
#
#     atlas_3_10_blas_threads_info:
#     Setting PTATLAS=ATLAS
#     customize UnixCCompiler
#       libraries tatlas not found in ['/usr/local/Cellar/python@3.9/3.9.0_1/Frameworks/Python.framework/Versions/3.9/lib', '/usr/local/lib', '/usr/lib']
#       NOT AVAILABLE
#
#     atlas_3_10_blas_info:
#     customize UnixCCompiler
#       libraries satlas not found in ['/usr/local/Cellar/python@3.9/3.9.0_1/Frameworks/Python.framework/Versions/3.9/lib', '/usr/local/lib', '/usr/lib']
#       NOT AVAILABLE
#
#     atlas_blas_threads_info:
#     Setting PTATLAS=ATLAS
#     customize UnixCCompiler
#       libraries ptf77blas,ptcblas,atlas not found in ['/usr/local/Cellar/python@3.9/3.9.0_1/Frameworks/Python.framework/Versions/3.9/lib', '/usr/local/lib', '/usr/lib']
#       NOT AVAILABLE
#
#     atlas_blas_info:
#     customize UnixCCompiler
#       libraries f77blas,cblas,atlas not found in ['/usr/local/Cellar/python@3.9/3.9.0_1/Frameworks/Python.framework/Versions/3.9/lib', '/usr/local/lib', '/usr/lib']
#       NOT AVAILABLE
#
#     /private/var/folders/5m/z78sg2m56qj87c1075qmwq780000gn/T/pip-build-env-g35wg5hz/overlay/lib/python3.9/site-packages/numpy/distutils/system_info.py:690: UserWarning:
#         Optimized (vendor) Blas libraries are not found.
#         Falls back to netlib Blas library which has worse performance.
#         A better performance should be easily gained by switching
#         Blas library.
#       self.calc_info()
#     blas_info:
#     customize UnixCCompiler
#     customize UnixCCompiler
#     C compiler: clang -Wno-unused-result -Wsign-compare -Wunreachable-code -fno-common -dynamic -DNDEBUG -g -fwrapv -O3 -Wall -isysroot /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk -I/Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include -I/Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/System/Library/Frameworks/Tk.framework/Versions/8.5/Headers
#
#     creating /var/folders/5m/z78sg2m56qj87c1075qmwq780000gn/T/tmpx3ucim3_/var
#     creating /var/folders/5m/z78sg2m56qj87c1075qmwq780000gn/T/tmpx3ucim3_/var/folders
#     creating /var/folders/5m/z78sg2m56qj87c1075qmwq780000gn/T/tmpx3ucim3_/var/folders/5m
#     creating /var/folders/5m/z78sg2m56qj87c1075qmwq780000gn/T/tmpx3ucim3_/var/folders/5m/z78sg2m56qj87c1075qmwq780000gn
#     creating /var/folders/5m/z78sg2m56qj87c1075qmwq780000gn/T/tmpx3ucim3_/var/folders/5m/z78sg2m56qj87c1075qmwq780000gn/T
#     creating /var/folders/5m/z78sg2m56qj87c1075qmwq780000gn/T/tmpx3ucim3_/var/folders/5m/z78sg2m56qj87c1075qmwq780000gn/T/tmpx3ucim3_
#     compile options: '-I/usr/local/include -I/usr/local/Cellar/python@3.9/3.9.0_1/Frameworks/Python.framework/Versions/3.9/include -c'
#     clang: /var/folders/5m/z78sg2m56qj87c1075qmwq780000gn/T/tmpx3ucim3_/source.c
#     /var/folders/5m/z78sg2m56qj87c1075qmwq780000gn/T/tmpx3ucim3_/source.c:1:10: fatal error: 'cblas.h' file not found
#     #include <cblas.h>
#              ^~~~~~~~~
#     1 error generated.
#     customize UnixCCompiler
#       FOUND:
#         libraries = ['blas', 'blas']
#         library_dirs = ['/usr/lib']
#         include_dirs = ['/usr/local/include', '/usr/local/Cellar/python@3.9/3.9.0_1/Frameworks/Python.framework/Versions/3.9/include']
#
#       FOUND:
#         define_macros = [('NO_ATLAS_INFO', 1)]
#         libraries = ['blas', 'blas']
#         library_dirs = ['/usr/lib']
#         include_dirs = ['/usr/local/include', '/usr/local/Cellar/python@3.9/3.9.0_1/Frameworks/Python.framework/Versions/3.9/include']
#
#       FOUND:
#         libraries = ['lapack', 'lapack', 'blas', 'blas']
#         library_dirs = ['/usr/lib']
#         language = f77
#         define_macros = [('NO_ATLAS_INFO', 1)]
#         include_dirs = ['/usr/local/include', '/usr/local/Cellar/python@3.9/3.9.0_1/Frameworks/Python.framework/Versions/3.9/include']
#
#     /private/var/folders/5m/z78sg2m56qj87c1075qmwq780000gn/T/pip-build-env-g35wg5hz/overlay/lib/python3.9/site-packages/numpy/distutils/system_info.py:782: UserWarning: Specified path /private/var/folders/5m/z78sg2m56qj87c1075qmwq780000gn/T/pip-build-env-g35wg5hz/overlay/include/python3.9 is invalid.
#       return self.get_paths(self.section, key)
#     /private/var/folders/5m/z78sg2m56qj87c1075qmwq780000gn/T/pip-build-env-g35wg5hz/overlay/lib/python3.9/site-packages/numpy/distutils/system_info.py:782: UserWarning: Specified path /usr/local/include/python3.9 is invalid.
#       return self.get_paths(self.section, key)
#     [makenpz] scipy/special/tests/data/boost.npz not rebuilt
#     [makenpz] scipy/special/tests/data/gsl.npz not rebuilt
#     [makenpz] scipy/special/tests/data/local.npz not rebuilt
#     non-existing path in 'scipy/signal/windows': 'tests'
#     running bdist_wheel
#     running build
#     running config_cc
#     unifing config_cc, config, build_clib, build_ext, build commands --compiler options
#     running config_fc
#     unifing config_fc, config, build_clib, build_ext, build commands --fcompiler options
#     running build_src
#     build_src
#     building py_modules sources
#     building library "mach" sources
#     building library "quadpack" sources
#     building library "lsoda" sources
#     building library "vode" sources
#     building library "dop" sources
#     building library "fitpack" sources
#     building library "fwrappers" sources
#     building library "odrpack" sources
#     building library "minpack" sources
#     building library "rectangular_lsap" sources
#     building library "rootfind" sources
#     building library "superlu_src" sources
#     building library "arpack_scipy" sources
#     building library "sc_cephes" sources
#     building library "sc_mach" sources
#     building library "sc_amos" sources
#     building library "sc_cdf" sources
#     building library "sc_specfun" sources
#     building library "statlib" sources
#     building extension "scipy.cluster._vq" sources
#     building extension "scipy.cluster._hierarchy" sources
#     building extension "scipy.cluster._optimal_leaf_ordering" sources
#     building extension "scipy.fft._pocketfft.pypocketfft" sources
#     building extension "scipy.fftpack.convolve" sources
#     building extension "scipy.integrate._quadpack" sources
#     building extension "scipy.integrate._odepack" sources
#     building extension "scipy.integrate.vode" sources
#     f2py options: []
#       adding 'build/src.macosx-10.15-x86_64-3.9/build/src.macosx-10.15-x86_64-3.9/scipy/integrate/fortranobject.c' to sources.
#       adding 'build/src.macosx-10.15-x86_64-3.9/build/src.macosx-10.15-x86_64-3.9/scipy/integrate' to include_dirs.
#       adding 'build/src.macosx-10.15-x86_64-3.9/scipy/integrate/vode-f2pywrappers.f' to sources.
#     building extension "scipy.integrate.lsoda" sources
#     f2py options: []
#       adding 'build/src.macosx-10.15-x86_64-3.9/build/src.macosx-10.15-x86_64-3.9/scipy/integrate/fortranobject.c' to sources.
#       adding 'build/src.macosx-10.15-x86_64-3.9/build/src.macosx-10.15-x86_64-3.9/scipy/integrate' to include_dirs.
#       adding 'build/src.macosx-10.15-x86_64-3.9/scipy/integrate/lsoda-f2pywrappers.f' to sources.
#     building extension "scipy.integrate._dop" sources
#     f2py options: []
#       adding 'build/src.macosx-10.15-x86_64-3.9/build/src.macosx-10.15-x86_64-3.9/scipy/integrate/fortranobject.c' to sources.
#       adding 'build/src.macosx-10.15-x86_64-3.9/build/src.macosx-10.15-x86_64-3.9/scipy/integrate' to include_dirs.
#       adding 'build/src.macosx-10.15-x86_64-3.9/scipy/integrate/_dop-f2pywrappers.f' to sources.
#     building extension "scipy.integrate._test_multivariate" sources
#     building extension "scipy.integrate._test_odeint_banded" sources
#     f2py options: []
#       adding 'build/src.macosx-10.15-x86_64-3.9/build/src.macosx-10.15-x86_64-3.9/scipy/integrate/fortranobject.c' to sources.
#       adding 'build/src.macosx-10.15-x86_64-3.9/build/src.macosx-10.15-x86_64-3.9/scipy/integrate' to include_dirs.
#       adding 'build/src.macosx-10.15-x86_64-3.9/scipy/integrate/_test_odeint_banded-f2pywrappers.f' to sources.
#     building extension "scipy.interpolate.interpnd" sources
#     building extension "scipy.interpolate._ppoly" sources
#     building extension "scipy.interpolate._bspl" sources
#     building extension "scipy.interpolate._fitpack" sources
#     building extension "scipy.interpolate.dfitpack" sources
#     f2py options: []
#       adding 'build/src.macosx-10.15-x86_64-3.9/build/src.macosx-10.15-x86_64-3.9/scipy/interpolate/src/fortranobject.c' to sources.
#       adding 'build/src.macosx-10.15-x86_64-3.9/build/src.macosx-10.15-x86_64-3.9/scipy/interpolate/src' to include_dirs.
#       adding 'build/src.macosx-10.15-x86_64-3.9/scipy/interpolate/src/dfitpack-f2pywrappers.f' to sources.
#     building extension "scipy.io._test_fortran" sources
#     f2py options: []
#       adding 'build/src.macosx-10.15-x86_64-3.9/build/src.macosx-10.15-x86_64-3.9/scipy/io/fortranobject.c' to sources.
#       adding 'build/src.macosx-10.15-x86_64-3.9/build/src.macosx-10.15-x86_64-3.9/scipy/io' to include_dirs.
#     building extension "scipy.io.matlab.streams" sources
#     building extension "scipy.io.matlab.mio_utils" sources
#     building extension "scipy.io.matlab.mio5_utils" sources
#     building extension "scipy.linalg._fblas" sources
#     f2py options: []
#       adding 'build/src.macosx-10.15-x86_64-3.9/build/src.macosx-10.15-x86_64-3.9/build/src.macosx-10.15-x86_64-3.9/scipy/linalg/fortranobject.c' to sources.
#       adding 'build/src.macosx-10.15-x86_64-3.9/build/src.macosx-10.15-x86_64-3.9/build/src.macosx-10.15-x86_64-3.9/scipy/linalg' to include_dirs.
#       adding 'build/src.macosx-10.15-x86_64-3.9/build/src.macosx-10.15-x86_64-3.9/scipy/linalg/_fblas-f2pywrappers.f' to sources.
#     building extension "scipy.linalg._flapack" sources
#     f2py options: []
#       adding 'build/src.macosx-10.15-x86_64-3.9/build/src.macosx-10.15-x86_64-3.9/build/src.macosx-10.15-x86_64-3.9/scipy/linalg/fortranobject.c' to sources.
#       adding 'build/src.macosx-10.15-x86_64-3.9/build/src.macosx-10.15-x86_64-3.9/build/src.macosx-10.15-x86_64-3.9/scipy/linalg' to include_dirs.
#       adding 'build/src.macosx-10.15-x86_64-3.9/build/src.macosx-10.15-x86_64-3.9/scipy/linalg/_flapack-f2pywrappers.f' to sources.
#     building extension "scipy.linalg._flinalg" sources
#     f2py options: []
#       adding 'build/src.macosx-10.15-x86_64-3.9/build/src.macosx-10.15-x86_64-3.9/scipy/linalg/fortranobject.c' to sources.
#       adding 'build/src.macosx-10.15-x86_64-3.9/build/src.macosx-10.15-x86_64-3.9/scipy/linalg' to include_dirs.
#     building extension "scipy.linalg._interpolative" sources
#     f2py options: []
#       adding 'build/src.macosx-10.15-x86_64-3.9/build/src.macosx-10.15-x86_64-3.9/scipy/linalg/fortranobject.c' to sources.
#       adding 'build/src.macosx-10.15-x86_64-3.9/build/src.macosx-10.15-x86_64-3.9/scipy/linalg' to include_dirs.
#     building extension "scipy.linalg._solve_toeplitz" sources
#     building extension "scipy.linalg.cython_blas" sources
#     building extension "scipy.linalg.cython_lapack" sources
#     building extension "scipy.linalg._decomp_update" sources
#     building extension "scipy.odr.__odrpack" sources
#     building extension "scipy.optimize._minpack" sources
#     building extension "scipy.optimize._lsap_module" sources
#     building extension "scipy.optimize._zeros" sources
#     building extension "scipy.optimize._lbfgsb" sources
#     f2py options: []
#       adding 'build/src.macosx-10.15-x86_64-3.9/build/src.macosx-10.15-x86_64-3.9/scipy/optimize/lbfgsb_src/fortranobject.c' to sources.
#       adding 'build/src.macosx-10.15-x86_64-3.9/build/src.macosx-10.15-x86_64-3.9/scipy/optimize/lbfgsb_src' to include_dirs.
#       adding 'build/src.macosx-10.15-x86_64-3.9/scipy/optimize/lbfgsb_src/_lbfgsb-f2pywrappers.f' to sources.
#     building extension "scipy.optimize.moduleTNC" sources
#     building extension "scipy.optimize._cobyla" sources
#     f2py options: []
#       adding 'build/src.macosx-10.15-x86_64-3.9/build/src.macosx-10.15-x86_64-3.9/scipy/optimize/cobyla/fortranobject.c' to sources.
#       adding 'build/src.macosx-10.15-x86_64-3.9/build/src.macosx-10.15-x86_64-3.9/scipy/optimize/cobyla' to include_dirs.
#     building extension "scipy.optimize.minpack2" sources
#     f2py options: []
#       adding 'build/src.macosx-10.15-x86_64-3.9/build/src.macosx-10.15-x86_64-3.9/scipy/optimize/minpack2/fortranobject.c' to sources.
#       adding 'build/src.macosx-10.15-x86_64-3.9/build/src.macosx-10.15-x86_64-3.9/scipy/optimize/minpack2' to include_dirs.
#     building extension "scipy.optimize._slsqp" sources
#     f2py options: []
#       adding 'build/src.macosx-10.15-x86_64-3.9/build/src.macosx-10.15-x86_64-3.9/scipy/optimize/slsqp/fortranobject.c' to sources.
#       adding 'build/src.macosx-10.15-x86_64-3.9/build/src.macosx-10.15-x86_64-3.9/scipy/optimize/slsqp' to include_dirs.
#     building extension "scipy.optimize.__nnls" sources
#     f2py options: []
#       adding 'build/src.macosx-10.15-x86_64-3.9/build/src.macosx-10.15-x86_64-3.9/scipy/optimize/__nnls/fortranobject.c' to sources.
#       adding 'build/src.macosx-10.15-x86_64-3.9/build/src.macosx-10.15-x86_64-3.9/scipy/optimize/__nnls' to include_dirs.
#     building extension "scipy.optimize._group_columns" sources
#     building extension "scipy.optimize._bglu_dense" sources
#     building extension "scipy.optimize._lsq.givens_elimination" sources
#     building extension "scipy.optimize._trlib._trlib" sources
#     building extension "scipy.optimize.cython_optimize._zeros" sources
#     building extension "scipy.signal.sigtools" sources
#     building extension "scipy.signal._spectral" sources
#     building extension "scipy.signal._max_len_seq_inner" sources
#     building extension "scipy.signal._peak_finding_utils" sources
#     building extension "scipy.signal._sosfilt" sources
#     building extension "scipy.signal._upfirdn_apply" sources
#     building extension "scipy.signal.spline" sources
#     building extension "scipy.sparse.linalg.isolve._iterative" sources
#     f2py options: []
#       adding 'build/src.macosx-10.15-x86_64-3.9/build/src.macosx-10.15-x86_64-3.9/build/src.macosx-10.15-x86_64-3.9/scipy/sparse/linalg/isolve/iterative/fortranobject.c' to sources.
#       adding 'build/src.macosx-10.15-x86_64-3.9/build/src.macosx-10.15-x86_64-3.9/build/src.macosx-10.15-x86_64-3.9/scipy/sparse/linalg/isolve/iterative' to include_dirs.
#     building extension "scipy.sparse.linalg.dsolve._superlu" sources
#     building extension "scipy.sparse.linalg.eigen.arpack._arpack" sources
#     f2py options: []
#       adding 'build/src.macosx-10.15-x86_64-3.9/build/src.macosx-10.15-x86_64-3.9/build/src.macosx-10.15-x86_64-3.9/scipy/sparse/linalg/eigen/arpack/fortranobject.c' to sources.
#       adding 'build/src.macosx-10.15-x86_64-3.9/build/src.macosx-10.15-x86_64-3.9/build/src.macosx-10.15-x86_64-3.9/scipy/sparse/linalg/eigen/arpack' to include_dirs.
#       adding 'build/src.macosx-10.15-x86_64-3.9/build/src.macosx-10.15-x86_64-3.9/scipy/sparse/linalg/eigen/arpack/_arpack-f2pywrappers.f' to sources.
#     building extension "scipy.sparse.csgraph._shortest_path" sources
#     building extension "scipy.sparse.csgraph._traversal" sources
#     building extension "scipy.sparse.csgraph._min_spanning_tree" sources
#     building extension "scipy.sparse.csgraph._matching" sources
#     building extension "scipy.sparse.csgraph._flow" sources
#     building extension "scipy.sparse.csgraph._reordering" sources
#     building extension "scipy.sparse.csgraph._tools" sources
#     building extension "scipy.sparse._csparsetools" sources
#     building extension "scipy.sparse._sparsetools" sources
#     [generate_sparsetools] '/private/var/folders/5m/z78sg2m56qj87c1075qmwq780000gn/T/pip-install-awo43y9a/scipy/scipy/sparse/sparsetools/bsr_impl.h' already up-to-date
#     [generate_sparsetools] '/private/var/folders/5m/z78sg2m56qj87c1075qmwq780000gn/T/pip-install-awo43y9a/scipy/scipy/sparse/sparsetools/csr_impl.h' already up-to-date
#     [generate_sparsetools] '/private/var/folders/5m/z78sg2m56qj87c1075qmwq780000gn/T/pip-install-awo43y9a/scipy/scipy/sparse/sparsetools/csc_impl.h' already up-to-date
#     [generate_sparsetools] '/private/var/folders/5m/z78sg2m56qj87c1075qmwq780000gn/T/pip-install-awo43y9a/scipy/scipy/sparse/sparsetools/other_impl.h' already up-to-date
#     [generate_sparsetools] '/private/var/folders/5m/z78sg2m56qj87c1075qmwq780000gn/T/pip-install-awo43y9a/scipy/scipy/sparse/sparsetools/sparsetools_impl.h' already up-to-date
#     building extension "scipy.spatial.qhull" sources
#     building extension "scipy.spatial.ckdtree" sources
#     building extension "scipy.spatial._distance_wrap" sources
#     building extension "scipy.spatial._voronoi" sources
#     building extension "scipy.spatial._hausdorff" sources
#     building extension "scipy.special.specfun" sources
#     f2py options: ['--no-wrap-functions']
#       adding 'build/src.macosx-10.15-x86_64-3.9/build/src.macosx-10.15-x86_64-3.9/scipy/special/fortranobject.c' to sources.
#       adding 'build/src.macosx-10.15-x86_64-3.9/build/src.macosx-10.15-x86_64-3.9/scipy/special' to include_dirs.
#     building extension "scipy.special._ufuncs" sources
#     building extension "scipy.special._ufuncs_cxx" sources
#     building extension "scipy.special._ellip_harm_2" sources
#     building extension "scipy.special.cython_special" sources
#     building extension "scipy.special._comb" sources
#     building extension "scipy.special._test_round" sources
#     building extension "scipy.stats.statlib" sources
#     f2py options: ['--no-wrap-functions']
#       adding 'build/src.macosx-10.15-x86_64-3.9/build/src.macosx-10.15-x86_64-3.9/scipy/stats/fortranobject.c' to sources.
#       adding 'build/src.macosx-10.15-x86_64-3.9/build/src.macosx-10.15-x86_64-3.9/scipy/stats' to include_dirs.
#     building extension "scipy.stats._stats" sources
#     building extension "scipy.stats.mvn" sources
#     f2py options: []
#       adding 'build/src.macosx-10.15-x86_64-3.9/build/src.macosx-10.15-x86_64-3.9/scipy/stats/fortranobject.c' to sources.
#       adding 'build/src.macosx-10.15-x86_64-3.9/build/src.macosx-10.15-x86_64-3.9/scipy/stats' to include_dirs.
#       adding 'build/src.macosx-10.15-x86_64-3.9/scipy/stats/mvn-f2pywrappers.f' to sources.
#     building extension "scipy.ndimage._nd_image" sources
#     building extension "scipy.ndimage._ni_label" sources
#     building extension "scipy.ndimage._ctest" sources
#     building extension "scipy.ndimage._ctest_oldapi" sources
#     building extension "scipy.ndimage._cytest" sources
#     building extension "scipy._lib._ccallback_c" sources
#     building extension "scipy._lib._test_ccallback" sources
#     building extension "scipy._lib._fpumode" sources
#     building extension "scipy._lib.messagestream" sources
#     get_default_fcompiler: matching types: '['gnu95', 'nag', 'absoft', 'ibm', 'intel', 'gnu', 'g95', 'pg']'
#     customize Gnu95FCompiler
#     Could not locate executable gfortran
#     Could not locate executable f95
#     customize NAGFCompiler
#     customize AbsoftFCompiler
#     Could not locate executable f90
#     Could not locate executable f77
#     customize IBMFCompiler
#     Could not locate executable xlf90
#     Could not locate executable xlf
#     customize IntelFCompiler
#     Could not locate executable ifort
#     Could not locate executable ifc
#     customize GnuFCompiler
#     Could not locate executable g77
#     customize G95FCompiler
#     Could not locate executable g95
#     customize PGroupFCompiler
#     Could not locate executable pgfortran
#     don't know how to compile Fortran code on platform 'posix'
#     C compiler: clang -Wno-unused-result -Wsign-compare -Wunreachable-code -fno-common -dynamic -DNDEBUG -g -fwrapv -O3 -Wall -isysroot /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk -I/Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include -I/Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/System/Library/Frameworks/Tk.framework/Versions/8.5/Headers
#
#     compile options: '-I/usr/local/include -I/usr/local/opt/openssl@1.1/include -I/usr/local/opt/sqlite/include -I/usr/local/Cellar/python@3.9/3.9.0_1/Frameworks/Python.framework/Versions/3.9/include/python3.9 -c'
#     clang: _configtest.c
#     clang _configtest.o -o _configtest
#     success!
#     removing: _configtest.c _configtest.o _configtest.o.d _configtest
#     building extension "scipy._lib._test_deprecation_call" sources
#     building extension "scipy._lib._test_deprecation_def" sources
#     building extension "scipy._lib._uarray._uarray" sources
#     building data_files sources
#     build_src: building npy-pkg config files
#     running build_py
#     creating build/lib.macosx-10.15-x86_64-3.9
#     creating build/lib.macosx-10.15-x86_64-3.9/scipy
#     copying scipy/conftest.py -> build/lib.macosx-10.15-x86_64-3.9/scipy
#     copying scipy/version.py -> build/lib.macosx-10.15-x86_64-3.9/scipy
#     copying scipy/__init__.py -> build/lib.macosx-10.15-x86_64-3.9/scipy
#     copying scipy/_distributor_init.py -> build/lib.macosx-10.15-x86_64-3.9/scipy
#     copying scipy/setup.py -> build/lib.macosx-10.15-x86_64-3.9/scipy
#     copying build/src.macosx-10.15-x86_64-3.9/scipy/__config__.py -> build/lib.macosx-10.15-x86_64-3.9/scipy
#     creating build/lib.macosx-10.15-x86_64-3.9/scipy/cluster
#     copying scipy/cluster/vq.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/cluster
#     copying scipy/cluster/__init__.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/cluster
#     copying scipy/cluster/hierarchy.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/cluster
#     copying scipy/cluster/setup.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/cluster
#     creating build/lib.macosx-10.15-x86_64-3.9/scipy/constants
#     copying scipy/constants/constants.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/constants
#     copying scipy/constants/__init__.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/constants
#     copying scipy/constants/codata.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/constants
#     copying scipy/constants/setup.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/constants
#     creating build/lib.macosx-10.15-x86_64-3.9/scipy/fft
#     copying scipy/fft/_backend.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/fft
#     copying scipy/fft/_helper.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/fft
#     copying scipy/fft/__init__.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/fft
#     copying scipy/fft/setup.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/fft
#     copying scipy/fft/_debug_backends.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/fft
#     copying scipy/fft/_realtransforms.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/fft
#     copying scipy/fft/_basic.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/fft
#     creating build/lib.macosx-10.15-x86_64-3.9/scipy/fft/_pocketfft
#     copying scipy/fft/_pocketfft/__init__.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/fft/_pocketfft
#     copying scipy/fft/_pocketfft/setup.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/fft/_pocketfft
#     copying scipy/fft/_pocketfft/realtransforms.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/fft/_pocketfft
#     copying scipy/fft/_pocketfft/basic.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/fft/_pocketfft
#     copying scipy/fft/_pocketfft/helper.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/fft/_pocketfft
#     creating build/lib.macosx-10.15-x86_64-3.9/scipy/fftpack
#     copying scipy/fftpack/__init__.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/fftpack
#     copying scipy/fftpack/pseudo_diffs.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/fftpack
#     copying scipy/fftpack/setup.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/fftpack
#     copying scipy/fftpack/realtransforms.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/fftpack
#     copying scipy/fftpack/basic.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/fftpack
#     copying scipy/fftpack/helper.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/fftpack
#     creating build/lib.macosx-10.15-x86_64-3.9/scipy/integrate
#     copying scipy/integrate/_ode.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/integrate
#     copying scipy/integrate/_quadrature.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/integrate
#     copying scipy/integrate/__init__.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/integrate
#     copying scipy/integrate/quadpack.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/integrate
#     copying scipy/integrate/_quad_vec.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/integrate
#     copying scipy/integrate/setup.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/integrate
#     copying scipy/integrate/_bvp.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/integrate
#     copying scipy/integrate/odepack.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/integrate
#     creating build/lib.macosx-10.15-x86_64-3.9/scipy/integrate/_ivp
#     copying scipy/integrate/_ivp/bdf.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/integrate/_ivp
#     copying scipy/integrate/_ivp/ivp.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/integrate/_ivp
#     copying scipy/integrate/_ivp/dop853_coefficients.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/integrate/_ivp
#     copying scipy/integrate/_ivp/__init__.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/integrate/_ivp
#     copying scipy/integrate/_ivp/setup.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/integrate/_ivp
#     copying scipy/integrate/_ivp/common.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/integrate/_ivp
#     copying scipy/integrate/_ivp/radau.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/integrate/_ivp
#     copying scipy/integrate/_ivp/lsoda.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/integrate/_ivp
#     copying scipy/integrate/_ivp/rk.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/integrate/_ivp
#     copying scipy/integrate/_ivp/base.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/integrate/_ivp
#     creating build/lib.macosx-10.15-x86_64-3.9/scipy/interpolate
#     copying scipy/interpolate/_cubic.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/interpolate
#     copying scipy/interpolate/polyint.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/interpolate
#     copying scipy/interpolate/ndgriddata.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/interpolate
#     copying scipy/interpolate/_bsplines.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/interpolate
#     copying scipy/interpolate/__init__.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/interpolate
#     copying scipy/interpolate/fitpack.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/interpolate
#     copying scipy/interpolate/rbf.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/interpolate
#     copying scipy/interpolate/interpnd_info.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/interpolate
#     copying scipy/interpolate/setup.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/interpolate
#     copying scipy/interpolate/_pade.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/interpolate
#     copying scipy/interpolate/interpolate.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/interpolate
#     copying scipy/interpolate/_fitpack_impl.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/interpolate
#     copying scipy/interpolate/fitpack2.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/interpolate
#     creating build/lib.macosx-10.15-x86_64-3.9/scipy/io
#     copying scipy/io/wavfile.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/io
#     copying scipy/io/idl.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/io
#     copying scipy/io/__init__.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/io
#     copying scipy/io/netcdf.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/io
#     copying scipy/io/setup.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/io
#     copying scipy/io/_fortran.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/io
#     copying scipy/io/mmio.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/io
#     creating build/lib.macosx-10.15-x86_64-3.9/scipy/io/matlab
#     copying scipy/io/matlab/miobase.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/io/matlab
#     copying scipy/io/matlab/mio5_params.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/io/matlab
#     copying scipy/io/matlab/__init__.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/io/matlab
#     copying scipy/io/matlab/setup.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/io/matlab
#     copying scipy/io/matlab/byteordercodes.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/io/matlab
#     copying scipy/io/matlab/mio.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/io/matlab
#     copying scipy/io/matlab/mio4.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/io/matlab
#     copying scipy/io/matlab/mio5.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/io/matlab
#     creating build/lib.macosx-10.15-x86_64-3.9/scipy/io/arff
#     copying scipy/io/arff/__init__.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/io/arff
#     copying scipy/io/arff/setup.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/io/arff
#     copying scipy/io/arff/arffread.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/io/arff
#     creating build/lib.macosx-10.15-x86_64-3.9/scipy/io/harwell_boeing
#     copying scipy/io/harwell_boeing/__init__.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/io/harwell_boeing
#     copying scipy/io/harwell_boeing/setup.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/io/harwell_boeing
#     copying scipy/io/harwell_boeing/_fortran_format_parser.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/io/harwell_boeing
#     copying scipy/io/harwell_boeing/hb.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/io/harwell_boeing
#     creating build/lib.macosx-10.15-x86_64-3.9/scipy/linalg
#     copying scipy/linalg/decomp_qr.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/linalg
#     copying scipy/linalg/_matfuncs_inv_ssq.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/linalg
#     copying scipy/linalg/misc.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/linalg
#     copying scipy/linalg/_sketches.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/linalg
#     copying scipy/linalg/decomp_cholesky.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/linalg
#     copying scipy/linalg/_testutils.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/linalg
#     copying scipy/linalg/decomp_lu.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/linalg
#     copying scipy/linalg/decomp_svd.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/linalg
#     copying scipy/linalg/_procrustes.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/linalg
#     copying scipy/linalg/_matfuncs_sqrtm.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/linalg
#     copying scipy/linalg/matfuncs.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/linalg
#     copying scipy/linalg/__init__.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/linalg
#     copying scipy/linalg/_generate_pyx.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/linalg
#     copying scipy/linalg/_solvers.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/linalg
#     copying scipy/linalg/_interpolative_backend.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/linalg
#     copying scipy/linalg/flinalg.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/linalg
#     copying scipy/linalg/setup.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/linalg
#     copying scipy/linalg/basic.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/linalg
#     copying scipy/linalg/_decomp_polar.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/linalg
#     copying scipy/linalg/decomp.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/linalg
#     copying scipy/linalg/interpolative.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/linalg
#     copying scipy/linalg/blas.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/linalg
#     copying scipy/linalg/_cython_signature_generator.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/linalg
#     copying scipy/linalg/special_matrices.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/linalg
#     copying scipy/linalg/_decomp_ldl.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/linalg
#     copying scipy/linalg/_decomp_cossin.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/linalg
#     copying scipy/linalg/decomp_schur.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/linalg
#     copying scipy/linalg/_decomp_qz.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/linalg
#     copying scipy/linalg/_expm_frechet.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/linalg
#     copying scipy/linalg/lapack.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/linalg
#     creating build/lib.macosx-10.15-x86_64-3.9/scipy/misc
#     copying scipy/misc/__init__.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/misc
#     copying scipy/misc/setup.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/misc
#     copying scipy/misc/common.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/misc
#     copying scipy/misc/doccer.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/misc
#     creating build/lib.macosx-10.15-x86_64-3.9/scipy/odr
#     copying scipy/odr/_add_newdocs.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/odr
#     copying scipy/odr/models.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/odr
#     copying scipy/odr/odrpack.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/odr
#     copying scipy/odr/__init__.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/odr
#     copying scipy/odr/setup.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/odr
#     creating build/lib.macosx-10.15-x86_64-3.9/scipy/optimize
#     copying scipy/optimize/tnc.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/optimize
#     copying scipy/optimize/_lsap.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/optimize
#     copying scipy/optimize/optimize.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/optimize
#     copying scipy/optimize/_linprog_ip.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/optimize
#     copying scipy/optimize/linesearch.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/optimize
#     copying scipy/optimize/nonlin.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/optimize
#     copying scipy/optimize/_linprog_rs.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/optimize
#     copying scipy/optimize/_root.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/optimize
#     copying scipy/optimize/lbfgsb.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/optimize
#     copying scipy/optimize/zeros.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/optimize
#     copying scipy/optimize/_shgo.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/optimize
#     copying scipy/optimize/_linprog_simplex.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/optimize
#     copying scipy/optimize/slsqp.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/optimize
#     copying scipy/optimize/_trustregion_ncg.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/optimize
#     copying scipy/optimize/_minimize.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/optimize
#     copying scipy/optimize/minpack.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/optimize
#     copying scipy/optimize/_basinhopping.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/optimize
#     copying scipy/optimize/_linprog.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/optimize
#     copying scipy/optimize/_hessian_update_strategy.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/optimize
#     copying scipy/optimize/__init__.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/optimize
#     copying scipy/optimize/cobyla.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/optimize
#     copying scipy/optimize/_tstutils.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/optimize
#     copying scipy/optimize/_nnls.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/optimize
#     copying scipy/optimize/_spectral.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/optimize
#     copying scipy/optimize/_differentiable_functions.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/optimize
#     copying scipy/optimize/_trustregion_krylov.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/optimize
#     copying scipy/optimize/_trustregion.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/optimize
#     copying scipy/optimize/setup.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/optimize
#     copying scipy/optimize/_linprog_util.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/optimize
#     copying scipy/optimize/_dual_annealing.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/optimize
#     copying scipy/optimize/_root_scalar.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/optimize
#     copying scipy/optimize/_trustregion_dogleg.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/optimize
#     copying scipy/optimize/_trustregion_exact.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/optimize
#     copying scipy/optimize/_constraints.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/optimize
#     copying scipy/optimize/_differentialevolution.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/optimize
#     copying scipy/optimize/_remove_redundancy.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/optimize
#     copying scipy/optimize/_numdiff.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/optimize
#     creating build/lib.macosx-10.15-x86_64-3.9/scipy/optimize/_lsq
#     copying scipy/optimize/_lsq/least_squares.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/optimize/_lsq
#     copying scipy/optimize/_lsq/dogbox.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/optimize/_lsq
#     copying scipy/optimize/_lsq/__init__.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/optimize/_lsq
#     copying scipy/optimize/_lsq/trf_linear.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/optimize/_lsq
#     copying scipy/optimize/_lsq/setup.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/optimize/_lsq
#     copying scipy/optimize/_lsq/common.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/optimize/_lsq
#     copying scipy/optimize/_lsq/lsq_linear.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/optimize/_lsq
#     copying scipy/optimize/_lsq/bvls.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/optimize/_lsq
#     copying scipy/optimize/_lsq/trf.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/optimize/_lsq
#     creating build/lib.macosx-10.15-x86_64-3.9/scipy/optimize/_trlib
#     copying scipy/optimize/_trlib/__init__.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/optimize/_trlib
#     copying scipy/optimize/_trlib/setup.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/optimize/_trlib
#     creating build/lib.macosx-10.15-x86_64-3.9/scipy/optimize/_trustregion_constr
#     copying scipy/optimize/_trustregion_constr/equality_constrained_sqp.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/optimize/_trustregion_constr
#     copying scipy/optimize/_trustregion_constr/__init__.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/optimize/_trustregion_constr
#     copying scipy/optimize/_trustregion_constr/setup.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/optimize/_trustregion_constr
#     copying scipy/optimize/_trustregion_constr/tr_interior_point.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/optimize/_trustregion_constr
#     copying scipy/optimize/_trustregion_constr/qp_subproblem.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/optimize/_trustregion_constr
#     copying scipy/optimize/_trustregion_constr/minimize_trustregion_constr.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/optimize/_trustregion_constr
#     copying scipy/optimize/_trustregion_constr/projections.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/optimize/_trustregion_constr
#     copying scipy/optimize/_trustregion_constr/report.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/optimize/_trustregion_constr
#     copying scipy/optimize/_trustregion_constr/canonical_constraint.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/optimize/_trustregion_constr
#     creating build/lib.macosx-10.15-x86_64-3.9/scipy/optimize/cython_optimize
#     copying scipy/optimize/cython_optimize/__init__.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/optimize/cython_optimize
#     creating build/lib.macosx-10.15-x86_64-3.9/scipy/optimize/_shgo_lib
#     copying scipy/optimize/_shgo_lib/__init__.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/optimize/_shgo_lib
#     copying scipy/optimize/_shgo_lib/sobol_seq.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/optimize/_shgo_lib
# ...
#     copying scipy/sparse/setup.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/sparse
#     copying scipy/sparse/_matrix_io.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/sparse
#     copying scipy/sparse/csr.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/sparse
#     copying scipy/sparse/construct.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/sparse
#     copying scipy/sparse/extract.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/sparse
#     copying scipy/sparse/base.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/sparse
#     copying scipy/sparse/data.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/sparse
#     creating build/lib.macosx-10.15-x86_64-3.9/scipy/sparse/linalg
#     copying scipy/sparse/linalg/matfuncs.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/sparse/linalg
#     copying scipy/sparse/linalg/interface.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/sparse/linalg
#     copying scipy/sparse/linalg/_expm_multiply.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/sparse/linalg
#     copying scipy/sparse/linalg/__init__.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/sparse/linalg
#     copying scipy/sparse/linalg/setup.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/sparse/linalg
#     copying scipy/sparse/linalg/_norm.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/sparse/linalg
#     copying scipy/sparse/linalg/_onenormest.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/sparse/linalg
#     creating build/lib.macosx-10.15-x86_64-3.9/scipy/sparse/linalg/isolve
#     copying scipy/sparse/linalg/isolve/lsqr.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/sparse/linalg/isolve
#     copying scipy/sparse/linalg/isolve/__init__.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/sparse/linalg/isolve
#     copying scipy/sparse/linalg/isolve/setup.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/sparse/linalg/isolve
#     copying scipy/sparse/linalg/isolve/iterative.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/sparse/linalg/isolve
#     copying scipy/sparse/linalg/isolve/utils.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/sparse/linalg/isolve
#     copying scipy/sparse/linalg/isolve/_gcrotmk.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/sparse/linalg/isolve
#     copying scipy/sparse/linalg/isolve/minres.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/sparse/linalg/isolve
#     copying scipy/sparse/linalg/isolve/lsmr.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/sparse/linalg/isolve
#     copying scipy/sparse/linalg/isolve/lgmres.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/sparse/linalg/isolve
#     creating build/lib.macosx-10.15-x86_64-3.9/scipy/sparse/linalg/dsolve
#     copying scipy/sparse/linalg/dsolve/_add_newdocs.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/sparse/linalg/dsolve
#     copying scipy/sparse/linalg/dsolve/linsolve.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/sparse/linalg/dsolve
#     copying scipy/sparse/linalg/dsolve/__init__.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/sparse/linalg/dsolve
#     copying scipy/sparse/linalg/dsolve/setup.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/sparse/linalg/dsolve
#     creating build/lib.macosx-10.15-x86_64-3.9/scipy/sparse/linalg/eigen
#     copying scipy/sparse/linalg/eigen/__init__.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/sparse/linalg/eigen
#     copying scipy/sparse/linalg/eigen/setup.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/sparse/linalg/eigen
#     creating build/lib.macosx-10.15-x86_64-3.9/scipy/sparse/linalg/eigen/arpack
#     copying scipy/sparse/linalg/eigen/arpack/__init__.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/sparse/linalg/eigen/arpack
#     copying scipy/sparse/linalg/eigen/arpack/setup.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/sparse/linalg/eigen/arpack
#     copying scipy/sparse/linalg/eigen/arpack/arpack.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/sparse/linalg/eigen/arpack
#     creating build/lib.macosx-10.15-x86_64-3.9/scipy/sparse/linalg/eigen/lobpcg
#     copying scipy/sparse/linalg/eigen/lobpcg/lobpcg.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/sparse/linalg/eigen/lobpcg
#     copying scipy/sparse/linalg/eigen/lobpcg/__init__.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/sparse/linalg/eigen/lobpcg
#     copying scipy/sparse/linalg/eigen/lobpcg/setup.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/sparse/linalg/eigen/lobpcg
#     creating build/lib.macosx-10.15-x86_64-3.9/scipy/sparse/csgraph
#     copying scipy/sparse/csgraph/_laplacian.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/sparse/csgraph
#     copying scipy/sparse/csgraph/__init__.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/sparse/csgraph
#     copying scipy/sparse/csgraph/setup.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/sparse/csgraph
#     copying scipy/sparse/csgraph/_validation.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/sparse/csgraph
#     creating build/lib.macosx-10.15-x86_64-3.9/scipy/spatial
#     copying scipy/spatial/_spherical_voronoi.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/spatial
#     copying scipy/spatial/_procrustes.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/spatial
#     copying scipy/spatial/__init__.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/spatial
#     copying scipy/spatial/distance.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/spatial
#     copying scipy/spatial/kdtree.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/spatial
#     copying scipy/spatial/setup.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/spatial
#     copying scipy/spatial/_geometric_slerp.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/spatial
#     copying scipy/spatial/_plotutils.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/spatial
#     creating build/lib.macosx-10.15-x86_64-3.9/scipy/spatial/transform
#     copying scipy/spatial/transform/__init__.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/spatial/transform
#     copying scipy/spatial/transform/setup.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/spatial/transform
#     copying scipy/spatial/transform/_rotation_spline.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/spatial/transform
#     copying scipy/spatial/transform/rotation.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/spatial/transform
#     copying scipy/spatial/transform/_rotation_groups.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/spatial/transform
#     creating build/lib.macosx-10.15-x86_64-3.9/scipy/special
#     copying scipy/special/spfun_stats.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/special
#     copying scipy/special/_testutils.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/special
#     copying scipy/special/sf_error.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/special
#     copying scipy/special/add_newdocs.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/special
#     copying scipy/special/_spherical_bessel.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/special
#     copying scipy/special/_mptestutils.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/special
#     copying scipy/special/__init__.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/special
#     copying scipy/special/_ellip_harm.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/special
#     copying scipy/special/_generate_pyx.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/special
#     copying scipy/special/setup.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/special
#     copying scipy/special/_lambertw.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/special
#     copying scipy/special/basic.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/special
#     copying scipy/special/orthogonal.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/special
#     copying scipy/special/_basic.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/special
#     copying scipy/special/_logsumexp.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/special
#     creating build/lib.macosx-10.15-x86_64-3.9/scipy/special/_precompute
#     copying scipy/special/_precompute/expn_asy.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/special/_precompute
#     copying scipy/special/_precompute/zetac.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/special/_precompute
#     copying scipy/special/_precompute/struve_convergence.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/special/_precompute
#     copying scipy/special/_precompute/loggamma.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/special/_precompute
#     copying scipy/special/_precompute/gammainc_asy.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/special/_precompute
#     copying scipy/special/_precompute/wrightomega.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/special/_precompute
#     copying scipy/special/_precompute/gammainc_data.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/special/_precompute
#     copying scipy/special/_precompute/__init__.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/special/_precompute
#     copying scipy/special/_precompute/setup.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/special/_precompute
#     copying scipy/special/_precompute/utils.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/special/_precompute
#     copying scipy/special/_precompute/lambertw.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/special/_precompute
#     creating build/lib.macosx-10.15-x86_64-3.9/scipy/stats
#     copying scipy/stats/_multivariate.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/stats
#     copying scipy/stats/_constants.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/stats
#     copying scipy/stats/_binned_statistic.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/stats
#     copying scipy/stats/_distr_params.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/stats
#     copying scipy/stats/_tukeylambda_stats.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/stats
#     copying scipy/stats/_rvs_sampling.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/stats
#     copying scipy/stats/_stats_mstats_common.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/stats
#     copying scipy/stats/_ksstats.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/stats
#     copying scipy/stats/kde.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/stats
#     copying scipy/stats/__init__.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/stats
#     copying scipy/stats/mstats_extras.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/stats
#     copying scipy/stats/_discrete_distns.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/stats
#     copying scipy/stats/distributions.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/stats
#     copying scipy/stats/_hypotests.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/stats
#     copying scipy/stats/setup.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/stats
#     copying scipy/stats/mstats.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/stats
#     copying scipy/stats/_distn_infrastructure.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/stats
#     copying scipy/stats/stats.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/stats
#     copying scipy/stats/_continuous_distns.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/stats
#     copying scipy/stats/morestats.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/stats
#     copying scipy/stats/mstats_basic.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/stats
#     copying scipy/stats/contingency.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/stats
#     copying scipy/stats/_wilcoxon_data.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/stats
#     creating build/lib.macosx-10.15-x86_64-3.9/scipy/ndimage
#     copying scipy/ndimage/_ni_support.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/ndimage
#     copying scipy/ndimage/interpolation.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/ndimage
#     copying scipy/ndimage/_ni_docstrings.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/ndimage
#     copying scipy/ndimage/__init__.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/ndimage
#     copying scipy/ndimage/morphology.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/ndimage
#     copying scipy/ndimage/setup.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/ndimage
#     copying scipy/ndimage/fourier.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/ndimage
#     copying scipy/ndimage/filters.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/ndimage
#     copying scipy/ndimage/measurements.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/ndimage
#     creating build/lib.macosx-10.15-x86_64-3.9/scipy/_build_utils
#     copying scipy/_build_utils/system_info.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/_build_utils
#     copying scipy/_build_utils/__init__.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/_build_utils
#     copying scipy/_build_utils/setup.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/_build_utils
#     copying scipy/_build_utils/_fortran.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/_build_utils
#     copying scipy/_build_utils/compiler_helper.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/_build_utils
#     creating build/lib.macosx-10.15-x86_64-3.9/scipy/_lib
#     copying scipy/_lib/uarray.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/_lib
#     copying scipy/_lib/_testutils.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/_lib
#     copying scipy/_lib/_pep440.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/_lib
#     copying scipy/_lib/deprecation.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/_lib
#     copying scipy/_lib/decorator.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/_lib
#     copying scipy/_lib/__init__.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/_lib
#     copying scipy/_lib/_ccallback.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/_lib
#     copying scipy/_lib/_threadsafety.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/_lib
#     copying scipy/_lib/setup.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/_lib
#     copying scipy/_lib/_tmpdirs.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/_lib
#     copying scipy/_lib/_util.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/_lib
#     copying scipy/_lib/_gcutils.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/_lib
#     copying scipy/_lib/doccer.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/_lib
#     creating build/lib.macosx-10.15-x86_64-3.9/scipy/_lib/_uarray
#     copying scipy/_lib/_uarray/_backend.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/_lib/_uarray
#     copying scipy/_lib/_uarray/__init__.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/_lib/_uarray
#     copying scipy/_lib/_uarray/setup.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/_lib/_uarray
#     running build_clib
#     customize UnixCCompiler
#     #### ['clang', '-Wno-unused-result', '-Wsign-compare', '-Wunreachable-code', '-fno-common', '-dynamic', '-DNDEBUG', '-g', '-fwrapv', '-O3', '-Wall', '-isysroot', '/Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk', '-I/Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include', '-I/Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/System/Library/Frameworks/Tk.framework/Versions/8.5/Headers'] #######
#     customize UnixCCompiler using build_clib
#     building 'mach' library
#     error: library mach has Fortran sources but no Fortran compiler found
#     ----------------------------------------
#     ERROR: Failed building wheel for scipy
#   Failed to build scipy
#   ERROR: Could not build wheels for scipy which use PEP 517 and cannot be installed directly
#   ----------------------------------------
# ERROR: Command errored out with exit status 1: /usr/local/opt/python@3.9/bin/python3.9 /usr/local/lib/python3.9/site-packages/pip install --ignore-installed --no-user --prefix /private/var/folders/5m/z78sg2m56qj87c1075qmwq780000gn/T/pip-build-env-aobb9s1a/overlay --no-warn-script-location --no-binary :none: --only-binary :none: -i https://pypi.org/simple -- setuptools wheel 'Cython>=0.28.5' 'numpy==1.13.3; python_version=='"'"'3.6'"'"' and platform_system!='"'"'AIX'"'"' and platform_python_implementation == '"'"'CPython'"'"'' 'numpy==1.14.0; python_version=='"'"'3.6'"'"' and platform_system!='"'"'AIX'"'"' and platform_python_implementation != '"'"'CPython'"'"'' 'numpy==1.14.5; python_version=='"'"'3.7'"'"' and platform_system!='"'"'AIX'"'"'' 'numpy==1.17.3; python_version>='"'"'3.8'"'"' and platform_system!='"'"'AIX'"'"'' 'numpy==1.16.0; python_version=='"'"'3.6'"'"' and platform_system=='"'"'AIX'"'"'' 'numpy==1.16.0; python_version=='"'"'3.7'"'"' and platform_system=='"'"'AIX'"'"'' 'numpy==1.17.3; python_version>='"'"'3.8'"'"' and platform_system=='"'"'AIX'"'"'' 'scipy>=0.19.1' Check the logs for full command output.

# %%
# !pip3 install mlxtend
# Out:
# Collecting mlxtend
#   Using cached mlxtend-0.17.3-py2.py3-none-any.whl (1.3 MB)
# Collecting joblib>=0.13.2
#   Using cached joblib-0.17.0-py3-none-any.whl (301 kB)
# Collecting scipy>=1.2.1
#   Using cached scipy-1.5.3.tar.gz (25.2 MB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# Requirement already satisfied: pandas>=0.24.2 in /usr/local/lib/python3.9/site-packages (from mlxtend) (1.1.4)
# Collecting scikit-learn>=0.20.3
#   Using cached scikit-learn-0.23.2.tar.gz (7.2 MB)
#   Installing build dependencies ... error
#   ERROR: Command errored out with exit status 1:
#    command: /usr/local/opt/python@3.9/bin/python3.9 /usr/local/lib/python3.9/site-packages/pip install --ignore-installed --no-user --prefix /private/var/folders/5m/z78sg2m56qj87c1075qmwq780000gn/T/pip-build-env-4i4iwci_/overlay --no-warn-script-location --no-binary :none: --only-binary :none: -i https://pypi.org/simple -- setuptools wheel 'Cython>=0.28.5' 'numpy==1.13.3; python_version=='"'"'3.6'"'"' and platform_system!='"'"'AIX'"'"' and platform_python_implementation == '"'"'CPython'"'"'' 'numpy==1.14.0; python_version=='"'"'3.6'"'"' and platform_system!='"'"'AIX'"'"' and platform_python_implementation != '"'"'CPython'"'"'' 'numpy==1.14.5; python_version=='"'"'3.7'"'"' and platform_system!='"'"'AIX'"'"'' 'numpy==1.17.3; python_version>='"'"'3.8'"'"' and platform_system!='"'"'AIX'"'"'' 'numpy==1.16.0; python_version=='"'"'3.6'"'"' and platform_system=='"'"'AIX'"'"'' 'numpy==1.16.0; python_version=='"'"'3.7'"'"' and platform_system=='"'"'AIX'"'"'' 'numpy==1.17.3; python_version>='"'"'3.8'"'"' and platform_system=='"'"'AIX'"'"'' 'scipy>=0.19.1'
#        cwd: None
#   Complete output (842 lines):
#   Ignoring numpy: markers 'python_version == "3.6" and platform_system != "AIX" and platform_python_implementation == "CPython"' don't match your environment
#   Ignoring numpy: markers 'python_version == "3.6" and platform_system != "AIX" and platform_python_implementation != "CPython"' don't match your environment
#   Ignoring numpy: markers 'python_version == "3.7" and platform_system != "AIX"' don't match your environment
#   Ignoring numpy: markers 'python_version == "3.6" and platform_system == "AIX"' don't match your environment
#   Ignoring numpy: markers 'python_version == "3.7" and platform_system == "AIX"' don't match your environment
#   Ignoring numpy: markers 'python_version >= "3.8" and platform_system == "AIX"' don't match your environment
#   Collecting setuptools
#     Using cached setuptools-50.3.2-py3-none-any.whl (785 kB)
#   Collecting wheel
#     Using cached wheel-0.35.1-py2.py3-none-any.whl (33 kB)
#   Collecting Cython>=0.28.5
#     Using cached Cython-0.29.21-py2.py3-none-any.whl (974 kB)
#   Processing /Users/thomaschenu/Library/Caches/pip/wheels/88/21/07/12b17bd52e2030a53d9757e9d65610e73d4075ee2d7c456d70/numpy-1.17.3-cp39-cp39-macosx_10_15_x86_64.whl
#   Collecting scipy>=0.19.1
#     Using cached scipy-1.5.3.tar.gz (25.2 MB)
#     Installing build dependencies: started
#     Installing build dependencies: finished with status 'done'
#     Getting requirements to build wheel: started
#     Getting requirements to build wheel: finished with status 'done'
#       Preparing wheel metadata: started
#       Preparing wheel metadata: finished with status 'done'
#   Building wheels for collected packages: scipy
#     Building wheel for scipy (PEP 517): started
#     Building wheel for scipy (PEP 517): finished with status 'error'
#     ERROR: Command errored out with exit status 1:
#      command: /usr/local/opt/python@3.9/bin/python3.9 /usr/local/lib/python3.9/site-packages/pip/_vendor/pep517/_in_process.py build_wheel /var/folders/5m/z78sg2m56qj87c1075qmwq780000gn/T/tmpjhiimr8x
#          cwd: /private/var/folders/5m/z78sg2m56qj87c1075qmwq780000gn/T/pip-install-9ejr9b05/scipy
#     Complete output (810 lines):
#     Running from SciPy source directory.
#     lapack_opt_info:
#     lapack_mkl_info:
#     customize UnixCCompiler
#       libraries mkl_rt not found in ['/usr/local/Cellar/python@3.9/3.9.0_1/Frameworks/Python.framework/Versions/3.9/lib', '/usr/local/lib', '/usr/lib']
#       NOT AVAILABLE
#
#     openblas_lapack_info:
#     customize UnixCCompiler
#     customize UnixCCompiler
#       libraries openblas not found in ['/usr/local/Cellar/python@3.9/3.9.0_1/Frameworks/Python.framework/Versions/3.9/lib', '/usr/local/lib', '/usr/lib']
#       NOT AVAILABLE
#
#     openblas_clapack_info:
#     customize UnixCCompiler
#     customize UnixCCompiler
#       libraries openblas,lapack not found in ['/usr/local/Cellar/python@3.9/3.9.0_1/Frameworks/Python.framework/Versions/3.9/lib', '/usr/local/lib', '/usr/lib']
#       NOT AVAILABLE
#
#     flame_info:
#     customize UnixCCompiler
#       libraries flame not found in ['/usr/local/Cellar/python@3.9/3.9.0_1/Frameworks/Python.framework/Versions/3.9/lib', '/usr/local/lib', '/usr/lib']
#       NOT AVAILABLE
#
#     atlas_3_10_threads_info:
#     Setting PTATLAS=ATLAS
#     customize UnixCCompiler
#       libraries lapack_atlas not found in /usr/local/Cellar/python@3.9/3.9.0_1/Frameworks/Python.framework/Versions/3.9/lib
#     customize UnixCCompiler
#       libraries tatlas,tatlas not found in /usr/local/Cellar/python@3.9/3.9.0_1/Frameworks/Python.framework/Versions/3.9/lib
#     customize UnixCCompiler
#       libraries lapack_atlas not found in /usr/local/lib
#     customize UnixCCompiler
#       libraries tatlas,tatlas not found in /usr/local/lib
#     customize UnixCCompiler
#       libraries lapack_atlas not found in /usr/lib
#     customize UnixCCompiler
#       libraries tatlas,tatlas not found in /usr/lib
#     <class 'numpy.distutils.system_info.atlas_3_10_threads_info'>
#       NOT AVAILABLE
#
#     atlas_3_10_info:
#     customize UnixCCompiler
#       libraries lapack_atlas not found in /usr/local/Cellar/python@3.9/3.9.0_1/Frameworks/Python.framework/Versions/3.9/lib
#     customize UnixCCompiler
#       libraries satlas,satlas not found in /usr/local/Cellar/python@3.9/3.9.0_1/Frameworks/Python.framework/Versions/3.9/lib
#     customize UnixCCompiler
#       libraries lapack_atlas not found in /usr/local/lib
#     customize UnixCCompiler
#       libraries satlas,satlas not found in /usr/local/lib
#     customize UnixCCompiler
#       libraries lapack_atlas not found in /usr/lib
#     customize UnixCCompiler
#       libraries satlas,satlas not found in /usr/lib
#     <class 'numpy.distutils.system_info.atlas_3_10_info'>
#       NOT AVAILABLE
#
#     atlas_threads_info:
#     Setting PTATLAS=ATLAS
#     customize UnixCCompiler
#       libraries lapack_atlas not found in /usr/local/Cellar/python@3.9/3.9.0_1/Frameworks/Python.framework/Versions/3.9/lib
#     customize UnixCCompiler
#       libraries ptf77blas,ptcblas,atlas not found in /usr/local/Cellar/python@3.9/3.9.0_1/Frameworks/Python.framework/Versions/3.9/lib
#     customize UnixCCompiler
#       libraries lapack_atlas not found in /usr/local/lib
#     customize UnixCCompiler
#       libraries ptf77blas,ptcblas,atlas not found in /usr/local/lib
#     customize UnixCCompiler
#       libraries lapack_atlas not found in /usr/lib
#     customize UnixCCompiler
#       libraries ptf77blas,ptcblas,atlas not found in /usr/lib
#     <class 'numpy.distutils.system_info.atlas_threads_info'>
#       NOT AVAILABLE
#
#     atlas_info:
#     customize UnixCCompiler
#       libraries lapack_atlas not found in /usr/local/Cellar/python@3.9/3.9.0_1/Frameworks/Python.framework/Versions/3.9/lib
#     customize UnixCCompiler
#       libraries f77blas,cblas,atlas not found in /usr/local/Cellar/python@3.9/3.9.0_1/Frameworks/Python.framework/Versions/3.9/lib
#     customize UnixCCompiler
#       libraries lapack_atlas not found in /usr/local/lib
#     customize UnixCCompiler
#       libraries f77blas,cblas,atlas not found in /usr/local/lib
#     customize UnixCCompiler
#       libraries lapack_atlas not found in /usr/lib
#     customize UnixCCompiler
#       libraries f77blas,cblas,atlas not found in /usr/lib
#     <class 'numpy.distutils.system_info.atlas_info'>
#       NOT AVAILABLE
#
#     accelerate_info:
#       NOT AVAILABLE
#
#     lapack_info:
#     customize UnixCCompiler
#     customize UnixCCompiler
#       FOUND:
#         libraries = ['lapack', 'lapack']
#         library_dirs = ['/usr/lib']
#         language = f77
#
#     blas_opt_info:
#     blas_mkl_info:
#     customize UnixCCompiler
#       libraries mkl_rt not found in ['/usr/local/Cellar/python@3.9/3.9.0_1/Frameworks/Python.framework/Versions/3.9/lib', '/usr/local/lib', '/usr/lib']
#       NOT AVAILABLE
#
#     blis_info:
#     customize UnixCCompiler
#       libraries blis not found in ['/usr/local/Cellar/python@3.9/3.9.0_1/Frameworks/Python.framework/Versions/3.9/lib', '/usr/local/lib', '/usr/lib']
#       NOT AVAILABLE
#
#     openblas_info:
#     customize UnixCCompiler
#     customize UnixCCompiler
#       libraries openblas not found in ['/usr/local/Cellar/python@3.9/3.9.0_1/Frameworks/Python.framework/Versions/3.9/lib', '/usr/local/lib', '/usr/lib']
#       NOT AVAILABLE
#
#     atlas_3_10_blas_threads_info:
#     Setting PTATLAS=ATLAS
#     customize UnixCCompiler
#       libraries tatlas not found in ['/usr/local/Cellar/python@3.9/3.9.0_1/Frameworks/Python.framework/Versions/3.9/lib', '/usr/local/lib', '/usr/lib']
#       NOT AVAILABLE
#
#     atlas_3_10_blas_info:
#     customize UnixCCompiler
#       libraries satlas not found in ['/usr/local/Cellar/python@3.9/3.9.0_1/Frameworks/Python.framework/Versions/3.9/lib', '/usr/local/lib', '/usr/lib']
#       NOT AVAILABLE
#
#     atlas_blas_threads_info:
#     Setting PTATLAS=ATLAS
#     customize UnixCCompiler
#       libraries ptf77blas,ptcblas,atlas not found in ['/usr/local/Cellar/python@3.9/3.9.0_1/Frameworks/Python.framework/Versions/3.9/lib', '/usr/local/lib', '/usr/lib']
#       NOT AVAILABLE
#
#     atlas_blas_info:
#     customize UnixCCompiler
#       libraries f77blas,cblas,atlas not found in ['/usr/local/Cellar/python@3.9/3.9.0_1/Frameworks/Python.framework/Versions/3.9/lib', '/usr/local/lib', '/usr/lib']
#       NOT AVAILABLE
#
#     /private/var/folders/5m/z78sg2m56qj87c1075qmwq780000gn/T/pip-build-env-n6vhtt9e/overlay/lib/python3.9/site-packages/numpy/distutils/system_info.py:690: UserWarning:
#         Optimized (vendor) Blas libraries are not found.
#         Falls back to netlib Blas library which has worse performance.
#         A better performance should be easily gained by switching
#         Blas library.
#       self.calc_info()
#     blas_info:
#     customize UnixCCompiler
#     customize UnixCCompiler
#     C compiler: clang -Wno-unused-result -Wsign-compare -Wunreachable-code -fno-common -dynamic -DNDEBUG -g -fwrapv -O3 -Wall -isysroot /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk -I/Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include -I/Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/System/Library/Frameworks/Tk.framework/Versions/8.5/Headers
#
#     creating /var/folders/5m/z78sg2m56qj87c1075qmwq780000gn/T/tmp6nutcq9r/var
#     creating /var/folders/5m/z78sg2m56qj87c1075qmwq780000gn/T/tmp6nutcq9r/var/folders
#     creating /var/folders/5m/z78sg2m56qj87c1075qmwq780000gn/T/tmp6nutcq9r/var/folders/5m
#     creating /var/folders/5m/z78sg2m56qj87c1075qmwq780000gn/T/tmp6nutcq9r/var/folders/5m/z78sg2m56qj87c1075qmwq780000gn
#     creating /var/folders/5m/z78sg2m56qj87c1075qmwq780000gn/T/tmp6nutcq9r/var/folders/5m/z78sg2m56qj87c1075qmwq780000gn/T
#     creating /var/folders/5m/z78sg2m56qj87c1075qmwq780000gn/T/tmp6nutcq9r/var/folders/5m/z78sg2m56qj87c1075qmwq780000gn/T/tmp6nutcq9r
#     compile options: '-I/usr/local/include -I/usr/local/Cellar/python@3.9/3.9.0_1/Frameworks/Python.framework/Versions/3.9/include -c'
#     clang: /var/folders/5m/z78sg2m56qj87c1075qmwq780000gn/T/tmp6nutcq9r/source.c
#     /var/folders/5m/z78sg2m56qj87c1075qmwq780000gn/T/tmp6nutcq9r/source.c:1:10: fatal error: 'cblas.h' file not found
#     #include <cblas.h>
#              ^~~~~~~~~
#     1 error generated.
#     customize UnixCCompiler
#       FOUND:
#         libraries = ['blas', 'blas']
#         library_dirs = ['/usr/lib']
#         include_dirs = ['/usr/local/include', '/usr/local/Cellar/python@3.9/3.9.0_1/Frameworks/Python.framework/Versions/3.9/include']
#
#       FOUND:
#         define_macros = [('NO_ATLAS_INFO', 1)]
#         libraries = ['blas', 'blas']
#         library_dirs = ['/usr/lib']
#         include_dirs = ['/usr/local/include', '/usr/local/Cellar/python@3.9/3.9.0_1/Frameworks/Python.framework/Versions/3.9/include']
#
#       FOUND:
#         libraries = ['lapack', 'lapack', 'blas', 'blas']
#         library_dirs = ['/usr/lib']
#         language = f77
#         define_macros = [('NO_ATLAS_INFO', 1)]
#         include_dirs = ['/usr/local/include', '/usr/local/Cellar/python@3.9/3.9.0_1/Frameworks/Python.framework/Versions/3.9/include']
#
#     /private/var/folders/5m/z78sg2m56qj87c1075qmwq780000gn/T/pip-build-env-n6vhtt9e/overlay/lib/python3.9/site-packages/numpy/distutils/system_info.py:782: UserWarning: Specified path /private/var/folders/5m/z78sg2m56qj87c1075qmwq780000gn/T/pip-build-env-n6vhtt9e/overlay/include/python3.9 is invalid.
#       return self.get_paths(self.section, key)
#     /private/var/folders/5m/z78sg2m56qj87c1075qmwq780000gn/T/pip-build-env-n6vhtt9e/overlay/lib/python3.9/site-packages/numpy/distutils/system_info.py:782: UserWarning: Specified path /usr/local/include/python3.9 is invalid.
#       return self.get_paths(self.section, key)
#     [makenpz] scipy/special/tests/data/boost.npz not rebuilt
#     [makenpz] scipy/special/tests/data/gsl.npz not rebuilt
#     [makenpz] scipy/special/tests/data/local.npz not rebuilt
#     non-existing path in 'scipy/signal/windows': 'tests'
#     running bdist_wheel
#     running build
#     running config_cc
#     unifing config_cc, config, build_clib, build_ext, build commands --compiler options
#     running config_fc
#     unifing config_fc, config, build_clib, build_ext, build commands --fcompiler options
#     running build_src
#     build_src
#     building py_modules sources
#     building library "mach" sources
#     building library "quadpack" sources
#     building library "lsoda" sources
#     building library "vode" sources
#     building library "dop" sources
#     building library "fitpack" sources
#     building library "fwrappers" sources
#     building library "odrpack" sources
#     building library "minpack" sources
#     building library "rectangular_lsap" sources
#     building library "rootfind" sources
#     building library "superlu_src" sources
#     building library "arpack_scipy" sources
#     building library "sc_cephes" sources
#     building library "sc_mach" sources
#     building library "sc_amos" sources
#     building library "sc_cdf" sources
#     building library "sc_specfun" sources
#     building library "statlib" sources
#     building extension "scipy.cluster._vq" sources
#     building extension "scipy.cluster._hierarchy" sources
#     building extension "scipy.cluster._optimal_leaf_ordering" sources
#     building extension "scipy.fft._pocketfft.pypocketfft" sources
#     building extension "scipy.fftpack.convolve" sources
#     building extension "scipy.integrate._quadpack" sources
#     building extension "scipy.integrate._odepack" sources
#     building extension "scipy.integrate.vode" sources
#     f2py options: []
#       adding 'build/src.macosx-10.15-x86_64-3.9/build/src.macosx-10.15-x86_64-3.9/scipy/integrate/fortranobject.c' to sources.
#       adding 'build/src.macosx-10.15-x86_64-3.9/build/src.macosx-10.15-x86_64-3.9/scipy/integrate' to include_dirs.
#       adding 'build/src.macosx-10.15-x86_64-3.9/scipy/integrate/vode-f2pywrappers.f' to sources.
#     building extension "scipy.integrate.lsoda" sources
#     f2py options: []
#       adding 'build/src.macosx-10.15-x86_64-3.9/build/src.macosx-10.15-x86_64-3.9/scipy/integrate/fortranobject.c' to sources.
#       adding 'build/src.macosx-10.15-x86_64-3.9/build/src.macosx-10.15-x86_64-3.9/scipy/integrate' to include_dirs.
#       adding 'build/src.macosx-10.15-x86_64-3.9/scipy/integrate/lsoda-f2pywrappers.f' to sources.
#     building extension "scipy.integrate._dop" sources
#     f2py options: []
#       adding 'build/src.macosx-10.15-x86_64-3.9/build/src.macosx-10.15-x86_64-3.9/scipy/integrate/fortranobject.c' to sources.
#       adding 'build/src.macosx-10.15-x86_64-3.9/build/src.macosx-10.15-x86_64-3.9/scipy/integrate' to include_dirs.
#       adding 'build/src.macosx-10.15-x86_64-3.9/scipy/integrate/_dop-f2pywrappers.f' to sources.
#     building extension "scipy.integrate._test_multivariate" sources
#     building extension "scipy.integrate._test_odeint_banded" sources
#     f2py options: []
#       adding 'build/src.macosx-10.15-x86_64-3.9/build/src.macosx-10.15-x86_64-3.9/scipy/integrate/fortranobject.c' to sources.
#       adding 'build/src.macosx-10.15-x86_64-3.9/build/src.macosx-10.15-x86_64-3.9/scipy/integrate' to include_dirs.
#       adding 'build/src.macosx-10.15-x86_64-3.9/scipy/integrate/_test_odeint_banded-f2pywrappers.f' to sources.
#     building extension "scipy.interpolate.interpnd" sources
#     building extension "scipy.interpolate._ppoly" sources
#     building extension "scipy.interpolate._bspl" sources
#     building extension "scipy.interpolate._fitpack" sources
#     building extension "scipy.interpolate.dfitpack" sources
#     f2py options: []
#       adding 'build/src.macosx-10.15-x86_64-3.9/build/src.macosx-10.15-x86_64-3.9/scipy/interpolate/src/fortranobject.c' to sources.
#       adding 'build/src.macosx-10.15-x86_64-3.9/build/src.macosx-10.15-x86_64-3.9/scipy/interpolate/src' to include_dirs.
#       adding 'build/src.macosx-10.15-x86_64-3.9/scipy/interpolate/src/dfitpack-f2pywrappers.f' to sources.
#     building extension "scipy.io._test_fortran" sources
#     f2py options: []
#       adding 'build/src.macosx-10.15-x86_64-3.9/build/src.macosx-10.15-x86_64-3.9/scipy/io/fortranobject.c' to sources.
#       adding 'build/src.macosx-10.15-x86_64-3.9/build/src.macosx-10.15-x86_64-3.9/scipy/io' to include_dirs.
#     building extension "scipy.io.matlab.streams" sources
#     building extension "scipy.io.matlab.mio_utils" sources
#     building extension "scipy.io.matlab.mio5_utils" sources
#     building extension "scipy.linalg._fblas" sources
#     f2py options: []
#       adding 'build/src.macosx-10.15-x86_64-3.9/build/src.macosx-10.15-x86_64-3.9/build/src.macosx-10.15-x86_64-3.9/scipy/linalg/fortranobject.c' to sources.
#       adding 'build/src.macosx-10.15-x86_64-3.9/build/src.macosx-10.15-x86_64-3.9/build/src.macosx-10.15-x86_64-3.9/scipy/linalg' to include_dirs.
#       adding 'build/src.macosx-10.15-x86_64-3.9/build/src.macosx-10.15-x86_64-3.9/scipy/linalg/_fblas-f2pywrappers.f' to sources.
#     building extension "scipy.linalg._flapack" sources
#     f2py options: []
#       adding 'build/src.macosx-10.15-x86_64-3.9/build/src.macosx-10.15-x86_64-3.9/build/src.macosx-10.15-x86_64-3.9/scipy/linalg/fortranobject.c' to sources.
#       adding 'build/src.macosx-10.15-x86_64-3.9/build/src.macosx-10.15-x86_64-3.9/build/src.macosx-10.15-x86_64-3.9/scipy/linalg' to include_dirs.
#       adding 'build/src.macosx-10.15-x86_64-3.9/build/src.macosx-10.15-x86_64-3.9/scipy/linalg/_flapack-f2pywrappers.f' to sources.
#     building extension "scipy.linalg._flinalg" sources
#     f2py options: []
#       adding 'build/src.macosx-10.15-x86_64-3.9/build/src.macosx-10.15-x86_64-3.9/scipy/linalg/fortranobject.c' to sources.
#       adding 'build/src.macosx-10.15-x86_64-3.9/build/src.macosx-10.15-x86_64-3.9/scipy/linalg' to include_dirs.
#     building extension "scipy.linalg._interpolative" sources
#     f2py options: []
#       adding 'build/src.macosx-10.15-x86_64-3.9/build/src.macosx-10.15-x86_64-3.9/scipy/linalg/fortranobject.c' to sources.
#       adding 'build/src.macosx-10.15-x86_64-3.9/build/src.macosx-10.15-x86_64-3.9/scipy/linalg' to include_dirs.
#     building extension "scipy.linalg._solve_toeplitz" sources
#     building extension "scipy.linalg.cython_blas" sources
#     building extension "scipy.linalg.cython_lapack" sources
#     building extension "scipy.linalg._decomp_update" sources
#     building extension "scipy.odr.__odrpack" sources
#     building extension "scipy.optimize._minpack" sources
#     building extension "scipy.optimize._lsap_module" sources
#     building extension "scipy.optimize._zeros" sources
#     building extension "scipy.optimize._lbfgsb" sources
#     f2py options: []
#       adding 'build/src.macosx-10.15-x86_64-3.9/build/src.macosx-10.15-x86_64-3.9/scipy/optimize/lbfgsb_src/fortranobject.c' to sources.
#       adding 'build/src.macosx-10.15-x86_64-3.9/build/src.macosx-10.15-x86_64-3.9/scipy/optimize/lbfgsb_src' to include_dirs.
#       adding 'build/src.macosx-10.15-x86_64-3.9/scipy/optimize/lbfgsb_src/_lbfgsb-f2pywrappers.f' to sources.
#     building extension "scipy.optimize.moduleTNC" sources
#     building extension "scipy.optimize._cobyla" sources
#     f2py options: []
#       adding 'build/src.macosx-10.15-x86_64-3.9/build/src.macosx-10.15-x86_64-3.9/scipy/optimize/cobyla/fortranobject.c' to sources.
#       adding 'build/src.macosx-10.15-x86_64-3.9/build/src.macosx-10.15-x86_64-3.9/scipy/optimize/cobyla' to include_dirs.
#     building extension "scipy.optimize.minpack2" sources
#     f2py options: []
#       adding 'build/src.macosx-10.15-x86_64-3.9/build/src.macosx-10.15-x86_64-3.9/scipy/optimize/minpack2/fortranobject.c' to sources.
#       adding 'build/src.macosx-10.15-x86_64-3.9/build/src.macosx-10.15-x86_64-3.9/scipy/optimize/minpack2' to include_dirs.
#     building extension "scipy.optimize._slsqp" sources
#     f2py options: []
#       adding 'build/src.macosx-10.15-x86_64-3.9/build/src.macosx-10.15-x86_64-3.9/scipy/optimize/slsqp/fortranobject.c' to sources.
#       adding 'build/src.macosx-10.15-x86_64-3.9/build/src.macosx-10.15-x86_64-3.9/scipy/optimize/slsqp' to include_dirs.
#     building extension "scipy.optimize.__nnls" sources
#     f2py options: []
#       adding 'build/src.macosx-10.15-x86_64-3.9/build/src.macosx-10.15-x86_64-3.9/scipy/optimize/__nnls/fortranobject.c' to sources.
#       adding 'build/src.macosx-10.15-x86_64-3.9/build/src.macosx-10.15-x86_64-3.9/scipy/optimize/__nnls' to include_dirs.
#     building extension "scipy.optimize._group_columns" sources
#     building extension "scipy.optimize._bglu_dense" sources
#     building extension "scipy.optimize._lsq.givens_elimination" sources
#     building extension "scipy.optimize._trlib._trlib" sources
#     building extension "scipy.optimize.cython_optimize._zeros" sources
#     building extension "scipy.signal.sigtools" sources
#     building extension "scipy.signal._spectral" sources
#     building extension "scipy.signal._max_len_seq_inner" sources
#     building extension "scipy.signal._peak_finding_utils" sources
#     building extension "scipy.signal._sosfilt" sources
#     building extension "scipy.signal._upfirdn_apply" sources
#     building extension "scipy.signal.spline" sources
#     building extension "scipy.sparse.linalg.isolve._iterative" sources
#     f2py options: []
#       adding 'build/src.macosx-10.15-x86_64-3.9/build/src.macosx-10.15-x86_64-3.9/build/src.macosx-10.15-x86_64-3.9/scipy/sparse/linalg/isolve/iterative/fortranobject.c' to sources.
#       adding 'build/src.macosx-10.15-x86_64-3.9/build/src.macosx-10.15-x86_64-3.9/build/src.macosx-10.15-x86_64-3.9/scipy/sparse/linalg/isolve/iterative' to include_dirs.
#     building extension "scipy.sparse.linalg.dsolve._superlu" sources
#     building extension "scipy.sparse.linalg.eigen.arpack._arpack" sources
#     f2py options: []
#       adding 'build/src.macosx-10.15-x86_64-3.9/build/src.macosx-10.15-x86_64-3.9/build/src.macosx-10.15-x86_64-3.9/scipy/sparse/linalg/eigen/arpack/fortranobject.c' to sources.
#       adding 'build/src.macosx-10.15-x86_64-3.9/build/src.macosx-10.15-x86_64-3.9/build/src.macosx-10.15-x86_64-3.9/scipy/sparse/linalg/eigen/arpack' to include_dirs.
#       adding 'build/src.macosx-10.15-x86_64-3.9/build/src.macosx-10.15-x86_64-3.9/scipy/sparse/linalg/eigen/arpack/_arpack-f2pywrappers.f' to sources.
#     building extension "scipy.sparse.csgraph._shortest_path" sources
#     building extension "scipy.sparse.csgraph._traversal" sources
#     building extension "scipy.sparse.csgraph._min_spanning_tree" sources
#     building extension "scipy.sparse.csgraph._matching" sources
#     building extension "scipy.sparse.csgraph._flow" sources
#     building extension "scipy.sparse.csgraph._reordering" sources
#     building extension "scipy.sparse.csgraph._tools" sources
#     building extension "scipy.sparse._csparsetools" sources
#     building extension "scipy.sparse._sparsetools" sources
#     [generate_sparsetools] '/private/var/folders/5m/z78sg2m56qj87c1075qmwq780000gn/T/pip-install-9ejr9b05/scipy/scipy/sparse/sparsetools/bsr_impl.h' already up-to-date
#     [generate_sparsetools] '/private/var/folders/5m/z78sg2m56qj87c1075qmwq780000gn/T/pip-install-9ejr9b05/scipy/scipy/sparse/sparsetools/csr_impl.h' already up-to-date
#     [generate_sparsetools] '/private/var/folders/5m/z78sg2m56qj87c1075qmwq780000gn/T/pip-install-9ejr9b05/scipy/scipy/sparse/sparsetools/csc_impl.h' already up-to-date
#     [generate_sparsetools] '/private/var/folders/5m/z78sg2m56qj87c1075qmwq780000gn/T/pip-install-9ejr9b05/scipy/scipy/sparse/sparsetools/other_impl.h' already up-to-date
#     [generate_sparsetools] '/private/var/folders/5m/z78sg2m56qj87c1075qmwq780000gn/T/pip-install-9ejr9b05/scipy/scipy/sparse/sparsetools/sparsetools_impl.h' already up-to-date
#     building extension "scipy.spatial.qhull" sources
#     building extension "scipy.spatial.ckdtree" sources
#     building extension "scipy.spatial._distance_wrap" sources
#     building extension "scipy.spatial._voronoi" sources
#     building extension "scipy.spatial._hausdorff" sources
#     building extension "scipy.special.specfun" sources
#     f2py options: ['--no-wrap-functions']
#       adding 'build/src.macosx-10.15-x86_64-3.9/build/src.macosx-10.15-x86_64-3.9/scipy/special/fortranobject.c' to sources.
#       adding 'build/src.macosx-10.15-x86_64-3.9/build/src.macosx-10.15-x86_64-3.9/scipy/special' to include_dirs.
#     building extension "scipy.special._ufuncs" sources
#     building extension "scipy.special._ufuncs_cxx" sources
#     building extension "scipy.special._ellip_harm_2" sources
#     building extension "scipy.special.cython_special" sources
#     building extension "scipy.special._comb" sources
#     building extension "scipy.special._test_round" sources
#     building extension "scipy.stats.statlib" sources
#     f2py options: ['--no-wrap-functions']
#       adding 'build/src.macosx-10.15-x86_64-3.9/build/src.macosx-10.15-x86_64-3.9/scipy/stats/fortranobject.c' to sources.
#       adding 'build/src.macosx-10.15-x86_64-3.9/build/src.macosx-10.15-x86_64-3.9/scipy/stats' to include_dirs.
#     building extension "scipy.stats._stats" sources
#     building extension "scipy.stats.mvn" sources
#     f2py options: []
#       adding 'build/src.macosx-10.15-x86_64-3.9/build/src.macosx-10.15-x86_64-3.9/scipy/stats/fortranobject.c' to sources.
#       adding 'build/src.macosx-10.15-x86_64-3.9/build/src.macosx-10.15-x86_64-3.9/scipy/stats' to include_dirs.
#       adding 'build/src.macosx-10.15-x86_64-3.9/scipy/stats/mvn-f2pywrappers.f' to sources.
#     building extension "scipy.ndimage._nd_image" sources
#     building extension "scipy.ndimage._ni_label" sources
#     building extension "scipy.ndimage._ctest" sources
#     building extension "scipy.ndimage._ctest_oldapi" sources
#     building extension "scipy.ndimage._cytest" sources
#     building extension "scipy._lib._ccallback_c" sources
#     building extension "scipy._lib._test_ccallback" sources
#     building extension "scipy._lib._fpumode" sources
#     building extension "scipy._lib.messagestream" sources
#     get_default_fcompiler: matching types: '['gnu95', 'nag', 'absoft', 'ibm', 'intel', 'gnu', 'g95', 'pg']'
#     customize Gnu95FCompiler
#     Could not locate executable gfortran
#     Could not locate executable f95
#     customize NAGFCompiler
#     customize AbsoftFCompiler
#     Could not locate executable f90
#     Could not locate executable f77
#     customize IBMFCompiler
#     Could not locate executable xlf90
#     Could not locate executable xlf
#     customize IntelFCompiler
#     Could not locate executable ifort
#     Could not locate executable ifc
#     customize GnuFCompiler
#     Could not locate executable g77
#     customize G95FCompiler
#     Could not locate executable g95
#     customize PGroupFCompiler
#     Could not locate executable pgfortran
#     don't know how to compile Fortran code on platform 'posix'
#     C compiler: clang -Wno-unused-result -Wsign-compare -Wunreachable-code -fno-common -dynamic -DNDEBUG -g -fwrapv -O3 -Wall -isysroot /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk -I/Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include -I/Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/System/Library/Frameworks/Tk.framework/Versions/8.5/Headers
#
#     compile options: '-I/usr/local/include -I/usr/local/opt/openssl@1.1/include -I/usr/local/opt/sqlite/include -I/usr/local/Cellar/python@3.9/3.9.0_1/Frameworks/Python.framework/Versions/3.9/include/python3.9 -c'
#     clang: _configtest.c
#     clang _configtest.o -o _configtest
#     success!
#     removing: _configtest.c _configtest.o _configtest.o.d _configtest
#     building extension "scipy._lib._test_deprecation_call" sources
#     building extension "scipy._lib._test_deprecation_def" sources
#     building extension "scipy._lib._uarray._uarray" sources
#     building data_files sources
#     build_src: building npy-pkg config files
#     running build_py
#     creating build/lib.macosx-10.15-x86_64-3.9
#     creating build/lib.macosx-10.15-x86_64-3.9/scipy
#     copying scipy/conftest.py -> build/lib.macosx-10.15-x86_64-3.9/scipy
#     copying scipy/version.py -> build/lib.macosx-10.15-x86_64-3.9/scipy
#     copying scipy/__init__.py -> build/lib.macosx-10.15-x86_64-3.9/scipy
#     copying scipy/_distributor_init.py -> build/lib.macosx-10.15-x86_64-3.9/scipy
#     copying scipy/setup.py -> build/lib.macosx-10.15-x86_64-3.9/scipy
#     copying build/src.macosx-10.15-x86_64-3.9/scipy/__config__.py -> build/lib.macosx-10.15-x86_64-3.9/scipy
#     creating build/lib.macosx-10.15-x86_64-3.9/scipy/cluster
#     copying scipy/cluster/vq.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/cluster
#     copying scipy/cluster/__init__.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/cluster
#     copying scipy/cluster/hierarchy.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/cluster
#     copying scipy/cluster/setup.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/cluster
#     creating build/lib.macosx-10.15-x86_64-3.9/scipy/constants
#     copying scipy/constants/constants.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/constants
#     copying scipy/constants/__init__.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/constants
#     copying scipy/constants/codata.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/constants
#     copying scipy/constants/setup.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/constants
#     creating build/lib.macosx-10.15-x86_64-3.9/scipy/fft
#     copying scipy/fft/_backend.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/fft
#     copying scipy/fft/_helper.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/fft
#     copying scipy/fft/__init__.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/fft
#     copying scipy/fft/setup.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/fft
#     copying scipy/fft/_debug_backends.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/fft
#     copying scipy/fft/_realtransforms.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/fft
#     copying scipy/fft/_basic.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/fft
#     creating build/lib.macosx-10.15-x86_64-3.9/scipy/fft/_pocketfft
#     copying scipy/fft/_pocketfft/__init__.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/fft/_pocketfft
#     copying scipy/fft/_pocketfft/setup.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/fft/_pocketfft
#     copying scipy/fft/_pocketfft/realtransforms.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/fft/_pocketfft
#     copying scipy/fft/_pocketfft/basic.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/fft/_pocketfft
#     copying scipy/fft/_pocketfft/helper.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/fft/_pocketfft
#     creating build/lib.macosx-10.15-x86_64-3.9/scipy/fftpack
#     copying scipy/fftpack/__init__.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/fftpack
#     copying scipy/fftpack/pseudo_diffs.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/fftpack
#     copying scipy/fftpack/setup.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/fftpack
#     copying scipy/fftpack/realtransforms.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/fftpack
#     copying scipy/fftpack/basic.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/fftpack
#     copying scipy/fftpack/helper.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/fftpack
#     creating build/lib.macosx-10.15-x86_64-3.9/scipy/integrate
#     copying scipy/integrate/_ode.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/integrate
#     copying scipy/integrate/_quadrature.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/integrate
#     copying scipy/integrate/__init__.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/integrate
#     copying scipy/integrate/quadpack.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/integrate
#     copying scipy/integrate/_quad_vec.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/integrate
#     copying scipy/integrate/setup.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/integrate
#     copying scipy/integrate/_bvp.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/integrate
#     copying scipy/integrate/odepack.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/integrate
#     creating build/lib.macosx-10.15-x86_64-3.9/scipy/integrate/_ivp
#     copying scipy/integrate/_ivp/bdf.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/integrate/_ivp
#     copying scipy/integrate/_ivp/ivp.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/integrate/_ivp
#     copying scipy/integrate/_ivp/dop853_coefficients.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/integrate/_ivp
#     copying scipy/integrate/_ivp/__init__.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/integrate/_ivp
#     copying scipy/integrate/_ivp/setup.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/integrate/_ivp
#     copying scipy/integrate/_ivp/common.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/integrate/_ivp
#     copying scipy/integrate/_ivp/radau.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/integrate/_ivp
#     copying scipy/integrate/_ivp/lsoda.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/integrate/_ivp
#     copying scipy/integrate/_ivp/rk.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/integrate/_ivp
#     copying scipy/integrate/_ivp/base.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/integrate/_ivp
#     creating build/lib.macosx-10.15-x86_64-3.9/scipy/interpolate
#     copying scipy/interpolate/_cubic.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/interpolate
#     copying scipy/interpolate/polyint.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/interpolate
#     copying scipy/interpolate/ndgriddata.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/interpolate
#     copying scipy/interpolate/_bsplines.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/interpolate
#     copying scipy/interpolate/__init__.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/interpolate
#     copying scipy/interpolate/fitpack.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/interpolate
#     copying scipy/interpolate/rbf.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/interpolate
#     copying scipy/interpolate/interpnd_info.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/interpolate
#     copying scipy/interpolate/setup.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/interpolate
#     copying scipy/interpolate/_pade.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/interpolate
#     copying scipy/interpolate/interpolate.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/interpolate
#     copying scipy/interpolate/_fitpack_impl.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/interpolate
#     copying scipy/interpolate/fitpack2.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/interpolate
#     creating build/lib.macosx-10.15-x86_64-3.9/scipy/io
#     copying scipy/io/wavfile.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/io
#     copying scipy/io/idl.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/io
#     copying scipy/io/__init__.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/io
#     copying scipy/io/netcdf.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/io
#     copying scipy/io/setup.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/io
#     copying scipy/io/_fortran.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/io
#     copying scipy/io/mmio.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/io
#     creating build/lib.macosx-10.15-x86_64-3.9/scipy/io/matlab
#     copying scipy/io/matlab/miobase.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/io/matlab
#     copying scipy/io/matlab/mio5_params.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/io/matlab
#     copying scipy/io/matlab/__init__.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/io/matlab
#     copying scipy/io/matlab/setup.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/io/matlab
#     copying scipy/io/matlab/byteordercodes.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/io/matlab
#     copying scipy/io/matlab/mio.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/io/matlab
#     copying scipy/io/matlab/mio4.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/io/matlab
#     copying scipy/io/matlab/mio5.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/io/matlab
#     creating build/lib.macosx-10.15-x86_64-3.9/scipy/io/arff
#     copying scipy/io/arff/__init__.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/io/arff
#     copying scipy/io/arff/setup.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/io/arff
#     copying scipy/io/arff/arffread.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/io/arff
#     creating build/lib.macosx-10.15-x86_64-3.9/scipy/io/harwell_boeing
#     copying scipy/io/harwell_boeing/__init__.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/io/harwell_boeing
#     copying scipy/io/harwell_boeing/setup.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/io/harwell_boeing
#     copying scipy/io/harwell_boeing/_fortran_format_parser.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/io/harwell_boeing
#     copying scipy/io/harwell_boeing/hb.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/io/harwell_boeing
#     creating build/lib.macosx-10.15-x86_64-3.9/scipy/linalg
#     copying scipy/linalg/decomp_qr.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/linalg
#     copying scipy/linalg/_matfuncs_inv_ssq.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/linalg
#     copying scipy/linalg/misc.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/linalg
#     copying scipy/linalg/_sketches.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/linalg
#     copying scipy/linalg/decomp_cholesky.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/linalg
#     copying scipy/linalg/_testutils.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/linalg
#     copying scipy/linalg/decomp_lu.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/linalg
#     copying scipy/linalg/decomp_svd.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/linalg
#     copying scipy/linalg/_procrustes.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/linalg
#     copying scipy/linalg/_matfuncs_sqrtm.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/linalg
#     copying scipy/linalg/matfuncs.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/linalg
#     copying scipy/linalg/__init__.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/linalg
#     copying scipy/linalg/_generate_pyx.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/linalg
#     copying scipy/linalg/_solvers.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/linalg
#     copying scipy/linalg/_interpolative_backend.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/linalg
#     copying scipy/linalg/flinalg.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/linalg
#     copying scipy/linalg/setup.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/linalg
#     copying scipy/linalg/basic.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/linalg
#     copying scipy/linalg/_decomp_polar.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/linalg
#     copying scipy/linalg/decomp.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/linalg
#     copying scipy/linalg/interpolative.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/linalg
#     copying scipy/linalg/blas.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/linalg
#     copying scipy/linalg/_cython_signature_generator.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/linalg
#     copying scipy/linalg/special_matrices.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/linalg
#     copying scipy/linalg/_decomp_ldl.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/linalg
#     copying scipy/linalg/_decomp_cossin.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/linalg
#     copying scipy/linalg/decomp_schur.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/linalg
#     copying scipy/linalg/_decomp_qz.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/linalg
#     copying scipy/linalg/_expm_frechet.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/linalg
#     copying scipy/linalg/lapack.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/linalg
#     creating build/lib.macosx-10.15-x86_64-3.9/scipy/misc
#     copying scipy/misc/__init__.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/misc
#     copying scipy/misc/setup.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/misc
#     copying scipy/misc/common.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/misc
#     copying scipy/misc/doccer.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/misc
#     creating build/lib.macosx-10.15-x86_64-3.9/scipy/odr
#     copying scipy/odr/_add_newdocs.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/odr
#     copying scipy/odr/models.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/odr
#     copying scipy/odr/odrpack.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/odr
#     copying scipy/odr/__init__.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/odr
#     copying scipy/odr/setup.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/odr
#     creating build/lib.macosx-10.15-x86_64-3.9/scipy/optimize
#     copying scipy/optimize/tnc.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/optimize
#     copying scipy/optimize/_lsap.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/optimize
#     copying scipy/optimize/optimize.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/optimize
#     copying scipy/optimize/_linprog_ip.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/optimize
#     copying scipy/optimize/linesearch.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/optimize
#     copying scipy/optimize/nonlin.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/optimize
#     copying scipy/optimize/_linprog_rs.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/optimize
#     copying scipy/optimize/_root.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/optimize
#     copying scipy/optimize/lbfgsb.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/optimize
#     copying scipy/optimize/zeros.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/optimize
#     copying scipy/optimize/_shgo.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/optimize
#     copying scipy/optimize/_linprog_simplex.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/optimize
#     copying scipy/optimize/slsqp.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/optimize
#     copying scipy/optimize/_trustregion_ncg.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/optimize
#     copying scipy/optimize/_minimize.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/optimize
#     copying scipy/optimize/minpack.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/optimize
#     copying scipy/optimize/_basinhopping.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/optimize
#     copying scipy/optimize/_linprog.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/optimize
#     copying scipy/optimize/_hessian_update_strategy.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/optimize
#     copying scipy/optimize/__init__.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/optimize
#     copying scipy/optimize/cobyla.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/optimize
#     copying scipy/optimize/_tstutils.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/optimize
#     copying scipy/optimize/_nnls.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/optimize
#     copying scipy/optimize/_spectral.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/optimize
#     copying scipy/optimize/_differentiable_functions.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/optimize
#     copying scipy/optimize/_trustregion_krylov.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/optimize
#     copying scipy/optimize/_trustregion.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/optimize
#     copying scipy/optimize/setup.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/optimize
#     copying scipy/optimize/_linprog_util.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/optimize
#     copying scipy/optimize/_dual_annealing.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/optimize
#     copying scipy/optimize/_root_scalar.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/optimize
#     copying scipy/optimize/_trustregion_dogleg.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/optimize
#     copying scipy/optimize/_trustregion_exact.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/optimize
#     copying scipy/optimize/_constraints.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/optimize
#     copying scipy/optimize/_differentialevolution.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/optimize
#     copying scipy/optimize/_remove_redundancy.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/optimize
#     copying scipy/optimize/_numdiff.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/optimize
#     creating build/lib.macosx-10.15-x86_64-3.9/scipy/optimize/_lsq
#     copying scipy/optimize/_lsq/least_squares.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/optimize/_lsq
#     copying scipy/optimize/_lsq/dogbox.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/optimize/_lsq
#     copying scipy/optimize/_lsq/__init__.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/optimize/_lsq
#     copying scipy/optimize/_lsq/trf_linear.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/optimize/_lsq
#     copying scipy/optimize/_lsq/setup.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/optimize/_lsq
#     copying scipy/optimize/_lsq/common.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/optimize/_lsq
#     copying scipy/optimize/_lsq/lsq_linear.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/optimize/_lsq
#     copying scipy/optimize/_lsq/bvls.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/optimize/_lsq
#     copying scipy/optimize/_lsq/trf.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/optimize/_lsq
#     creating build/lib.macosx-10.15-x86_64-3.9/scipy/optimize/_trlib
#     copying scipy/optimize/_trlib/__init__.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/optimize/_trlib
#     copying scipy/optimize/_trlib/setup.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/optimize/_trlib
#     creating build/lib.macosx-10.15-x86_64-3.9/scipy/optimize/_trustregion_constr
#     copying scipy/optimize/_trustregion_constr/equality_constrained_sqp.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/optimize/_trustregion_constr
#     copying scipy/optimize/_trustregion_constr/__init__.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/optimize/_trustregion_constr
#     copying scipy/optimize/_trustregion_constr/setup.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/optimize/_trustregion_constr
#     copying scipy/optimize/_trustregion_constr/tr_interior_point.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/optimize/_trustregion_constr
#     copying scipy/optimize/_trustregion_constr/qp_subproblem.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/optimize/_trustregion_constr
#     copying scipy/optimize/_trustregion_constr/minimize_trustregion_constr.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/optimize/_trustregion_constr
#     copying scipy/optimize/_trustregion_constr/projections.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/optimize/_trustregion_constr
#     copying scipy/optimize/_trustregion_constr/report.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/optimize/_trustregion_constr
#     copying scipy/optimize/_trustregion_constr/canonical_constraint.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/optimize/_trustregion_constr
#     creating build/lib.macosx-10.15-x86_64-3.9/scipy/optimize/cython_optimize
#     copying scipy/optimize/cython_optimize/__init__.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/optimize/cython_optimize
#     creating build/lib.macosx-10.15-x86_64-3.9/scipy/optimize/_shgo_lib
# ...
#     copying scipy/sparse/setup.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/sparse
#     copying scipy/sparse/_matrix_io.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/sparse
#     copying scipy/sparse/csr.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/sparse
#     copying scipy/sparse/construct.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/sparse
#     copying scipy/sparse/extract.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/sparse
#     copying scipy/sparse/base.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/sparse
#     copying scipy/sparse/data.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/sparse
#     creating build/lib.macosx-10.15-x86_64-3.9/scipy/sparse/linalg
#     copying scipy/sparse/linalg/matfuncs.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/sparse/linalg
#     copying scipy/sparse/linalg/interface.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/sparse/linalg
#     copying scipy/sparse/linalg/_expm_multiply.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/sparse/linalg
#     copying scipy/sparse/linalg/__init__.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/sparse/linalg
#     copying scipy/sparse/linalg/setup.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/sparse/linalg
#     copying scipy/sparse/linalg/_norm.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/sparse/linalg
#     copying scipy/sparse/linalg/_onenormest.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/sparse/linalg
#     creating build/lib.macosx-10.15-x86_64-3.9/scipy/sparse/linalg/isolve
#     copying scipy/sparse/linalg/isolve/lsqr.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/sparse/linalg/isolve
#     copying scipy/sparse/linalg/isolve/__init__.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/sparse/linalg/isolve
#     copying scipy/sparse/linalg/isolve/setup.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/sparse/linalg/isolve
#     copying scipy/sparse/linalg/isolve/iterative.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/sparse/linalg/isolve
#     copying scipy/sparse/linalg/isolve/utils.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/sparse/linalg/isolve
#     copying scipy/sparse/linalg/isolve/_gcrotmk.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/sparse/linalg/isolve
#     copying scipy/sparse/linalg/isolve/minres.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/sparse/linalg/isolve
#     copying scipy/sparse/linalg/isolve/lsmr.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/sparse/linalg/isolve
#     copying scipy/sparse/linalg/isolve/lgmres.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/sparse/linalg/isolve
#     creating build/lib.macosx-10.15-x86_64-3.9/scipy/sparse/linalg/dsolve
#     copying scipy/sparse/linalg/dsolve/_add_newdocs.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/sparse/linalg/dsolve
#     copying scipy/sparse/linalg/dsolve/linsolve.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/sparse/linalg/dsolve
#     copying scipy/sparse/linalg/dsolve/__init__.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/sparse/linalg/dsolve
#     copying scipy/sparse/linalg/dsolve/setup.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/sparse/linalg/dsolve
#     creating build/lib.macosx-10.15-x86_64-3.9/scipy/sparse/linalg/eigen
#     copying scipy/sparse/linalg/eigen/__init__.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/sparse/linalg/eigen
#     copying scipy/sparse/linalg/eigen/setup.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/sparse/linalg/eigen
#     creating build/lib.macosx-10.15-x86_64-3.9/scipy/sparse/linalg/eigen/arpack
#     copying scipy/sparse/linalg/eigen/arpack/__init__.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/sparse/linalg/eigen/arpack
#     copying scipy/sparse/linalg/eigen/arpack/setup.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/sparse/linalg/eigen/arpack
#     copying scipy/sparse/linalg/eigen/arpack/arpack.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/sparse/linalg/eigen/arpack
#     creating build/lib.macosx-10.15-x86_64-3.9/scipy/sparse/linalg/eigen/lobpcg
#     copying scipy/sparse/linalg/eigen/lobpcg/lobpcg.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/sparse/linalg/eigen/lobpcg
#     copying scipy/sparse/linalg/eigen/lobpcg/__init__.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/sparse/linalg/eigen/lobpcg
#     copying scipy/sparse/linalg/eigen/lobpcg/setup.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/sparse/linalg/eigen/lobpcg
#     creating build/lib.macosx-10.15-x86_64-3.9/scipy/sparse/csgraph
#     copying scipy/sparse/csgraph/_laplacian.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/sparse/csgraph
#     copying scipy/sparse/csgraph/__init__.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/sparse/csgraph
#     copying scipy/sparse/csgraph/setup.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/sparse/csgraph
#     copying scipy/sparse/csgraph/_validation.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/sparse/csgraph
#     creating build/lib.macosx-10.15-x86_64-3.9/scipy/spatial
#     copying scipy/spatial/_spherical_voronoi.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/spatial
#     copying scipy/spatial/_procrustes.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/spatial
#     copying scipy/spatial/__init__.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/spatial
#     copying scipy/spatial/distance.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/spatial
#     copying scipy/spatial/kdtree.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/spatial
#     copying scipy/spatial/setup.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/spatial
#     copying scipy/spatial/_geometric_slerp.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/spatial
#     copying scipy/spatial/_plotutils.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/spatial
#     creating build/lib.macosx-10.15-x86_64-3.9/scipy/spatial/transform
#     copying scipy/spatial/transform/__init__.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/spatial/transform
#     copying scipy/spatial/transform/setup.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/spatial/transform
#     copying scipy/spatial/transform/_rotation_spline.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/spatial/transform
#     copying scipy/spatial/transform/rotation.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/spatial/transform
#     copying scipy/spatial/transform/_rotation_groups.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/spatial/transform
#     creating build/lib.macosx-10.15-x86_64-3.9/scipy/special
#     copying scipy/special/spfun_stats.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/special
#     copying scipy/special/_testutils.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/special
#     copying scipy/special/sf_error.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/special
#     copying scipy/special/add_newdocs.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/special
#     copying scipy/special/_spherical_bessel.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/special
#     copying scipy/special/_mptestutils.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/special
#     copying scipy/special/__init__.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/special
#     copying scipy/special/_ellip_harm.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/special
#     copying scipy/special/_generate_pyx.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/special
#     copying scipy/special/setup.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/special
#     copying scipy/special/_lambertw.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/special
#     copying scipy/special/basic.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/special
#     copying scipy/special/orthogonal.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/special
#     copying scipy/special/_basic.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/special
#     copying scipy/special/_logsumexp.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/special
#     creating build/lib.macosx-10.15-x86_64-3.9/scipy/special/_precompute
#     copying scipy/special/_precompute/expn_asy.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/special/_precompute
#     copying scipy/special/_precompute/zetac.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/special/_precompute
#     copying scipy/special/_precompute/struve_convergence.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/special/_precompute
#     copying scipy/special/_precompute/loggamma.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/special/_precompute
#     copying scipy/special/_precompute/gammainc_asy.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/special/_precompute
#     copying scipy/special/_precompute/wrightomega.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/special/_precompute
#     copying scipy/special/_precompute/gammainc_data.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/special/_precompute
#     copying scipy/special/_precompute/__init__.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/special/_precompute
#     copying scipy/special/_precompute/setup.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/special/_precompute
#     copying scipy/special/_precompute/utils.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/special/_precompute
#     copying scipy/special/_precompute/lambertw.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/special/_precompute
#     creating build/lib.macosx-10.15-x86_64-3.9/scipy/stats
#     copying scipy/stats/_multivariate.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/stats
#     copying scipy/stats/_constants.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/stats
#     copying scipy/stats/_binned_statistic.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/stats
#     copying scipy/stats/_distr_params.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/stats
#     copying scipy/stats/_tukeylambda_stats.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/stats
#     copying scipy/stats/_rvs_sampling.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/stats
#     copying scipy/stats/_stats_mstats_common.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/stats
#     copying scipy/stats/_ksstats.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/stats
#     copying scipy/stats/kde.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/stats
#     copying scipy/stats/__init__.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/stats
#     copying scipy/stats/mstats_extras.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/stats
#     copying scipy/stats/_discrete_distns.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/stats
#     copying scipy/stats/distributions.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/stats
#     copying scipy/stats/_hypotests.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/stats
#     copying scipy/stats/setup.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/stats
#     copying scipy/stats/mstats.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/stats
#     copying scipy/stats/_distn_infrastructure.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/stats
#     copying scipy/stats/stats.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/stats
#     copying scipy/stats/_continuous_distns.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/stats
#     copying scipy/stats/morestats.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/stats
#     copying scipy/stats/mstats_basic.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/stats
#     copying scipy/stats/contingency.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/stats
#     copying scipy/stats/_wilcoxon_data.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/stats
#     creating build/lib.macosx-10.15-x86_64-3.9/scipy/ndimage
#     copying scipy/ndimage/_ni_support.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/ndimage
#     copying scipy/ndimage/interpolation.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/ndimage
#     copying scipy/ndimage/_ni_docstrings.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/ndimage
#     copying scipy/ndimage/__init__.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/ndimage
#     copying scipy/ndimage/morphology.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/ndimage
#     copying scipy/ndimage/setup.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/ndimage
#     copying scipy/ndimage/fourier.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/ndimage
#     copying scipy/ndimage/filters.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/ndimage
#     copying scipy/ndimage/measurements.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/ndimage
#     creating build/lib.macosx-10.15-x86_64-3.9/scipy/_build_utils
#     copying scipy/_build_utils/system_info.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/_build_utils
#     copying scipy/_build_utils/__init__.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/_build_utils
#     copying scipy/_build_utils/setup.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/_build_utils
#     copying scipy/_build_utils/_fortran.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/_build_utils
#     copying scipy/_build_utils/compiler_helper.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/_build_utils
#     creating build/lib.macosx-10.15-x86_64-3.9/scipy/_lib
#     copying scipy/_lib/uarray.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/_lib
#     copying scipy/_lib/_testutils.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/_lib
#     copying scipy/_lib/_pep440.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/_lib
#     copying scipy/_lib/deprecation.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/_lib
#     copying scipy/_lib/decorator.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/_lib
#     copying scipy/_lib/__init__.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/_lib
#     copying scipy/_lib/_ccallback.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/_lib
#     copying scipy/_lib/_threadsafety.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/_lib
#     copying scipy/_lib/setup.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/_lib
#     copying scipy/_lib/_tmpdirs.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/_lib
#     copying scipy/_lib/_util.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/_lib
#     copying scipy/_lib/_gcutils.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/_lib
#     copying scipy/_lib/doccer.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/_lib
#     creating build/lib.macosx-10.15-x86_64-3.9/scipy/_lib/_uarray
#     copying scipy/_lib/_uarray/_backend.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/_lib/_uarray
#     copying scipy/_lib/_uarray/__init__.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/_lib/_uarray
#     copying scipy/_lib/_uarray/setup.py -> build/lib.macosx-10.15-x86_64-3.9/scipy/_lib/_uarray
#     running build_clib
#     customize UnixCCompiler
#     #### ['clang', '-Wno-unused-result', '-Wsign-compare', '-Wunreachable-code', '-fno-common', '-dynamic', '-DNDEBUG', '-g', '-fwrapv', '-O3', '-Wall', '-isysroot', '/Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk', '-I/Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include', '-I/Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/System/Library/Frameworks/Tk.framework/Versions/8.5/Headers'] #######
#     customize UnixCCompiler using build_clib
#     building 'mach' library
#     error: library mach has Fortran sources but no Fortran compiler found
#     ----------------------------------------
#     ERROR: Failed building wheel for scipy
#   Failed to build scipy
#   ERROR: Could not build wheels for scipy which use PEP 517 and cannot be installed directly
#   ----------------------------------------
# ERROR: Command errored out with exit status 1: /usr/local/opt/python@3.9/bin/python3.9 /usr/local/lib/python3.9/site-packages/pip install --ignore-installed --no-user --prefix /private/var/folders/5m/z78sg2m56qj87c1075qmwq780000gn/T/pip-build-env-4i4iwci_/overlay --no-warn-script-location --no-binary :none: --only-binary :none: -i https://pypi.org/simple -- setuptools wheel 'Cython>=0.28.5' 'numpy==1.13.3; python_version=='"'"'3.6'"'"' and platform_system!='"'"'AIX'"'"' and platform_python_implementation == '"'"'CPython'"'"'' 'numpy==1.14.0; python_version=='"'"'3.6'"'"' and platform_system!='"'"'AIX'"'"' and platform_python_implementation != '"'"'CPython'"'"'' 'numpy==1.14.5; python_version=='"'"'3.7'"'"' and platform_system!='"'"'AIX'"'"'' 'numpy==1.17.3; python_version>='"'"'3.8'"'"' and platform_system!='"'"'AIX'"'"'' 'numpy==1.16.0; python_version=='"'"'3.6'"'"' and platform_system=='"'"'AIX'"'"'' 'numpy==1.16.0; python_version=='"'"'3.7'"'"' and platform_system=='"'"'AIX'"'"'' 'numpy==1.17.3; python_version>='"'"'3.8'"'"' and platform_system=='"'"'AIX'"'"'' 'scipy>=0.19.1' Check the logs for full command output.

# %%
from platform import python_version
print(python_version())
# Out:
# 3.8.3

# %%
conda install mlxtend
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: failed with initial frozen solve. Retrying with flexible solve.
# Collecting package metadata (repodata.json): done
# Solving environment: failed with initial frozen solve. Retrying with flexible solve.
#
# PackagesNotFoundError: The following packages are not available from current channels:
#
#   - mlxtend
#
# Current channels:
#
#   - https://repo.anaconda.com/pkgs/main/osx-64
#   - https://repo.anaconda.com/pkgs/main/noarch
#   - https://repo.anaconda.com/pkgs/r/osx-64
#   - https://repo.anaconda.com/pkgs/r/noarch
#
# To search for alternate channels that may provide the conda package you're
# looking for, navigate to
#
#     https://anaconda.org
#
# and use the search bar at the top of the page.
#
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
conda install -c conda-forge mlxtend
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.8.3
#   latest version: 4.9.1
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# ## Package Plan ##
#
#   environment location: /usr/local/anaconda3
#
#   added / updated specs:
#     - mlxtend
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     conda-4.9.0                |   py38h5347e94_1         3.0 MB  conda-forge
#     mlxtend-0.17.3             |     pyh9f0ad1d_0         1.2 MB  conda-forge
#     python_abi-3.8             |           1_cp38           4 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         4.3 MB
#
# The following NEW packages will be INSTALLED:
#
#   mlxtend            conda-forge/noarch::mlxtend-0.17.3-pyh9f0ad1d_0
#   python_abi         conda-forge/osx-64::python_abi-3.8-1_cp38
#
# The following packages will be UPDATED:
#
#   conda                       pkgs/main::conda-4.8.3-py38_0 --> conda-forge::conda-4.9.0-py38h5347e94_1
#
#
#
# Downloading and Extracting Packages
# conda-4.9.0          | 3.0 MB    | ##################################### | 100%
# python_abi-3.8       | 4 KB      | ##################################### | 100%
# mlxtend-0.17.3       | 1.2 MB    | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: - WARNING conda.core.path_actions:verify(962): Unable to create environments file. Path not writable.
#   environment location: /Users/thomaschenu/.conda/environments.txt
#
# done
# Executing transaction: done
#
# Note: you may need to restart the kernel to use updated packages.

# %%
conda install -c conda-forge xgboost
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: failed with initial frozen solve. Retrying with flexible solve.
# Solving environment: failed with repodata from current_repodata.json, will retry with next repodata source.
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /usr/local/anaconda3
#
#   added / updated specs:
#     - xgboost
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     _py-xgboost-mutex-2.0      |            cpu_0           8 KB  conda-forge
#     libxgboost-1.1.1           |       h4a8c4bd_0         1.9 MB  conda-forge
#     py-xgboost-1.1.1           |   py38h32f6830_0         1.0 MB  conda-forge
#     xgboost-1.1.1              |   py38hc84c608_0          11 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         3.0 MB
#
# The following NEW packages will be INSTALLED:
#
#   _py-xgboost-mutex  conda-forge/osx-64::_py-xgboost-mutex-2.0-cpu_0
#   libxgboost         conda-forge/osx-64::libxgboost-1.1.1-h4a8c4bd_0
#   py-xgboost         conda-forge/osx-64::py-xgboost-1.1.1-py38h32f6830_0
#   xgboost            conda-forge/osx-64::xgboost-1.1.1-py38hc84c608_0
#
#
#
# Downloading and Extracting Packages
# xgboost-1.1.1        | 11 KB     | ##################################### | 100%
# libxgboost-1.1.1     | 1.9 MB    | ##################################### | 100%
# py-xgboost-1.1.1     | 1.0 MB    | ##################################### | 100%
# _py-xgboost-mutex-2. | 8 KB      | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: / WARNING conda.core.path_actions:verify(962): Unable to create environments file. Path not writable.
#   environment location: /Users/thomaschenu/.conda/environments.txt
#
# done
# Executing transaction: done
#
# Note: you may need to restart the kernel to use updated packages.

# %%
conda install -c conda-forge pycaret
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: failed with initial frozen solve. Retrying with flexible solve.
# Solving environment: failed with repodata from current_repodata.json, will retry with next repodata source.
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /usr/local/anaconda3
#
#   added / updated specs:
#     - pycaret
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     aiohttp-3.7.2              |   py38h4d0b108_0         603 KB  conda-forge
#     alembic-1.4.3              |     pyh9f0ad1d_0         111 KB  conda-forge
#     appdirs-1.4.4              |     pyh9f0ad1d_0          13 KB  conda-forge
#     async-timeout-3.0.1        |          py_1000          11 KB  conda-forge
#     boto3-1.16.10              |     pyhd8ed1ab_0          70 KB  conda-forge
#     botocore-1.19.10           |     pyhd3deb0d_0         4.1 MB  conda-forge
#     bz2file-0.98               |             py_0           9 KB  conda-forge
#     c-ares-1.16.1              |       haf1e3a3_3          92 KB  conda-forge
#     cachetools-4.1.1           |             py_0          12 KB  conda-forge
#     catalogue-1.0.0            |             py_0          10 KB  conda-forge
#     catboost-0.24              |   py38h32f6830_0        10.0 MB  conda-forge
#     chart-studio-1.1.0         |     pyh9f0ad1d_0          51 KB  conda-forge
#     colorlover-0.3.0           |             py_0          12 KB  conda-forge
#     configparser-5.0.1         |             py_0          23 KB  conda-forge
#     confuse-1.3.0              |     pyh9f0ad1d_0          20 KB  conda-forge
#     cufflinks-py-0.17.3        |             py_0           4 KB  conda-forge
#     cymem-2.0.3                |   py38hc84c608_2          33 KB  conda-forge
#     cython-blis-0.4.1          |   py38h64e0658_1         3.1 MB  conda-forge
#     databricks-cli-0.9.1       |             py_0          48 KB  conda-forge
#     datefinder-0.7.1           |     pyh9f0ad1d_0          13 KB  conda-forge
#     docker-py-4.3.1            |   py38h32f6830_1         182 KB  conda-forge
#     docker-pycreds-0.4.0       |             py_0          11 KB  conda-forge
#     funcy-1.15                 |     pyh9f0ad1d_0          29 KB  conda-forge
#     gensim-3.8.3               |   py38hc84c608_2        22.7 MB  conda-forge
#     gitdb-4.0.5                |             py_0          46 KB  conda-forge
#     gitpython-3.1.11           |             py_0         110 KB  conda-forge
#     google-api-core-1.23.0     |     pyh9f0ad1d_0          58 KB  conda-forge
#     google-auth-1.23.0         |     pyhd8ed1ab_0          62 KB  conda-forge
#     google-cloud-core-1.4.3    |     pyh9f0ad1d_0          26 KB  conda-forge
#     google-cloud-storage-1.32.0|     pyh9f0ad1d_0          64 KB  conda-forge
#     google-crc32c-1.0.0        |   py38h320b2b7_1          23 KB  conda-forge
#     google-resumable-media-1.1.0|     pyh9f0ad1d_0          40 KB  conda-forge
#     googleapis-common-protos-1.52.0|   py38h50d1736_1          70 KB  conda-forge
#     gorilla-0.3.0              |             py_0          11 KB  conda-forge
#     grpcio-1.30.0              |   py38hb05251e_0         1.9 MB  conda-forge
#     gunicorn-20.0.4            |   py38h32f6830_2         117 KB  conda-forge
#     htmlmin-0.1.12             |             py_1          21 KB  conda-forge
#     imagehash-4.1.0            |     pyh9f0ad1d_0         288 KB  conda-forge
#     imbalanced-learn-0.7.0     |             py_1          97 KB  conda-forge
#     jmespath-0.10.0            |     pyh9f0ad1d_0          21 KB  conda-forge
#     kmodes-0.10.2              |     pyh9f0ad1d_0          18 KB  conda-forge
#     libcrc32c-1.1.1            |       hb1e8313_2          19 KB  conda-forge
#     libprotobuf-3.12.3         |       hab81aa3_2         2.1 MB  conda-forge
#     lightgbm-2.3.1             |   py38h4a8c4bd_0         731 KB  conda-forge
#     mako-1.1.3                 |     pyh9f0ad1d_0          58 KB  conda-forge
#     missingno-0.4.2            |             py_1          12 KB  conda-forge
#     mlflow-1.7.0               |           py38_0         3.3 MB  conda-forge
#     multidict-4.7.5            |   py38h4d0b108_2          60 KB  conda-forge
#     multimethod-1.4            |             py_0          10 KB  conda-forge
#     murmurhash-1.0.0           |   py38hc84c608_0          15 KB  conda-forge
#     pandas-profiling-2.8.0     |             py_0         172 KB  conda-forge
#     phik-0.10.0                |             py_0         578 KB  conda-forge
#     plac-0.9.6                 |             py_1          18 KB  conda-forge
#     plotly-4.12.0              |     pyh9f0ad1d_0         5.9 MB  conda-forge
#     preshed-3.0.2              |   py38hc84c608_3          91 KB  conda-forge
#     prometheus_flask_exporter-0.18.1|     pyh9f0ad1d_0          18 KB  conda-forge
#     protobuf-3.12.3            |   py38hc84c608_0         692 KB  conda-forge
#     pyasn1-0.4.8               |             py_0          53 KB  conda-forge
#     pyasn1-modules-0.2.7       |             py_0          60 KB  conda-forge
#     pycaret-2.1.2              |     pyh9f0ad1d_0         153 KB  conda-forge
#     pyldavis-2.1.2             |             py_0          81 KB  conda-forge
#     pyod-0.8.3                 |     pyh9f0ad1d_0          68 KB  conda-forge
#     python-cufflinks-0.17.3    |             py_0          59 KB  conda-forge
#     python-editor-1.0.4        |             py_0           9 KB  conda-forge
#     querystring_parser-1.2.4   |             py_0          10 KB  conda-forge
#     retrying-1.3.3             |             py_2          11 KB  conda-forge
#     rsa-4.6                    |     pyh9f0ad1d_0          27 KB  conda-forge
#     s3transfer-0.3.3           |             py_3          51 KB  conda-forge
#     simplejson-3.17.2          |   py38h4d0b108_1         100 KB  conda-forge
#     smart_open-3.0.0           |     pyh9f0ad1d_0          77 KB  conda-forge
#     smmap-3.0.4                |     pyh9f0ad1d_0          22 KB  conda-forge
#     spacy-2.3.2                |   py38h02bb52f_0         7.8 MB  conda-forge
#     sqlparse-0.4.1             |     pyh9f0ad1d_0          34 KB  conda-forge
#     srsly-1.0.2                |   py38hc84c608_0         196 KB  conda-forge
#     tabulate-0.8.7             |     pyh9f0ad1d_0          24 KB  conda-forge
#     tangled-up-in-unicode-0.0.6|     pyh9f0ad1d_0         2.0 MB  conda-forge
#     textblob-0.15.3            |             py_0         595 KB  conda-forge
#     thinc-7.4.1                |   py38ha0d09dd_0         1.5 MB  conda-forge
#     typing-extensions-3.7.4.2  |                0           7 KB  conda-forge
#     umap-learn-0.4.6           |   py38h32f6830_0         111 KB  conda-forge
#     visions-0.6.4              |     pyh9f0ad1d_0          60 KB  conda-forge
#     wasabi-0.8.0               |     pyh9f0ad1d_0          22 KB  conda-forge
#     websocket-client-0.57.0    |   py38h32f6830_3          59 KB  conda-forge
#     wordcloud-1.8.0            |   py38h4d0b108_0         174 KB  conda-forge
#     yarl-1.5.1                 |   py38h4d0b108_0         131 KB  conda-forge
#     yellowbrick-1.2            |     pyh9f0ad1d_0         152 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:        71.4 MB
#
# The following NEW packages will be INSTALLED:
#
#   aiohttp            conda-forge/osx-64::aiohttp-3.7.2-py38h4d0b108_0
#   alembic            conda-forge/noarch::alembic-1.4.3-pyh9f0ad1d_0
#   appdirs            conda-forge/noarch::appdirs-1.4.4-pyh9f0ad1d_0
#   async-timeout      conda-forge/noarch::async-timeout-3.0.1-py_1000
#   boto3              conda-forge/noarch::boto3-1.16.10-pyhd8ed1ab_0
#   botocore           conda-forge/noarch::botocore-1.19.10-pyhd3deb0d_0
#   bz2file            conda-forge/noarch::bz2file-0.98-py_0
#   c-ares             conda-forge/osx-64::c-ares-1.16.1-haf1e3a3_3
#   cachetools         conda-forge/noarch::cachetools-4.1.1-py_0
#   catalogue          conda-forge/noarch::catalogue-1.0.0-py_0
#   catboost           conda-forge/osx-64::catboost-0.24-py38h32f6830_0
#   chart-studio       conda-forge/noarch::chart-studio-1.1.0-pyh9f0ad1d_0
#   colorlover         conda-forge/noarch::colorlover-0.3.0-py_0
#   configparser       conda-forge/noarch::configparser-5.0.1-py_0
#   confuse            conda-forge/noarch::confuse-1.3.0-pyh9f0ad1d_0
#   cufflinks-py       conda-forge/noarch::cufflinks-py-0.17.3-py_0
#   cymem              conda-forge/osx-64::cymem-2.0.3-py38hc84c608_2
#   cython-blis        conda-forge/osx-64::cython-blis-0.4.1-py38h64e0658_1
#   databricks-cli     conda-forge/noarch::databricks-cli-0.9.1-py_0
#   datefinder         conda-forge/noarch::datefinder-0.7.1-pyh9f0ad1d_0
#   docker-py          conda-forge/osx-64::docker-py-4.3.1-py38h32f6830_1
#   docker-pycreds     conda-forge/noarch::docker-pycreds-0.4.0-py_0
#   funcy              conda-forge/noarch::funcy-1.15-pyh9f0ad1d_0
#   gensim             conda-forge/osx-64::gensim-3.8.3-py38hc84c608_2
#   gitdb              conda-forge/noarch::gitdb-4.0.5-py_0
#   gitpython          conda-forge/noarch::gitpython-3.1.11-py_0
#   google-api-core    conda-forge/noarch::google-api-core-1.23.0-pyh9f0ad1d_0
#   google-auth        conda-forge/noarch::google-auth-1.23.0-pyhd8ed1ab_0
#   google-cloud-core  conda-forge/noarch::google-cloud-core-1.4.3-pyh9f0ad1d_0
#   google-cloud-stor~ conda-forge/noarch::google-cloud-storage-1.32.0-pyh9f0ad1d_0
#   google-crc32c      conda-forge/osx-64::google-crc32c-1.0.0-py38h320b2b7_1
#   google-resumable-~ conda-forge/noarch::google-resumable-media-1.1.0-pyh9f0ad1d_0
#   googleapis-common~ conda-forge/osx-64::googleapis-common-protos-1.52.0-py38h50d1736_1
#   gorilla            conda-forge/noarch::gorilla-0.3.0-py_0
#   grpcio             conda-forge/osx-64::grpcio-1.30.0-py38hb05251e_0
#   gunicorn           conda-forge/osx-64::gunicorn-20.0.4-py38h32f6830_2
#   htmlmin            conda-forge/noarch::htmlmin-0.1.12-py_1
#   imagehash          conda-forge/noarch::imagehash-4.1.0-pyh9f0ad1d_0
#   imbalanced-learn   conda-forge/noarch::imbalanced-learn-0.7.0-py_1
#   jmespath           conda-forge/noarch::jmespath-0.10.0-pyh9f0ad1d_0
#   kmodes             conda-forge/noarch::kmodes-0.10.2-pyh9f0ad1d_0
#   libcrc32c          conda-forge/osx-64::libcrc32c-1.1.1-hb1e8313_2
#   libprotobuf        conda-forge/osx-64::libprotobuf-3.12.3-hab81aa3_2
#   lightgbm           conda-forge/osx-64::lightgbm-2.3.1-py38h4a8c4bd_0
#   mako               conda-forge/noarch::mako-1.1.3-pyh9f0ad1d_0
#   missingno          conda-forge/noarch::missingno-0.4.2-py_1
#   mlflow             conda-forge/osx-64::mlflow-1.7.0-py38_0
#   multidict          conda-forge/osx-64::multidict-4.7.5-py38h4d0b108_2
#   multimethod        conda-forge/noarch::multimethod-1.4-py_0
#   murmurhash         conda-forge/osx-64::murmurhash-1.0.0-py38hc84c608_0
#   pandas-profiling   conda-forge/noarch::pandas-profiling-2.8.0-py_0
#   phik               conda-forge/noarch::phik-0.10.0-py_0
#   plac               conda-forge/noarch::plac-0.9.6-py_1
#   plotly             conda-forge/noarch::plotly-4.12.0-pyh9f0ad1d_0
#   preshed            conda-forge/osx-64::preshed-3.0.2-py38hc84c608_3
#   prometheus_flask_~ conda-forge/noarch::prometheus_flask_exporter-0.18.1-pyh9f0ad1d_0
#   protobuf           conda-forge/osx-64::protobuf-3.12.3-py38hc84c608_0
#   pyasn1             conda-forge/noarch::pyasn1-0.4.8-py_0
#   pyasn1-modules     conda-forge/noarch::pyasn1-modules-0.2.7-py_0
#   pycaret            conda-forge/noarch::pycaret-2.1.2-pyh9f0ad1d_0
#   pyldavis           conda-forge/noarch::pyldavis-2.1.2-py_0
#   pyod               conda-forge/noarch::pyod-0.8.3-pyh9f0ad1d_0
#   python-cufflinks   conda-forge/noarch::python-cufflinks-0.17.3-py_0
#   python-editor      conda-forge/noarch::python-editor-1.0.4-py_0
#   querystring_parser conda-forge/noarch::querystring_parser-1.2.4-py_0
#   retrying           conda-forge/noarch::retrying-1.3.3-py_2
#   rsa                conda-forge/noarch::rsa-4.6-pyh9f0ad1d_0
#   s3transfer         conda-forge/noarch::s3transfer-0.3.3-py_3
#   simplejson         conda-forge/osx-64::simplejson-3.17.2-py38h4d0b108_1
#   smart_open         conda-forge/noarch::smart_open-3.0.0-pyh9f0ad1d_0
#   smmap              conda-forge/noarch::smmap-3.0.4-pyh9f0ad1d_0
#   spacy              conda-forge/osx-64::spacy-2.3.2-py38h02bb52f_0
#   sqlparse           conda-forge/noarch::sqlparse-0.4.1-pyh9f0ad1d_0
#   srsly              conda-forge/osx-64::srsly-1.0.2-py38hc84c608_0
#   tabulate           conda-forge/noarch::tabulate-0.8.7-pyh9f0ad1d_0
#   tangled-up-in-uni~ conda-forge/noarch::tangled-up-in-unicode-0.0.6-pyh9f0ad1d_0
#   textblob           conda-forge/noarch::textblob-0.15.3-py_0
#   thinc              conda-forge/osx-64::thinc-7.4.1-py38ha0d09dd_0
#   typing-extensions  conda-forge/noarch::typing-extensions-3.7.4.2-0
#   umap-learn         conda-forge/osx-64::umap-learn-0.4.6-py38h32f6830_0
#   visions            conda-forge/noarch::visions-0.6.4-pyh9f0ad1d_0
#   wasabi             conda-forge/noarch::wasabi-0.8.0-pyh9f0ad1d_0
#   websocket-client   conda-forge/osx-64::websocket-client-0.57.0-py38h32f6830_3
#   wordcloud          conda-forge/osx-64::wordcloud-1.8.0-py38h4d0b108_0
#   yarl               conda-forge/osx-64::yarl-1.5.1-py38h4d0b108_0
#   yellowbrick        conda-forge/noarch::yellowbrick-1.2-pyh9f0ad1d_0
#
#
#
# Downloading and Extracting Packages
# gensim-3.8.3         | 22.7 MB   | ##################################### | 100%
# cython-blis-0.4.1    | 3.1 MB    | ##################################### | 100%
# pyasn1-modules-0.2.7 | 60 KB     | ##################################### | 100%
# prometheus_flask_exp | 18 KB     | ##################################### | 100%
# tangled-up-in-unicod | 2.0 MB    | ##################################### | 100%
# alembic-1.4.3        | 111 KB    | ##################################### | 100%
# missingno-0.4.2      | 12 KB     | ##################################### | 100%
# mako-1.1.3           | 58 KB     | ##################################### | 100%
# datefinder-0.7.1     | 13 KB     | ##################################### | 100%
# configparser-5.0.1   | 23 KB     | ##################################### | 100%
# pyod-0.8.3           | 68 KB     | ##################################### | 100%
# libcrc32c-1.1.1      | 19 KB     | ##################################### | 100%
# phik-0.10.0          | 578 KB    | ##################################### | 100%
# kmodes-0.10.2        | 18 KB     | ##################################### | 100%
# confuse-1.3.0        | 20 KB     | ##################################### | 100%
# querystring_parser-1 | 10 KB     | ##################################### | 100%
# botocore-1.19.10     | 4.1 MB    | ##################################### | 100%
# multidict-4.7.5      | 60 KB     | ##################################### | 100%
# google-resumable-med | 40 KB     | ##################################### | 100%
# simplejson-3.17.2    | 100 KB    | ##################################### | 100%
# cufflinks-py-0.17.3  | 4 KB      | ##################################### | 100%
# umap-learn-0.4.6     | 111 KB    | ##################################### | 100%
# databricks-cli-0.9.1 | 48 KB     | ##################################### | 100%
# google-auth-1.23.0   | 62 KB     | ##################################### | 100%
# google-crc32c-1.0.0  | 23 KB     | ##################################### | 100%
# websocket-client-0.5 | 59 KB     | ##################################### | 100%
# srsly-1.0.2          | 196 KB    | ##################################### | 100%
# mlflow-1.7.0         | 3.3 MB    | ##################################### | 100%
# smmap-3.0.4          | 22 KB     | ##################################### | 100%
# gitdb-4.0.5          | 46 KB     | ##################################### | 100%
# cymem-2.0.3          | 33 KB     | ##################################### | 100%
# google-api-core-1.23 | 58 KB     | ##################################### | 100%
# pandas-profiling-2.8 | 172 KB    | ##################################### | 100%
# c-ares-1.16.1        | 92 KB     | ##################################### | 100%
# catboost-0.24        | 10.0 MB   | ##################################### | 100%
# bz2file-0.98         | 9 KB      | ##################################### | 100%
# htmlmin-0.1.12       | 21 KB     | ##################################### | 100%
# wasabi-0.8.0         | 22 KB     | ##################################### | 100%
# pyldavis-2.1.2       | 81 KB     | ##################################### | 100%
# pycaret-2.1.2        | 153 KB    | ##################################### | 100%
# protobuf-3.12.3      | 692 KB    | ##################################### | 100%
# funcy-1.15           | 29 KB     | ##################################### | 100%
# spacy-2.3.2          | 7.8 MB    | ##################################### | 100%
# python-editor-1.0.4  | 9 KB      | ##################################### | 100%
# cachetools-4.1.1     | 12 KB     | ##################################### | 100%
# plotly-4.12.0        | 5.9 MB    | ##################################### | 100%
# sqlparse-0.4.1       | 34 KB     | ##################################### | 100%
# boto3-1.16.10        | 70 KB     | ##################################### | 100%
# rsa-4.6              | 27 KB     | ##################################### | 100%
# visions-0.6.4        | 60 KB     | ##################################### | 100%
# tabulate-0.8.7       | 24 KB     | ##################################### | 100%
# typing-extensions-3. | 7 KB      | ##################################### | 100%
# aiohttp-3.7.2        | 603 KB    | ##################################### | 100%
# lightgbm-2.3.1       | 731 KB    | ##################################### | 100%
# wordcloud-1.8.0      | 174 KB    | ##################################### | 100%
# multimethod-1.4      | 10 KB     | ##################################### | 100%
# yellowbrick-1.2      | 152 KB    | ##################################### | 100%
# imagehash-4.1.0      | 288 KB    | ##################################### | 100%
# smart_open-3.0.0     | 77 KB     | ##################################### | 100%
# chart-studio-1.1.0   | 51 KB     | ##################################### | 100%
# docker-pycreds-0.4.0 | 11 KB     | ##################################### | 100%
# imbalanced-learn-0.7 | 97 KB     | ##################################### | 100%
# murmurhash-1.0.0     | 15 KB     | ##################################### | 100%
# s3transfer-0.3.3     | 51 KB     | ##################################### | 100%
# textblob-0.15.3      | 595 KB    | ##################################### | 100%
# preshed-3.0.2        | 91 KB     | ##################################### | 100%
# plac-0.9.6           | 18 KB     | ##################################### | 100%
# async-timeout-3.0.1  | 11 KB     | ##################################### | 100%
# gorilla-0.3.0        | 11 KB     | ##################################### | 100%
# libprotobuf-3.12.3   | 2.1 MB    | ##################################### | 100%
# gitpython-3.1.11     | 110 KB    | ##################################### | 100%
# google-cloud-storage | 64 KB     | ##################################### | 100%
# yarl-1.5.1           | 131 KB    | ##################################### | 100%
# retrying-1.3.3       | 11 KB     | ##################################### | 100%
# python-cufflinks-0.1 | 59 KB     | ##################################### | 100%
# thinc-7.4.1          | 1.5 MB    | ##################################### | 100%
# colorlover-0.3.0     | 12 KB     | ##################################### | 100%
# docker-py-4.3.1      | 182 KB    | ##################################### | 100%
# googleapis-common-pr | 70 KB     | ##################################### | 100%
# appdirs-1.4.4        | 13 KB     | ##################################### | 100%
# google-cloud-core-1. | 26 KB     | ##################################### | 100%
# grpcio-1.30.0        | 1.9 MB    | ##################################### | 100%
# gunicorn-20.0.4      | 117 KB    | ##################################### | 100%
# catalogue-1.0.0      | 10 KB     | ##################################### | 100%
# pyasn1-0.4.8         | 53 KB     | ##################################### | 100%
# jmespath-0.10.0      | 21 KB     | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: | WARNING conda.core.path_actions:verify(962): Unable to create environments file. Path not writable.
#   environment location: /Users/thomaschenu/.conda/environments.txt
#
# done
# Executing transaction: done
#
# Note: you may need to restart the kernel to use updated packages.

# %%
conda install -c conda-forge imbalanced-learn
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# # All requested packages already installed.
#
#
# Note: you may need to restart the kernel to use updated packages.
